# %%
# Script to build JSON-LD pages that provide multilingual labels and definitions controlled vocabularies
# Steve Baskauf 2020-09-26 CC0

import re
import requests   # best library to manage HTTP transactions
import csv        # library to read/write/parse CSV files
import json       # library to convert JSON to Python data structures
import pandas as pd

# -----------------
# Configuration section
# -----------------

# This is the base URL for raw files from the branch of the repo that has been pushed to GitHub. In this example,
# the branch is named "pathway"
github_base_url = 'https://raw.githubusercontent.com/tdwg/rs.tdwg.org/format_cv/'
database_name = 'format'
translations_url = 'https://raw.githubusercontent.com/tdwg/rs.tdwg.org/format_cv/format/format-translations.csv'

out_filename = 'format.json'

has_broader = True # set to true if any terms have skos:broader values
has_exactMatch = True # set to true of any terms have skos:exactMatch values

label_col_prefix = 'label_'
def_col_prefix = 'definition_'
localname_column_header = 'term_localName'

# ---------------
# Function definitions
# ---------------

# replace URL with link
#
def createLinks(text):
    def repl(match):
        if match.group(1)[-1] == '.':
            return '<a href="' + match.group(1)[:-1] + '">' + match.group(1)[:-1] + '</a>.'
        return '<a href="' + match.group(1) + '">' + match.group(1) + '</a>'

    pattern = '(https?://[^\s,;\)"]*)'
    result = re.sub(pattern, repl, text)
    return result

# %%
frame = pd.read_csv(github_base_url + database_name + '/constants.csv', na_filter=False)
namespace_iri = frame.domainRoot[0]

translations_frame = pd.read_csv(translations_url, na_filter=False)
columns = translations_frame.columns

# Extract the list of languages from the translations spreadsheet column headers
languages = []
for column_header in columns:
    if label_col_prefix in column_header:
        language_code = column_header.split(label_col_prefix)[1]
        if language_code != 'en':
            languages.append(column_header.split(label_col_prefix)[1])
print(languages)
# Out:
# ['es', 'zh-Hans']

# %%
# Create a dictionary of language dictionaries for the terms
translations_dictionary = {}
for index,row in translations_frame.iterrows():
    language_dictionary = {}
    for language in languages:
        term_dictionary = {'label': row[label_col_prefix + language], 'definition': row[def_col_prefix + language]}
        language_dictionary[language] = term_dictionary
    translations_dictionary[row[localname_column_header]] = language_dictionary
print(json.dumps(translations_dictionary, indent = 2))
# Out:
# {
#   "m": {
#     "es": {
#       "label": "Nombre aceptado en uso",
#       "definition": "El nombre completo, con autor\u00eda e informaci\u00f3n de fecha si se conoce, del tax\u00f3n actualmente v\u00e1lido (zool\u00f3gico) o aceptado (bot\u00e1nico). "
#     },
#     "zh-Hans": {
#       "label": "\u516c\u8ba4\u4f7f\u7528\u540d\u79f0",
#       "definition": "\u76ee\u524d\u6709\u6548\uff08\u52a8\u7269\u5b66\uff09\u7684\u6216\u516c\u8ba4\uff08\u690d\u7269\u5b66\uff09\u7684\u5206\u7c7b\u5355\u5143\u5168\u79f0\uff0c\u5982\u5df2\u77e5\u6765\u6e90\u548c\u65e5\u671f\u4fe1\u606f\u5219\u9700\u6ce8\u660e\u3002"
#     }
#   },
#   "e": {
#     "es": {
#       "label": "Nombre aceptado en uso - ID",
#       "definition": "Un identificador para el nombre en uso (significado del nombre, documentado de acuerdo con alguna fuente) del tax\u00f3n actualmente v\u00e1lido (zool\u00f3gico) o aceptado (bot\u00e1nico).   "
#     },
#     "zh-Hans": {
#       "label": "\u516c\u8ba4\u4f7f\u7528\u540d\u79f0\u7f16\u53f7",
#       "definition": "\u76ee\u524d\u6709\u6548\uff08\u52a8\u7269\u5b66\uff09\u7684\u6216\u516c\u8ba4\uff08\u690d\u7269\u5b66\uff09\u7684\u5206\u7c7b\u5355\u5143\u7684\u540d\u79f0\u4f7f\u7528\uff08\u6839\u636e\u6765\u6e90\u6240\u53d6\u540d\u79f0\u7684\u5b58\u6863\u8bb0\u5f55\u65b9\u6cd5\uff09\u6807\u8bc6\u7b26\u3002"
#     }
#   },
#   "m001": {
#     "es": {
#       "label": "Medios asociados",
#       "definition": "Una lista (concatenada o delimitada) de identificadores (publicaci\u00f3n, identificador \u00fanico global, URI) de los medios asociados con el registro biol\u00f3gico."
#     },
#     "zh-Hans": {
#       "label": "\u76f8\u5173\u5a92\u4ecb",
#       "definition": "\u53d1\u73b0\u5a92\u4ecb\u7684\uff08\u53d1\u8868\u3001\u5168\u5c40\u552f\u4e00\u6807\u8bc6\u7b26\u3001\u7edf\u4e00\u8d44\u6e90\u6807\u8bc6\u7b26\u7b49\uff09\u6807\u8bc6\u7b26\u4e4b\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u5217\u8868\u3002"
#     }
#   },
#   "m002": {
#     "es": {
#       "label": "Registros biol\u00f3gicos asociados",
#       "definition": "Una lista (concatenada y separada) de los identificadores de otros registros biol\u00f3gicos y su relaci\u00f3n con este Registro Biol\u00f3gico. "
#     },
#     "zh-Hans": {
#       "label": "\u76f8\u5173\u4e8b\u4ef6",
#       "definition": "\u5176\u4ed6\u53d1\u73b0\u8bb0\u5f55\u53ca\u5176\u4e0e\u53d1\u73b0\u4fe1\u606f\u76f8\u5173\u8054\u7684\u6807\u8bc6\u7b26\u4e4b\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u5217\u8868\u3002"
#     }
#   },
#   "m003": {
#     "es": {
#       "label": "Referencias asociadas",
#       "definition": "Una lista (concatenada y separada) de los identificadores (publicaci\u00f3n, referencia bibliogr\u00e1fica, identificador \u00fanico global, URI) de la literatura asociada con el Registro Biol\u00f3gico. "
#     },
#     "zh-Hans": {
#       "label": "\u76f8\u5173\u53c2\u8003",
#       "definition": "\u4e0e\u53d1\u73b0\u60c5\u51b5\u76f8\u5173\u4e4b\u6587\u732e\u7684\uff08\u53d1\u8868\u3001\u53c2\u8003\u6587\u732e\u3001\u5168\u5c40\u552f\u4e00\u6807\u8bc6\u7b26\u3001\u7edf\u4e00\u8d44\u6e90\u6807\u8bc6\u7b26\u7b49\uff09\u6807\u8bc6\u7b26\u4e4b\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u5217\u8868\u3002"
#     }
#   },
#   "m004": {
#     "es": {
#       "label": "Secuencias asociadas",
#       "definition": "Una lista (concatenada y separada) de los identificadores (publicaci\u00f3n, identificador \u00fanico global, URI) de la informaci\u00f3n de la secuencia gen\u00e9tica asociada con el Registro Biol\u00f3gico. "
#     },
#     "zh-Hans": {
#       "label": "\u76f8\u5173\u5e8f\u5217",
#       "definition": "\u4e0e\u53d1\u73b0\u60c5\u51b5\u76f8\u5173\u4e4b\u57fa\u56e0\u5e8f\u5217\u4fe1\u606f\u7684\uff08\u53d1\u8868\u3001\u5168\u5c40\u552f\u4e00\u6807\u8bc6\u7b26\u3001\u7edf\u4e00\u8d44\u6e90\u6807\u8bc6\u7b26\u7b49\uff09\u6807\u8bc6\u7b26\u4e4b\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u5217\u8868\u3002"
#     }
#   },
#   "m005": {
#     "es": {
#       "label": "Taxones asociados",
#       "definition": "Una lista (concatenada y separada) de los identificadores o nombres de taxones y su asociaci\u00f3n con el Registro Biol\u00f3gico."
#     },
#     "zh-Hans": {
#       "label": "\u76f8\u5173\u7c7b\u7fa4",
#       "definition": "\u4e0e\u53d1\u73b0\u60c5\u51b5\u76f8\u5173\u7684\u6807\u8bc6\u7b26\u6216\u5206\u7c7b\u5355\u5143\u540d\u79f0\u4e4b\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u5217\u8868\u3002"
#     }
#   },
#   "m006": {
#     "es": {
#       "label": "Base del registro",
#       "definition": "La naturaleza espec\u00edfica del registro de datos - un subtipo de Tipo.\u00a0La pr\u00e1ctica recomendada es el uso de lenguaje controlado como el vocabulario controlado para Tipo de Darwin Core (http://rs.tdwg.org/dwc/terms/type-vocabulary/index.htm). "
#     },
#     "zh-Hans": {
#       "label": "\u8bb0\u5f55\u57fa\u7840",
#       "definition": "\u6570\u636e\u8bb0\u5f55\u7684\u7279\u6709\u5c5e\u6027\u2014\u2014dcterms:type\u7684\u5b50\u7c7b\u3002\u5efa\u8bae\u6700\u597d\u4f7f\u7528\u63a7\u5236\u6027\u8bcd\u6c47\uff0c\u5982\u8fbe\u5c14\u6587\u6838\u5fc3\u7c7b\u578b\u8bcd\u6c47\uff08http://rs.tdwg.org/dwc/terms/type-vocabulary/index.htm\uff09\u3002"
#     }
#   },
#   "m007": {
#     "es": {
#       "label": "Capa",
#       "definition": "El nombre completo de la capa litoestratigr\u00e1fica de la cual se colect\u00f3 el elemento catalogado. "
#     },
#     "zh-Hans": {
#       "label": "\u5ca9\u5e8a",
#       "definition": "\u91c7\u96c6\u6536\u5f55\u5bf9\u8c61\u7684\u5ca9\u5e8a\u7684\u5168\u79f0\u3002"
#     }
#   },
#   "m008": {
#     "es": {
#       "label": "Comportamiento",
#       "definition": "Una descripci\u00f3n de la conducta mostrada por el sujeto en el momento del Registro Biol\u00f3gico.\u00a0La pr\u00e1ctica recomendada es el uso de un lenguaje controlado."
#     },
#     "zh-Hans": {
#       "label": "\u884c\u4e3a",
#       "definition": "\u5bf9\u8bb0\u5f55\u53d1\u73b0\u8fc7\u7a0b\u4e2d\u76ee\u6807\u884c\u4e3a\u7684\u63cf\u8ff0\u3002\u5efa\u8bae\u6700\u597d\u4f7f\u7528\u63a7\u5236\u6027\u8bcd\u6c47\u3002"
#     }
#   },
#   "m009": {
#     "es": {
#       "label": "N\u00famero de cat\u00e1logo",
#       "definition": "Un identificador (preferiblemente \u00fanico) para el registro dentro del conjunto de datos o colecci\u00f3n. "
#     },
#     "zh-Hans": {
#       "label": "\u76ee\u5f55\u7f16\u53f7",
#       "definition": "\u6570\u636e\u96c6\u6216\u4fdd\u85cf\u4fe1\u606f\u4e2d\u7684\u8bb0\u5f55\u6807\u8bc6\u7b26\uff08\u6700\u597d\u662f\u552f\u4e00\u7684\uff09\u3002"
#     }
#   },
#   "m010": {
#     "es": {
#       "label": "Clase",
#       "definition": "El nombre cient\u00edfico completo de la clase en la que se clasifica el tax\u00f3n."
#     },
#     "zh-Hans": {
#       "label": "\u7eb2",
#       "definition": "\u5206\u7c7b\u5355\u5143\u6240\u5c5e\u7eb2\u7684\u5b8c\u6574\u5b66\u540d\u3002"
#     }
#   },
#   "m011": {
#     "es": {
#       "label": "C\u00f3digo de la colecci\u00f3n",
#       "definition": "El nombre, acr\u00f3nimo, coden, o iniciales que identifican la colecci\u00f3n o conjunto de datos del que procede el registro. "
#     },
#     "zh-Hans": {
#       "label": "\u4fdd\u85cf\u4ee3\u7801",
#       "definition": "\u6807\u8bc6\u751f\u6210\u8bb0\u5f55\u7684\u4fdd\u85cf\u4fe1\u606f\u6216\u6570\u636e\u96c6\u7684\u540d\u79f0\u3001\u9996\u5b57\u6bcd\u7f29\u7565\u8bcd\u3001\u5206\u7c7b\u7f16\u53f7\u6216\u8bcd\u8d77\u9996\u5b57\u6bcd"
#     }
#   },
#   "m012": {
#     "es": {
#       "label": "ID de la colecci\u00f3n",
#       "definition": "Un identificador de la colecci\u00f3n o conjunto de datos del que procede el registro. Para espec\u00edmenes f\u00edsicos, la pr\u00e1ctica recomendada es utilizar el identificador de un \u00edndice de colecci\u00f3n tal como el \u00cdndice de Colecciones de Biodiversidad (http://www.biodi"
#     },
#     "zh-Hans": {
#       "label": "\u4fdd\u85cf\u7f16\u53f7",
#       "definition": "\u751f\u6210\u8bb0\u5f55\u7684\u4fdd\u85cf\u4fe1\u606f\u6216\u6570\u636e\u96c6\u7684\u6807\u8bc6\u7b26\u3002\u9488\u5bf9\u5b9e\u4f53\u6807\u672c\uff0c\u5efa\u8bae\u6700\u597d\u4f7f\u7528\u4fdd\u85cf\u6ce8\u518c\u6807\u8bc6\u7b26\uff0c\u5982\u751f\u7269\u591a\u6837\u6027\u4fdd\u85cf\u7d22\u5f15(http://www.biodiversitycollectionsindex.org/)\u3002"
#     }
#   },
#   "m013": {
#     "es": {
#       "label": "Continente",
#       "definition": "El nombre del continente en el que la ubicaci\u00f3n ocurre.\u00a0La pr\u00e1ctica recomendada es el uso de un lenguaje controlado, como la norma ISO 3166 de c\u00f3digos de Continente. "
#     },
#     "zh-Hans": {
#       "label": "\u6d32",
#       "definition": "\u53d1\u73b0\u5730\u70b9\u6240\u5728\u7684\u5927\u6d32\u540d\u3002\u5efa\u8bae\u6700\u597d\u4f7f\u7528\u63a7\u5236\u6027\u8bcd\u6c47\uff0c\u5982\u76d6\u63d0\u5730\u7406\u540d\u79f0\u7d22\u5f15\u5178\u6216\u56fd\u9645\u6807\u51c6\u5316\u7ec4\u7ec73166\u6d32\u4ee3\u7801\u3002"
#     }
#   },
#   "m014": {
#     "es": {
#       "label": "Precisi\u00f3n de las coordenadas",
#       "definition": "Una representaci\u00f3n decimal de la precisi\u00f3n de las coordenadas provistas en Latitud Decimal y Longitud Decimal. "
#     },
#     "zh-Hans": {
#       "label": "\u5750\u6807\u7cbe\u5ea6",
#       "definition": "\u7cbe\u786e\u5230\u5c0f\u6570\u7684\u7eac\u5ea6\u548c\u7ecf\u5ea6\u5750\u6807\u7684\u5c0f\u6570\u793a\u6570\u3002"
#     }
#   },
#   "m015": {
#     "es": {
#       "label": " Incertidumbre de las coordenadas en metros",
#       "definition": "La distancia horizontal (en metros) de la Latitud Decimal y Longitud Decimal provistas describiendo el c\u00edrculo m\u00e1s peque\u00f1o que contiene la totalidad de la ubicaci\u00f3n.\u00a0Deje el valor vac\u00edo si la incertidumbre es desconocida, no se puede estimar, o no es apli"
#     },
#     "zh-Hans": {
#       "label": "\u5750\u6807\u4e0d\u786e\u5b9a\u6027\uff08\u4ee5\u7c73\u4e3a\u5355\u4f4d\uff09",
#       "definition": "\u5230\u6db5\u76d6\u6574\u4e2a\u5730\u70b9\u7684\u6700\u5c0f\u5706\u5f62\u533a\u57df\u7684\u5c0f\u6570\u7eac\u5ea6\u548c\u7ecf\u5ea6\u7684\u6c34\u5e73\u8ddd\u79bb\uff08\u4ee5\u201c\u7c73\u201d\u4e3a\u5355\u4f4d\uff09\u3002\u82e5\u672a\u77e5\u3001\u65e0\u6cd5\u4f30\u7b97\u6216\u4e0d\u9002\u7528\uff08\u7531\u4e8e\u6ca1\u6709\u5750\u6807\uff09\uff0c\u5219\u503c\u4e3a\u7a7a\u3002\u6b64\u9879\u4e2d0\u4e0d\u662f\u6709\u6548\u503c\u3002"
#     }
#   },
#   "m016": {
#     "es": {
#       "label": "Pa\u00eds",
#       "definition": "El nombre del pa\u00eds o unidad administrativa de mayor jerarqu\u00eda de la ubicaci\u00f3n.\u00a0La pr\u00e1ctica recomendada es utilizar un identificador persistente de un lenguaje controlado como el Tesauro Getty de Nombres Geogr\u00e1ficos. "
#     },
#     "zh-Hans": {
#       "label": "\u56fd\u5bb6",
#       "definition": "\u53d1\u73b0\u5730\u70b9\u7684\u56fd\u5bb6\u6216\u4e3b\u8981\u884c\u653f\u533a\u5212\u540d\u79f0\u3002\u5efa\u8bae\u6700\u597d\u4f7f\u7528\u63a7\u5236\u6027\u8bcd\u6c47\uff0c\u5982\u76d6\u63d0\u5730\u7406\u540d\u79f0\u7d22\u5f15\u3002"
#     }
#   },
#   "m017": {
#     "es": {
#       "label": "C\u00f3digo del pa\u00eds",
#       "definition": "El c\u00f3digo est\u00e1ndar para el pa\u00eds de la ubicaci\u00f3n.\u00a0La pr\u00e1ctica recomendada es el uso de ISO 3166-1-alfa-2 de c\u00f3digos de pa\u00edses. "
#     },
#     "zh-Hans": {
#       "label": "\u56fd\u5bb6\u4ee3\u7801",
#       "definition": "\u53d1\u73b0\u5730\u70b9\u7684\u6807\u51c6\u56fd\u5bb6\u4ee3\u7801\u3002\u5efa\u8bae\u6700\u597d\u4f7f\u7528\u56fd\u9645\u6807\u51c6\u5316\u7ec4\u7ec73166-1-\u963f\u5c14\u6cd5-2\u56fd\u5bb6\u4ee3\u7801\u3002"
#     }
#   },
#   "m018": {
#     "es": {
#       "label": "Condado",
#       "definition": "El nombre completo, sin abreviar de la siguiente regi\u00f3n administrativa de menor jerarqu\u00eda que Estado Provincia (condado, departamento, etc.) de la ubicaci\u00f3n."
#     },
#     "zh-Hans": {
#       "label": "\u90e1/\u53bf",
#       "definition": "\u53d1\u73b0\u5730\u70b9\u6240\u5728\u7684\u9664\u5dde/\u7701\u4e4b\u5916\u7684\u6b21\u4e00\u7ea7\u884c\u653f\u533a\u5212\uff08\u53bf\u3001\u90e1\u3001\u884c\u653f\u533a\u7b49\uff09\u3002"
#     }
#   },
#   "m019": {
#     "es": {
#       "label": "Generalizaci\u00f3n de los datos",
#       "definition": "Las medidas adoptadas para que los datos compartidos sean menos espec\u00edficos o completos que en su forma original.\u00a0Sugiere que datos alternativos de mayor calidad pueden estar disponibles bajo petici\u00f3n."
#     },
#     "zh-Hans": {
#       "label": "\u6570\u636e\u6982\u62ec",
#       "definition": "\u4e3a\u4f7f\u5171\u4eab\u6570\u636e\u8f83\u4e4b\u5176\u539f\u59cb\u5f62\u5f0f\u4e0d\u90a3\u4e48\u7cbe\u786e\u6216\u5b8c\u6574\u6240\u91c7\u53d6\u7684\u884c\u52a8\u3002\u5efa\u8bae\u4ee5\u66f4\u9ad8\u8d28\u91cf\u7684\u66ff\u4ee3\u6570\u636e\u5907\u7d22\u3002"
#     }
#   },
#   "m020": {
#     "es": {
#       "label": "ID del conjunto de datos",
#       "definition": "Un identificador para el conjunto de datos.\u00a0Puede ser un identificador \u00fanico global o un identificador espec\u00edfico de una colecci\u00f3n o instituci\u00f3n."
#     },
#     "zh-Hans": {
#       "label": "\u6570\u636e\u96c6\u7f16\u53f7",
#       "definition": "\u6570\u636e\u96c6\u7684\u6807\u8bc6\u7b26\u3002\u53ef\u80fd\u662f\u4e00\u4e2a\u5168\u5c40\u552f\u4e00\u6807\u8bc6\u7b26\u6216\u4e00\u4e2a\u4fdd\u85cf\u4e2d\u5fc3\u6216\u7814\u7a76\u673a\u6784\u7684\u7279\u5b9a\u6807\u8bc6\u7b26\u3002"
#     }
#   },
#   "m021": {
#     "es": {
#       "label": "Nombre del conjunto de datos",
#       "definition": "El nombre que identifica el conjunto de datos del cual se deriv\u00f3 el registro.  "
#     },
#     "zh-Hans": {
#       "label": "\u6570\u636e\u96c6\u540d\u79f0",
#       "definition": "\u6807\u8bc6\u751f\u6210\u8bb0\u5f55\u7684\u6570\u636e\u96c6\u7684\u540d\u79f0\u3002"
#     }
#   },
#   "m022": {
#     "es": {
#       "label": "Fecha de identificaci\u00f3n",
#       "definition": "La fecha en que fue identificado el sujeto como representativo del tax\u00f3n.\u00a0La pr\u00e1ctica recomendada es utilizar un esquema de codificaci\u00f3n, como ISO 8601:2004 (E). "
#     },
#     "zh-Hans": {
#       "label": "\u9274\u5b9a\u65e5\u671f",
#       "definition": "\u6d89\u53ca\u88ab\u89c6\u4e3a\u4ee3\u8868\u5206\u7c7b\u5355\u5143\u7684\u4e3b\u4f53\u7684\u6570\u636e\u3002\u5efa\u8bae\u6700\u597d\u4f7f\u7528\u7f16\u7801\u65b9\u6848\uff0c\u5982ISO 8601:2004(E)\u3002"
#     }
#   },
#   "m023": {
#     "es": {
#       "label": "D\u00eda",
#       "definition": "El d\u00eda en n\u00fameros enteros, del mes en que ocurri\u00f3 el evento. "
#     },
#     "zh-Hans": {
#       "label": "\u5929",
#       "definition": "\u4e8b\u4ef6\u53d1\u751f\u7684\u6574\u6570\u5929\u3002"
#     }
#   },
#   "m024": {
#     "es": {
#       "label": "Latitud decimal",
#       "definition": "La latitud geogr\u00e1fica (en grados decimales, utilizando el sistema de referencia espacial provisto en Datum Geod\u00e9sico) del centro geogr\u00e1fico de una ubicaci\u00f3n.\u00a0Los valores positivos se encuentran al norte del ecuador, los valores negativos est\u00e1n al sur del "
#     },
#     "zh-Hans": {
#       "label": "\u5341\u8fdb\u5236\u7eac\u5ea6",
#       "definition": "\u5730\u70b9\u7684\u5730\u7406\u4e2d\u5fc3\u7684\u7eac\u5ea6\uff08\u4ee5\u5c0f\u6570\u8868\u793a\uff0c\u91c7\u7528\u5927\u5730\u57fa\u51c6\u4e2d\u63d0\u4f9b\u7684\u7a7a\u95f4\u53c2\u7167\u7cfb\u7edf\uff09\u3002\u6b63\u503c\u4ee3\u8868\u8d64\u9053\u4ee5\u5317\uff0c\u8d1f\u503c\u4ee3\u8868\u8d64\u9053\u4ee5\u5357\u3002\u6cd5\u5b9a\u503c\u4ecb\u4e8e-90\u81f390\uff08\u542b\uff09\u4e4b\u95f4\u3002"
#     }
#   },
#   "m025": {
#     "es": {
#       "label": "Longitud decimal",
#       "definition": "La longitud geogr\u00e1fica (en grados decimales, mediante el sistema de referencia espacial provisto en Datum Geod\u00e9sico) del centro geogr\u00e1fico de un lugar.\u00a0Los valores positivos se encuentran al este del meridiano de Greenwich, los valores negativos se encuen"
#     },
#     "zh-Hans": {
#       "label": "\u5341\u8fdb\u5236\u7ecf\u5ea6",
#       "definition": "\u5730\u70b9\u7684\u5730\u7406\u4e2d\u5fc3\u7684\u7ecf\u5ea6\uff08\u4ee5\u5c0f\u6570\u8868\u793a\uff0c\u91c7\u7528\u5927\u5730\u57fa\u51c6\u4e2d\u63d0\u4f9b\u7684\u7a7a\u95f4\u53c2\u7167\u7cfb\u7edf\uff09\u3002\u6b63\u503c\u4ee3\u8868\u683c\u6797\u5a01\u6cbb\u5b50\u5348\u7ebf\u4ee5\u897f\uff0c\u8d1f\u503c\u4ee3\u8868\u683c\u6797\u5a01\u6cbb\u5b50\u5348\u7ebf\u4ee5\u4e1c\u3002\u6cd5\u5b9a\u503c\u4ecb\u4e8e-180\u81f3180\uff08\u542b\uff09\u4e4b\u95f4\u3002"
#     }
#   },
#   "m026": {
#     "es": {
#       "label": "Disposici\u00f3n",
#       "definition": "El estado actual de un esp\u00e9cimen con respecto a la colecci\u00f3n identificada en C\u00f3digo de la Colecci\u00f3n o ID de la Colecci\u00f3n.\u00a0La pr\u00e1ctica recomendada es el uso de un lenguaje controlado. "
#     },
#     "zh-Hans": {
#       "label": "\u5bc4\u5b58",
#       "definition": "\u4e0e\u786e\u5b9a\u4e86\u4fdd\u85cf\u4ee3\u7801\u6216\u4fdd\u85cf\u8bc6\u522b\u7801\u7684\u4fdd\u85cf\u7269\u76f8\u5173\u7684\u6807\u672c\u7684\u5f53\u524d\u72b6\u6001\u3002\u63a8\u8350\u4f7f\u7528\u63a7\u5236\u8bcd\u8868\u3002"
#     }
#   },
#   "m027": {
#     "es": {
#       "label": "Propiedades din\u00e1micas",
#       "definition": "Una lista (concatenada y separada) de las medidas, hechos, caracter\u00edsticas, o aseveraciones adicionales sobre el registro. Su intenci\u00f3n es proporcionar un mecanismo para contenido estructurado como pares de valor.  "
#     },
#     "zh-Hans": {
#       "label": "\u52a8\u6001\u5c5e\u6027",
#       "definition": "\u5173\u4e8e\u8bb0\u5f55\u7684\u5176\u4ed6\u6d4b\u91cf\u3001\u60c5\u51b5\u3001\u7279\u5f81\u3001\u5224\u5b9a\u7b49\u4fe1\u606f\u7684\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u5217\u8868\u3002\u610f\u5728\u4e3a\u8bf8\u5982\u952e\u503c\u5bf9\u7b49\u7684\u7ed3\u6784\u5316\u5185\u5bb9\u8bbe\u7acb\u673a\u5236\u3002"
#     }
#   },
#   "m028": {
#     "es": {
#       "label": "Edad temprana o estad\u00edo inferior",
#       "definition": "El nombre completo de la edad geocronol\u00f3gica m\u00e1s temprana posible o la etapa cronoestratigr\u00e1fica m\u00e1s baja, atribuible al horizonte estratigr\u00e1fico donde se recolect\u00f3 el objeto catalogado. "
#     },
#     "zh-Hans": {
#       "label": "\u6700\u65e9\u5730\u8d28\u5e74\u4ee3\u6216\u6700\u4f4e\u5e74\u4ee3\u5730\u5c42",
#       "definition": "\u7f16\u76ee\u9879\u6240\u91c7\u96c6\u7684\u5730\u5c42\u5c42\u4f4d\u6240\u5c5e\u4e4b\u53ef\u80fd\u7684\u6700\u65e9\u7684\u5730\u8d28\u5e74\u4ee3\u6216\u6700\u4f4e\u7684\u5e74\u4ee3\u5730\u5c42\u7684\u5168\u79f0\u3002"
#     }
#   },
#   "m029": {
#     "es": {
#       "label": "E\u00f3n temprano o eonotema inferior",
#       "definition": "El nombre completo del e\u00f3n geocronol\u00f3gico m\u00e1s temprano o el eratema crono-estratigr\u00e1fico m\u00e1s bajo, o el nombre informal (\"Prec\u00e1mbrico\") atribuible al horizonte estratigr\u00e1fico donde se recolect\u00f3 el objeto catalogado. "
#     },
#     "zh-Hans": {
#       "label": "\u6700\u65e9\u5730\u8d28\u5b99\u6216\u6700\u4f4e\u5730\u5c42\u5b87",
#       "definition": "\u7f16\u76ee\u9879\u6240\u91c7\u96c6\u7684\u5730\u5c42\u5c42\u4f4d\u6240\u5c5e\u4e4b\u53ef\u80fd\u7684\u6700\u65e9\u7684\u5730\u8d28\u5b99\u6216\u6700\u4f4e\u7684\u5730\u5c42\u5b87\u7684\u5168\u79f0\u6216\u975e\u6b63\u5f0f\u540d\u79f0\uff08\u201c\u524d\u5bd2\u6b66\u7eaa\u201d\uff09\u3002"
#     }
#   },
#   "m030": {
#     "es": {
#       "label": "\u00c9poca temprana o serie inferior",
#       "definition": "El nombre completo de la \u00e9poca geocronol\u00f3gica m\u00e1s temprana o la serie cronoestratigr\u00e1fica m\u00e1s baja posible, atribuible al horizonte estratigr\u00e1fico donde se recolect\u00f3 el objeto catalogado. "
#     },
#     "zh-Hans": {
#       "label": "\u6700\u65e9\u5730\u8d28\u4e16\u6216\u6700\u4f4e\u5730\u5c42\u7edf",
#       "definition": "\u7f16\u76ee\u9879\u6240\u91c7\u96c6\u7684\u5730\u5c42\u5c42\u4f4d\u6240\u5c5e\u4e4b\u53ef\u80fd\u7684\u6700\u65e9\u7684\u5730\u8d28\u4e16\u6216\u6700\u4f4e\u7684\u5730\u5c42\u7edf\u7684\u5168\u79f0\u3002"
#     }
#   },
#   "m031": {
#     "es": {
#       "label": "Era temprana o eratema inferior",
#       "definition": "El nombre completo de la era geocronol\u00f3gica m\u00e1s temprana o el eratema crono-estratigr\u00e1fico m\u00e1s bajo, atribuible al horizonte estratigr\u00e1fico donde se recolect\u00f3 el objeto catalogado. "
#     },
#     "zh-Hans": {
#       "label": "\u6700\u65e9\u5730\u8d28\u4ee3\u6216\u6700\u4f4e\u5730\u5c42\u754c",
#       "definition": "\u7f16\u76ee\u9879\u6240\u91c7\u96c6\u7684\u5730\u5c42\u5c42\u4f4d\u6240\u5c5e\u4e4b\u53ef\u80fd\u7684\u6700\u65e9\u7684\u5730\u8d28\u4ee3\u6216\u6700\u4f4e\u7684\u5730\u5c42\u754c\u7684\u5168\u79f0\u3002"
#     }
#   },
#   "m032": {
#     "es": {
#       "label": "Periodo temprano o sistema inferior",
#       "definition": "Puede corresponder a: a) un indicador de la existencia de, b) una referencia a (publicaci\u00f3n, URI), o c) el texto de las notas tomadas en campo sobre el evento."
#     },
#     "zh-Hans": {
#       "label": "\u6700\u65e9\u5730\u8d28\u7eaa\u6216\u6700\u4f4e\u5730\u5c42\u7cfb",
#       "definition": "\u7f16\u76ee\u9879\u6240\u91c7\u96c6\u7684\u5730\u5c42\u5c42\u4f4d\u6240\u5c5e\u4e4b\u53ef\u80fd\u7684\u6700\u65e9\u7684\u5730\u8d28\u7eaa\u6216\u6700\u4f4e\u7684\u5730\u5c42\u7cfb\u7684\u5168\u79f0\u3002"
#     }
#   },
#   "m033": {
#     "es": {
#       "label": "D\u00eda final del a\u00f1o",
#       "definition": "El \u00faltimo d\u00eda ordinal del a\u00f1o en que ocurri\u00f3 el evento (1 para el 1\u00ba de enero, 365 para el 31 de diciembre, excepto en un a\u00f1o bisiesto, en cuyo caso es 366)."
#     },
#     "zh-Hans": {
#       "label": "\u5f53\u5e74\u7ed3\u675f\u65e5",
#       "definition": "\u4e8b\u4ef6\u53d1\u751f\u5f53\u5e74\u7684\u6700\u65b0\u65e5\u671f\u53f7\uff08\u9664\u4e86\u95f0\u5e74\u6709366\u5929\u7684\u60c5\u51b5\uff0c1\u4ee3\u88681\u67081\u65e5\uff0c365\u4ee3\u886812\u670831\u65e5\uff09\u3002"
#     }
#   },
#   "m034": {
#     "es": {
#       "label": "Medios de establecimiento",
#       "definition": "El proceso por el cual el individuo(s) biol\u00f3gico(s) representado en el Registro Biol\u00f3gico se estableci\u00f3 en el lugar.\u00a0La pr\u00e1ctica recomendada es el uso de un lenguaje controlado. "
#     },
#     "zh-Hans": {
#       "label": "\u786e\u5b9a\u65b9\u6cd5",
#       "definition": "\u5728\u91c7\u96c6\u5730\u70b9\u786e\u5b9a\u751f\u7269\u4e2a\u4f53\u5728\u4e8b\u4ef6\u4e2d\u8868\u73b0\u7684\u8fc7\u7a0b\u3002\u5efa\u8bae\u6700\u4f73\u505a\u6cd5\u662f\u4f7f\u7528\u4e00\u4e2a\u63a7\u5236\u6027\u8bcd\u6c47\u3002"
#     }
#   },
#   "m035": {
#     "es": {
#       "label": "Fecha del evento",
#       "definition": "La fecha y hora o el intervalo durante el cual se produjo un evento.\u00a0Para los registros de especies, esta es la fecha y hora cuando el evento se registr\u00f3.\u00a0No es adecuado para un momento en un contexto geol\u00f3gico.\u00a0La pr\u00e1ctica recomendada es utilizar un esqu"
#     },
#     "zh-Hans": {
#       "label": "\u4e8b\u4ef6\u65e5\u671f",
#       "definition": "\u4e8b\u4ef6\u53d1\u751f\u7684\u65e5\u671f\u6216\u95f4\u9694\u3002\u5bf9\u4e8e\u5df2\u53d1\u751f\u7684\u4e8b\u4ef6\u8fd9\u662f\u88ab\u8bb0\u5f55\u7684\u65e5\u671f\u3002\t\t\t\t\t\t\u4e0d\u9002\u5408\u5730\u8d28\u80cc\u666f\u65f6\u95f4\u3002\u5efa\u8bae\u6700\u4f73\u505a\u6cd5\u662f\u4f7f\u7528\u4e00\u4e2a\u7f16\u7801\u65b9\u6848\uff0c\u4f8b\u5982ISO 8601:2004(E)\u3002"
#     }
#   },
#   "m036": {
#     "es": {
#       "label": "ID del evento",
#       "definition": "Un identificador para el conjunto de la informaci\u00f3n asociada a un Evento (algo que ocurre en un lugar y tiempo).\u00a0Puede ser un identificador \u00fanico global o un identificador espec\u00edfico para el conjunto de datos. "
#     },
#     "zh-Hans": {
#       "label": "\u4e8b\u4ef6\u7f16\u53f7",
#       "definition": "\u4e0e\u4e8b\u4ef6\u76f8\u5173\u7684\u4fe1\u606f\u96c6\u6807\u8bc6\u7b26\uff08\u53d1\u751f\u5728\u540c\u4e00\u5730\u70b9\u548c\u65f6\u95f4\uff09\u3002\u53ef\u80fd\u662f\u4e00\u4e2a\u5168\u5c40\u552f\u4e00\u6807\u8bc6\u7b26\u6216\u7279\u5b9a\u7684\u6570\u636e\u96c6\u6807\u8bc6\u7b26\u3002"
#     }
#   },
#   "m037": {
#     "es": {
#       "label": "Comentarios del evento",
#       "definition": "Comentarios o anotaciones sobre el evento. "
#     },
#     "zh-Hans": {
#       "label": "\u4e8b\u4ef6\u5907\u6ce8",
#       "definition": "\u5173\u4e8e\u4e8b\u4ef6\u7684\u8bc4\u8bba\u6216\u8bb0\u5f55\u3002"
#     }
#   },
#   "m038": {
#     "es": {
#       "label": "Hora del evento",
#       "definition": "El tiempo o intervalo durante el cual se produjo un evento.\u00a0La pr\u00e1ctica recomendada es utilizar un esquema de codificaci\u00f3n, tales como ISO 8601:2004 (E). "
#     },
#     "zh-Hans": {
#       "label": "\u4e8b\u4ef6\u65f6\u95f4",
#       "definition": "\u4e8b\u4ef6\u53d1\u751f\u7684\u65f6\u95f4\u6216\u95f4\u9694\u3002\t\t\t\u5efa\u8bae\u6700\u4f73\u505a\u6cd5\u662f\u4f7f\u7528\u4e00\u4e2a\u7f16\u7801\u65b9\u6848\uff0c\u4f8b\u5982ISO \t\t\t8601:2004(E)\u3002"
#     }
#   },
#   "m039": {
#     "es": {
#       "label": "Familia",
#       "definition": "El nombre cient\u00edfico completo de la familia en el que se clasifica el tax\u00f3n. "
#     },
#     "zh-Hans": {
#       "label": "\u79d1",
#       "definition": "\u5206\u7c7b\u5355\u5143\u6240\u5c5e\u79d1\u7684\u5b8c\u6574\u5b66\u540d\u3002"
#     }
#   },
#   "m040": {
#     "es": {
#       "label": "Notas de campo",
#       "definition": "Puede corresponder a: a) un indicador de la existencia de, b) una referencia a (publicaci\u00f3n, URI), o c) el texto de las notas tomadas en campo sobre el evento."
#     },
#     "zh-Hans": {
#       "label": "\u73b0\u573a\u8bb0\u5f55",
#       "definition": "\u6709\u5173\u4e8b\u4ef6\u7684\u73b0\u573a\u8bb0\u5f55\u4e4b\u4e00\uff1aa\uff09\u5b58\u5728\u6807\u5fd7\uff0cb\uff09\u51fa\u7248\u7269\u3001\u7f51\u7ad9\u8d44\u6e90\u53c2\u8003\uff0cc\uff09\u8bb0\u5f55\u6587\u672c\u3002"
#     }
#   },
#   "m041": {
#     "es": {
#       "label": "N\u00famero de campo",
#       "definition": "Un identificador dado en campo al evento.\u00a0A menudo sirve como un v\u00ednculo entre las anotaciones de campo y el evento."
#     },
#     "zh-Hans": {
#       "label": "\u73b0\u573a\u7f16\u53f7",
#       "definition": "\u73b0\u573a\u4e8b\u4ef6\u6807\u8bc6\u7b26\u3002\u901a\u5e38\u4f5c\u4e3a\u73b0\u573a\u8bb0\u5f55\u548c\u4e8b\u4ef6\u7684\u8054\u7cfb\u3002"
#     }
#   },
#   "m042": {
#     "es": {
#       "label": "Ajuste espacial de footprint",
#       "definition": "La relaci\u00f3n del \u00e1rea de footprint (WKT Footprint) y el \u00e1rea de la verdadera (original, o m\u00e1s espec\u00edfica) representaci\u00f3n espacial de la ubicaci\u00f3n.\u00a0Los valores v\u00e1lidos son 0, mayor que o igual a 1, o indefinido.\u00a0Un valor de 1 es una coincidencia exacta o su"
#     },
#     "zh-Hans": {
#       "label": "\u8db3\u8ff9\u7a7a\u95f4\u62df\u5408",
#       "definition": "\u91c7\u96c6\u5730\u70b9\u8db3\u8ff9\u533a\u9762\u79ef\uff08footprintWKT\uff09\u4e0e\u771f\u6b63\uff08\u6700\u521d\u6216\u6700\u5177\u4f53\uff09\u6240\u7528\u7a7a\u95f4\u9762\u79ef\u7684\u6bd4\u7387\u3002\u5408\u6cd5\u503c\u662f0\uff0c\u6216\u5927\u4e8e\u7b49\u4e8e1\uff0c\u6216\u672a\u5b9a\u4e49\u3002\u503c\u4e3a1\u65f6\u8868\u793a\u4e24\u8005\u7cbe\u786e\u5339\u914d\u6216100%\u91cd\u53e0\u3002\u503c\u4e3a0\u65f6\u8868\u793a\u7ed9\u5b9a\u7684\u8db3\u8ff9\u533a\u4e0d\u5b8c\u5168\u5305\u542b\u6700\u521d\u5730\u57df\u3002\u5982\u679c\u6700\u521d\u5730\u57df\u662f\u4e00\u4e2a\u70b9\u800c\u7ed9\u5b9a\u7684\u5730\u7406\u53c2\u8003\u662f\u53e6\u5916\u4e00\u4e2a\u70b9\uff0c\u90a3\u4e48\u8db3\u8ff9\u7a7a\u95f4\u62df\u5408\u503c\u672a\u5b9a\u4e49\uff08\u5e94\u8be5\u7559\u767d\uff09\u3002\u5982\u679c\u6700\u521d\u5730\u57df\u4e0e\u7ed9\u5b9a\u7684\u5730\u7406\u53c2\u8003\u662f\u540c\u4e00\u4e2a\u70b9\uff0c\u5219\u8db3\u8ff9\u7a7a\u95f4\u62df\u5408\u503c\u4e3a1\u3002"
#     }
#   },
#   "m043": {
#     "es": {
#       "label": "SRS footprint",
#       "definition": "Una representaci\u00f3n Well-Known Text (WKT) del sistema de referencia espacial (SRS) para WKT Footprint de la ubicaci\u00f3n.\u00a0No utilice este elemento para describir el SRS de Latitud Decimal y Longitud Decimal, incluso si es la misma que para WKT Footprint - uti"
#     },
#     "zh-Hans": {
#       "label": "\u8db3\u8ff9\u7a7a\u95f4\u53c2\u8003\u7cfb\u7edf",
#       "definition": "\u91c7\u96c6\u5730\u70b9\u8db3\u8ff9\u533a\u7a7a\u95f4\u53c2\u8003\u7cfb\u7edf\u7684\u516c\u8ba4\u7684\u6587\u672c\u8868\u793a\u3002\u8bf7\u52ff\u4f7f\u7528\u8fd9\u4e2a\u8bcd\u63cf\u8ff0\u5341\u8fdb\u5236\u7ecf\u5ea6\u548c\u7eac\u5ea6\u7684\u7a7a\u95f4\u53c2\u8003\u7cfb\u7edf\uff0c\u5373\u4fbf\u5b83\u4e0e\u8db3\u8ff9\u533a\u516c\u8ba4\u6587\u672c\u8868\u793a\u76f8\u540c\uff0c\u8bf7\u7528\u5927\u5730\u57fa\u51c6\u70b9\u4ee3\u66ff\u3002"
#     }
#   },
#   "m044": {
#     "es": {
#       "label": "WKT footprint",
#       "definition": "Una representaci\u00f3n Well-Known Text (WKT) de la forma (footprint, geometr\u00eda) que define la ubicaci\u00f3n.\u00a0Una ubicaci\u00f3n puede tener una representaci\u00f3n de radio-punto (v\u00e9ase Latitud Decimal) y una representaci\u00f3n de footprint, y pueden diferir entre s\u00ed. "
#     },
#     "zh-Hans": {
#       "label": "\u8db3\u8ff9\u516c\u8ba4\u6587\u672c",
#       "definition": "\u63cf\u8ff0\u5730\u70b9\u5f62\u72b6\uff08\u8db3\u8ff9\uff0c\u51e0\u4f55\uff09\u7684\u516c\u8ba4\u6587\u672c\u8868\u793a\u3002\u4e00\u4e2a\u5730\u70b9\u53ef\u80fd\u540c\u65f6\u7528\u70b9\u534a\u5f84\uff08\u770b\u5341\u8fdb\u5236\u7eac\u5ea6\uff09\u548c\u8db3\u8ff9\u533a\u8868\u793a\uff0c\u800c\u4e24\u8005\u4e4b\u95f4\u5e76\u4e0d\u76f8\u540c\u3002"
#     }
#   },
#   "m045": {
#     "es": {
#       "label": "Formaci\u00f3n",
#       "definition": "El nombre completo de la formaci\u00f3n litoestratigr\u00e1fica de la cual se colect\u00f3 el objeto catalogado."
#     },
#     "zh-Hans": {
#       "label": "\u5730\u5c42",
#       "definition": "\u91c7\u96c6\u7f16\u76ee\u9879\u6240\u5728\u5730\u5c42\u7684\u5b8c\u6574\u540d\u79f0\u3002"
#     }
#   },
#   "m046": {
#     "es": {
#       "label": "G\u00e9nero",
#       "definition": "El nombre cient\u00edfico completo del g\u00e9nero en el que se clasifica el tax\u00f3n. "
#     },
#     "zh-Hans": {
#       "label": "\u5c5e",
#       "definition": "\u5206\u7c7b\u5355\u5143\u6240\u5c5e\u5c5e\u7684\u5b8c\u6574\u5b66\u540d\u3002"
#     }
#   },
#   "m047": {
#     "es": {
#       "label": "Datum geod\u00e9sico",
#       "definition": "El elipsoide, datum geod\u00e9sico, o sistema de referencia espacial (SRS) en el que se basan las coordenadas geogr\u00e1ficas provistas en Latitud Decimal y Longitud Decimal.\u00a0La pr\u00e1ctica recomendada es usar el c\u00f3digo EPSG como un lenguaje controlado para proporcio"
#     },
#     "zh-Hans": {
#       "label": "\u5927\u5730\u57fa\u51c6",
#       "definition": "\u692d\u5706\u4f53\u3001\u5927\u5730\u57fa\u51c6\u70b9\u6216\u7a7a\u95f4\u53c2\u8003\u7cfb\u7edf\u7684\u5730\u7406\u5750\u6807\u4ee5\u5341\u8fdb\u5236\u7ecf\u5ea6\u548c\u7eac\u5ea6\u4e3a\u57fa\u7840\u3002\u5efa\u8bae\u6700\u4f73\u505a\u6cd5\u662f\u5982\u679c\u5df2\u77e5EPSG\u7f16\u7801\uff0c\u4f7f\u7528\u5176\u4f5c\u4e3a\u63a7\u5236\u6027\u8bcd\u6c47\u89c4\u5b9a\u4e00\u4e2a\u7a7a\u95f4\u53c2\u8003\u7cfb\u7edf\u3002\u6216\u8005\u4f7f\u7528\u5df2\u77e5\u7684\u63a7\u5236\u6027\u8bcd\u6c47\u4f5c\u4e3a\u5927\u5730\u57fa\u51c6\u70b9\u7684\u540d\u79f0\u6216\u7f16\u7801\u3002\u6216\u8005\u4f7f\u7528\u5df2\u77e5\u7684\u63a7\u5236\u6027\u8bcd\u6c47\u4f5c\u4e3a\u692d\u5706\u4f53\u7684\u540d\u79f0\u6216\u7f16\u7801\u3002\u5982\u679c\u8fd9\u4e9b\u90fd\u672a\u77e5\uff0c\u5219\u4f7f\u7528\u201c\u672a\u77e5\u201d\u503c\u3002"
#     }
#   },
#   "m048": {
#     "es": {
#       "label": "ID del contexto geol\u00f3gico",
#       "definition": "Un identificador para el conjunto de la informaci\u00f3n asociada con Contexto Geol\u00f3gico (la ubicaci\u00f3n dentro de un contexto geol\u00f3gico, tal como la estratigraf\u00eda).\u00a0Puede ser un identificador \u00fanico global o un identificador espec\u00edfico para el conjunto de datos."
#     },
#     "zh-Hans": {
#       "label": "\u5730\u8d28\u73af\u5883\u7f16\u53f7",
#       "definition": "\u4e0e\u5730\u8d28\u73af\u5883\uff08\u6709\u5730\u8d28\u73af\u5883\u7684\u5730\u70b9\uff0c\u5982\u5730\u5c42\uff09\u6709\u5173\u7684\u4fe1\u606f\u96c6\u6807\u8bc6\u7b26\u3002\u53ef\u80fd\u662f\u4e00\u4e2a\u5168\u5c40\u552f\u4e00\u6807\u8bc6\u7b26\u6216\u7279\u5b9a\u7684\u6570\u636e\u96c6\u6807\u8bc6\u7b26\u3002"
#     }
#   },
#   "m049": {
#     "es": {
#       "label": "Georreferenciado por",
#       "definition": "Una lista (concatenada y separada) de los nombres de las personas, grupos u organizaciones que determinan la georreferencia (representaci\u00f3n espacial) para la ubicaci\u00f3n. "
#     },
#     "zh-Hans": {
#       "label": "\u786e\u5b9a\u5730\u7406\u53c2\u8003\u8005",
#       "definition": "\u786e\u5b9a\u5730\u70b9\u7684\u5730\u7406\u53c2\u8003\uff08\u7a7a\u95f4\u8868\u8ff0\uff09\u7684\u4eba\u540d\u3001\u7fa4\u4f53\u6216\u7ec4\u7ec7\u5217\u8868\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u3002"
#     }
#   },
#   "m050": {
#     "es": {
#       "label": "Fecha de la georreferenciaci\u00f3n",
#       "definition": "La fecha en que fue georreferenciada la ubicaci\u00f3n.\u00a0La pr\u00e1ctica recomendada es utilizar un esquema de codificaci\u00f3n, tal como ISO 8601:2004 (E)."
#     },
#     "zh-Hans": {
#       "label": "\u786e\u5b9a\u5730\u7406\u53c2\u8003\u65e5\u671f",
#       "definition": "\u786e\u5b9a\u5730\u70b9\u7684\u5730\u7406\u53c2\u8003\u7684\u65e5\u671f\u3002\u5efa\u8bae\u6700\u4f73\u505a\u6cd5\u662f\u4f7f\u7528\u4e00\u4e2a\u7f16\u7801\u65b9\u6848\uff0c\u4f8b\u5982ISO 8601:2004(E)\u3002"
#     }
#   },
#   "m051": {
#     "es": {
#       "label": "Protocolo de georreferenciaci\u00f3n",
#       "definition": "Una descripci\u00f3n o referencia a los m\u00e9todos utilizados para determinar el footprint espacial, coordenadas, e incertidumbres. "
#     },
#     "zh-Hans": {
#       "label": "\u5730\u7406\u53c2\u8003\u8349\u6848",
#       "definition": "\u7528\u6765\u786e\u5b9a\u7a7a\u95f4\u8db3\u8ff9\u3001\u5750\u6807\u548c\u4e0d\u786e\u5b9a\u6027\u7684\u65b9\u6cd5\u63cf\u8ff0\u6216\u53c2\u8003\u3002"
#     }
#   },
#   "m052": {
#     "es": {
#       "label": "Comentarios de la georreferenciaci\u00f3n",
#       "definition": "Anotaciones o comentarios acerca de la determinaci\u00f3n de la descripci\u00f3n espacial, suposiciones explicativas adicionales o en oposici\u00f3n a las formalizadas en el m\u00e9todo referido en Protocolo de Georreferenciaci\u00f3n. "
#     },
#     "zh-Hans": {
#       "label": "\u5730\u7406\u53c2\u8003\u5907\u6ce8",
#       "definition": "\u5173\u4e8e\u4e3a\u8865\u5145\u6216\u53cd\u5bf9\u5730\u7406\u53c2\u8003\u8349\u6848\u4e2d\u63d0\u5230\u7684\u90a3\u4e9b\u6b63\u5f0f\u7684\u65b9\u6cd5\u6240\u505a\u7684\u7a7a\u95f4\u63cf\u8ff0\u786e\u5b9a\u3001\u89e3\u91ca\u5047\u8bbe\u7684\u8bb0\u5f55\u6216\u8bc4\u8bba\u3002"
#     }
#   },
#   "m053": {
#     "es": {
#       "label": "Fuentes de la georreferenciaci\u00f3n",
#       "definition": "Una lista (concatenada y separada) de los mapas, gaceteros, u otros recursos utilizados para georreferenciar la ubicaci\u00f3n, que se describe lo suficiente espec\u00edficamente como para permitir que cualquier persona en el futuro utilice los mismos recursos. "
#     },
#     "zh-Hans": {
#       "label": "\u5730\u7406\u53c2\u8003\u6e90",
#       "definition": "\u7528\u4e8e\u5bf9\u5730\u70b9\u8fdb\u884c\u5730\u7406\u53c2\u8003\u6807\u8bc6\u7684\u5730\u56fe\u3001\u5730\u540d\u8868\u6216\u5176\u4ed6\u8d44\u6e90\u5217\u8868\uff0c\u63cf\u8ff0\u5177\u4f53\uff0c\u8db3\u4ee5\u8ba9\u5c06\u6765\u4efb\u4f55\u4eba\u4f7f\u7528\u76f8\u540c\u7684\u8d44\u6e90\u3002"
#     }
#   },
#   "m054": {
#     "es": {
#       "label": "Estado de verificaci\u00f3n de la georreferenciaci\u00f3n",
#       "definition": "Una descripci\u00f3n categ\u00f3rica de la medida en que se ha verificado la georreferencia para representar, de la mejor manera, la descripci\u00f3n espacial.\u00a0La pr\u00e1ctica recomendada es el uso de un lenguaje controlado. "
#     },
#     "zh-Hans": {
#       "label": "\u5730\u7406\u53c2\u8003\u786e\u8ba4\u72b6\u6001",
#       "definition": "\u4e00\u4e2a\u5df2\u8bc1\u5b9e\u4ee3\u8868\u6700\u597d\u7684\u7a7a\u95f4\u63cf\u8ff0\u7684\u5730\u7406\u53c2\u8003\u8303\u56f4\u7684\u5206\u7c7b\u63cf\u8ff0\u3002\u5efa\u8bae\u6700\u4f73\u505a\u6cd5\u662f\u4f7f\u7528\u4e00\u4e2a\u63a7\u5236\u6027\u8bcd\u6c47\u3002"
#     }
#   },
#   "m055": {
#     "es": {
#       "label": "Grupo",
#       "definition": "El nombre completo del grupo litoestratigr\u00e1fico del cual se colect\u00f3 el objeto catalogado. "
#     },
#     "zh-Hans": {
#       "label": "\u7ec4",
#       "definition": "\u91c7\u96c6\u7f16\u76ee\u9879\u6240\u5728\u5730\u5c42\u7ec4\u7684\u5b8c\u6574\u540d\u79f0\u3002"
#     }
#   },
#   "m056": {
#     "es": {
#       "label": "H\u00e1bitat",
#       "definition": "Una categor\u00eda o la descripci\u00f3n del h\u00e1bitat en el que ocurri\u00f3 el evento."
#     },
#     "zh-Hans": {
#       "label": "\u6816\u606f\u5730",
#       "definition": "\u4e8b\u4ef6\u53d1\u751f\u7684\u6816\u606f\u5730\u7684\u7c7b\u522b\u6216\u63cf\u8ff0\u3002"
#     }
#   },
#   "m057": {
#     "es": {
#       "label": "Clasificaci\u00f3n superior",
#       "definition": "Una lista (concatenada y separada) de los nombres de los taxones que terminan en el nivel inmediatamente superior al del tax\u00f3n de referencia en el registro del tax\u00f3n.\u00a0La pr\u00e1ctica recomendada es ordenar la lista comenzando con el m\u00e1s alto nivel y separando"
#     },
#     "zh-Hans": {
#       "label": "\u8f83\u9ad8\u7ea7\u5206\u7c7b",
#       "definition": "\u4f18\u4e8e\u5206\u7c7b\u8bb0\u5f55\u4e2d\u5f15\u7528\u7684\u7c7b\u7fa4\u3001\u5728\u7b49\u7ea7\u6392\u5217\u4e2d\u7d27\u63a5\u5728\u6700\u540e\u7684\u7c7b\u7fa4\u540d\u79f0\u5217\u8868\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u3002\u5efa\u8bae\u6700\u4f73\u505a\u6cd5\u662f\u4ece\u6700\u9ad8\u5206\u7c7b\u7ea7\u522b\u5f00\u59cb\u6392\u5217\uff0c\u7528\u5206\u53f7\uff08\";\"\uff09\u5206\u9694\u6bcf\u4e2a\u7b49\u7ea7\u540d\u79f0\u3002"
#     }
#   },
#   "m058": {
#     "es": {
#       "label": "Geograf\u00eda superior",
#       "definition": "Una lista (concatenada y separada) de los nombres geogr\u00e1ficos menos espec\u00edficos que la informaci\u00f3n capturada en el elemento de Localidad."
#     },
#     "zh-Hans": {
#       "label": "\u8f83\u9ad8\u4e00\u7ea7\u5730\u533a",
#       "definition": "\u4e0e\u5728\u5f53\u5730\u957f\u671f\u83b7\u5f97\u7684\u4fe1\u606f\u76f8\u6bd4\u4e0d\u591f\u5177\u4f53\u7684\u5730\u540d\u5217\u8868\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u3002"
#     }
#   },
#   "m059": {
#     "es": {
#       "label": "ID de la geograf\u00eda superior",
#       "definition": "Un identificador de la regi\u00f3n geogr\u00e1fica de la ubicaci\u00f3n.\u00a0La pr\u00e1ctica recomendada es utilizar un identificador persistente de un lenguaje controlado como el Tesauro Getty de Nombres Geogr\u00e1ficos. "
#     },
#     "zh-Hans": {
#       "label": "\u8f83\u9ad8\u4e00\u7ea7\u5730\u533a\u7f16\u53f7",
#       "definition": "\u5730\u70b9\u6240\u5728\u5730\u7406\u533a\u57df\u7684\u6807\u8bc6\u7b26\u3002\u5efa\u8bae\u6700\u4f73\u505a\u6cd5\u662f\u4f7f\u7528\u4e00\u4e2a\u63a7\u5236\u6027\u8bcd\u6c47\u4e2d\u7684\u6301\u4e45\u6807\u8bc6\u7b26\uff0c\u5982\u5730\u540d\u76d6\u8482\u8bcd\u5e93\u3002"
#     }
#   },
#   "m060": {
#     "es": {
#       "label": "Zona bioestratigr\u00e1fica superior",
#       "definition": "El nombre completo de la zona geol\u00f3gica bioestratigr\u00e1fica m\u00e1s alta posible del horizonte estratigr\u00e1fico donde se recolect\u00f3 el objeto catalogado. "
#     },
#     "zh-Hans": {
#       "label": "\u6700\u9ad8\u751f\u7269\u5730\u5c42\u533a",
#       "definition": "\u91c7\u96c6\u7f16\u76ee\u9879\u6240\u5728\u5730\u5c42\u5730\u5e73\u7ebf\u7684\u53ef\u80fd\u6700\u9ad8\u7684\u5730\u8d28\u751f\u7269\u5730\u5c42\u533a\u7684\u5b8c\u6574\u540d\u79f0\u3002"
#     }
#   },
#   "m061": {
#     "es": {
#       "label": "ID de la identificaci\u00f3n",
#       "definition": "Un identificador para la identificaci\u00f3n (el cuerpo de la informaci\u00f3n asociada con la asignaci\u00f3n de un nombre cient\u00edfico).\u00a0Puede ser un identificador \u00fanico global o un identificador espec\u00edfico para el conjunto de datos. "
#     },
#     "zh-Hans": {
#       "label": "\u9274\u5b9a\u7f16\u53f7",
#       "definition": "\u9274\u5b9a\u6807\u8bc6\u7b26\uff08\u4e0e\u5206\u914d\u5b66\u540d\u76f8\u5173\u7684\u4fe1\u606f\u4e3b\u4f53\uff09\u3002\u53ef\u80fd\u662f\u4e00\u4e2a\u5168\u5c40\u552f\u4e00\u6807\u8bc6\u7b26\u6216\u7279\u5b9a\u7684\u6570\u636e\u96c6\u6807\u8bc6\u7b26\u3002\n"
#     }
#   },
#   "m062": {
#     "es": {
#       "label": "Calificador de la identificaci\u00f3n",
#       "definition": "Una breve frase o t\u00e9rmino est\u00e1ndar (\"cf.\" ,\"aff.\") para expresar las dudas del determinador sobre la identificaci\u00f3n. "
#     },
#     "zh-Hans": {
#       "label": "\u9274\u5b9a\u5408\u683c\u8005",
#       "definition": "\u9274\u5b9a\u8005\u5bf9\u7ed3\u679c\u8868\u793a\u7591\u8651\u7684\u4e00\u4e2a\u7b80\u5355\u77ed\u8bed\u6216\u4e00\u4e2a\u6807\u51c6\u672f\u8bed(\"cf.\", \"aff.\")\u3002"
#     }
#   },
#   "m063": {
#     "es": {
#       "label": "Referencias de la identificaci\u00f3n",
#       "definition": "Una lista (concatenada y separada) de las referencias (publicaci\u00f3n, identificador \u00fanico global, URI) utilizadas en la identificaci\u00f3n. "
#     },
#     "zh-Hans": {
#       "label": "\u9274\u5b9a\u53c2\u8003",
#       "definition": "\u9274\u5b9a\u4e2d\u4f7f\u7528\u7684\u53c2\u8003\uff08\u51fa\u7248\u7269\uff0c\u5168\u7403\u552f\u4e00\u6807\u8bc6\u7b26\uff0c\u7f51\u7ad9\u8d44\u6e90\uff09\u5217\u8868\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u3002"
#     }
#   },
#   "m064": {
#     "es": {
#       "label": "Comentarios de la identificaci\u00f3n",
#       "definition": "Comentarios o anotaciones sobre la identificaci\u00f3n. "
#     },
#     "zh-Hans": {
#       "label": "\u9274\u5b9a\u5907\u6ce8",
#       "definition": "\u6709\u5173\u9274\u5b9a\u7684\u8bc4\u8bba\u6216\u8bb0\u5f55\u3002"
#     }
#   },
#   "m065": {
#     "es": {
#       "label": "Estado de la verificaci\u00f3n de la identificaci\u00f3n",
#       "definition": "Un indicador categ\u00f3rico del alcance de la verificaci\u00f3n de la identificaci\u00f3n taxon\u00f3mica.\u00a0La pr\u00e1ctica recomendada es el uso de un lenguaje controlado."
#     },
#     "zh-Hans": {
#       "label": "\u9274\u5b9a\u786e\u8ba4\u72b6\u6001",
#       "definition": "\u5206\u7c7b\u9274\u5b9a\u7ed3\u679c\u7ecf\u6838\u5b9e\u4e3a\u6b63\u786e\u7684\u786e\u5207\u8303\u56f4\u6307\u6807\u3002\u5efa\u8bae\u6700\u4f73\u505a\u6cd5\u662f\u4f7f\u7528\u4e00\u4e2a\u4f8b\u5982\u7528\u5728HISPID/ABCD\u4e2d\u7684\u63a7\u5236\u6027\u8bcd\u6c47\u3002"
#     }
#   },
#   "m066": {
#     "es": {
#       "label": "Identificado por",
#       "definition": "Una lista (concatenada y separada) de los nombres de las personas, grupos u organizaciones que asignaron el tax\u00f3n al sujeto. "
#     },
#     "zh-Hans": {
#       "label": "\u9274\u5b9a\u8005",
#       "definition": "\u9274\u5b9a\u672a\u77e5\u5bf9\u8c61\u4e3a\u76f8\u5173\u7c7b\u7fa4\u7684\u4eba\u540d\u3001\u7fa4\u4f53\u6216\u7ec4\u7ec7\u5217\u8868\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u3002"
#     }
#   },
#   "m067": {
#     "es": {
#       "label": "Conteo de individuos",
#       "definition": "El n\u00famero de individuos representados presente en el momento del Registro Biol\u00f3gico. "
#     },
#     "zh-Hans": {
#       "label": "\u4e2a\u4f53\u8ba1\u6570",
#       "definition": "\u5f53\u524d\u53d1\u751f\u65f6\u95f4\u53c2\u52a0\u7684\u4e2a\u4f53\u6570\u91cf\u3002"
#     }
#   },
#   "m068": {
#     "es": {
#       "label": "ID del individuo",
#       "definition": "Un identificador para un individuo o grupo de organismos individuales representados en el Registro Biol\u00f3gico.\u00a0Destinado a alojar remuestreo del mismo individuo o grupo con fines de monitoreo.\u00a0Puede ser un identificador \u00fanico global o un identificador espe"
#     },
#     "zh-Hans": {
#       "label": "\u4e2a\u4f53\u7f16\u53f7",
#       "definition": "\u4e8b\u4ef6\u4e2d\u5c55\u73b0\u7684\u4e2a\u4f53\u6807\u8bc6\u7b26\u6216\u751f\u7269\u4e2a\u4f53\u547d\u540d\u7ec4\u3002\u4e3a\u4ee5\u540e\u5bf9\u76f8\u540c\u4e2a\u4f53\u6216\u7ec4\u7fa4\u91cd\u65b0\u91c7\u6837\u8fdb\u884c\u68c0\u6d4b\u63d0\u4f9b\u65b9\u4fbf\u3002\u53ef\u80fd\u662f\u4e00\u4e2a\u5168\u5c40\u552f\u4e00\u6807\u8bc6\u7b26\u6216\u7279\u5b9a\u6570\u636e\u96c6\u6807\u8bc6\u7b26\u3002"
#     }
#   },
#   "m069": {
#     "es": {
#       "label": "Informaci\u00f3n retenida",
#       "definition": "Informaci\u00f3n adicional que existe, pero que no ha sido compartida en el registro dado. "
#     },
#     "zh-Hans": {
#       "label": "\u4fe1\u606f\u9690\u7792",
#       "definition": "\u5b58\u5728\u9644\u52a0\u4fe1\u606f\uff0c\u4f46\u6ca1\u6709\u5728\u7ed9\u5b9a\u8bb0\u5f55\u4e2d\u5171\u4eab\u3002"
#     }
#   },
#   "m070": {
#     "es": {
#       "label": "Ep\u00edteto infraespec\u00edfico",
#       "definition": "El nombre del ep\u00edteto infraespec\u00edfico m\u00e1s bajo o terminal del Nombre Cient\u00edfico, excluyendo cualquier otra denominaci\u00f3n de nivel. "
#     },
#     "zh-Hans": {
#       "label": "\u79cd\u5185\u540d\u79f0",
#       "definition": "\u5b66\u540d\u7684\u6700\u4f4e\u7b49\u7ea7\u6216\u672b\u7aef\u7684\u79cd\u5185\u522b\u540d\uff0c\u4e0d\u5305\u62ec\u4efb\u4f55\u7b49\u7ea7\u540d\u79f0\u3002"
#     }
#   },
#   "m071": {
#     "es": {
#       "label": "C\u00f3digo de la instituci\u00f3n",
#       "definition": "El nombre (o acr\u00f3nimo) en uso por la instituci\u00f3n que tenga la custodia del objeto(s) o informaci\u00f3n mencionada en el registro. "
#     },
#     "zh-Hans": {
#       "label": "\u673a\u6784\u7f16\u7801",
#       "definition": "\u8bb0\u5f55\u4e2d\u63d0\u5230\u6709\u4fdd\u7ba1\u7684\u7269\u54c1\u6216\u8d44\u6599\u7684\u673a\u6784\u6240\u4f7f\u7528\u7684\u540d\u79f0\uff08\u6216\u9996\u5b57\u6bcd\u7f29\u7565\u8bcd\uff09\u3002"
#     }
#   },
#   "m072": {
#     "es": {
#       "label": "ID de la instituci\u00f3n",
#       "definition": "Un identificador de la instituci\u00f3n que custodia el objeto(s) o informaci\u00f3n mencionada en el registro. "
#     },
#     "zh-Hans": {
#       "label": "\u673a\u6784\u7f16\u53f7",
#       "definition": "\u8bb0\u5f55\u4e2d\u63d0\u5230\u6709\u4fdd\u7ba1\u7684\u7269\u54c1\u6216\u8d44\u6599\u7684\u673a\u6784\u7684\u6807\u8bc6\u7b26\u3002"
#     }
#   },
#   "e001": {
#     "es": {
#       "label": "Isla",
#       "definition": "El nombre de la isla en o cerca de la ubicaci\u00f3n. La pr\u00e1ctica recomendada es utilizar un identificador persistente de un lenguaje controlado como el Tesauro Getty de Nombres Geogr\u00e1ficos."
#     },
#     "zh-Hans": {
#       "label": "\u5c9b\u5c7f",
#       "definition": "\u4e8b\u4ef6\u53d1\u751f\u5730\u70b9\u6216\u9644\u8fd1\u7684\u5c9b\u5c7f\u540d\u79f0\u3002\u5efa\u8bae\u6700\u4f73\u505a\u6cd5\u662f\u4f7f\u7528\u4e00\u4e2a\u63a7\u5236\u6027\u8bcd\u6c47\uff0c\u5982\u5730\u540d\u76d6\u8482\u8bcd\u5e93\u3002"
#     }
#   },
#   "e002": {
#     "es": {
#       "label": "Grupo de islas",
#       "definition": "El nombre del grupo de islas de la ubicaci\u00f3n.\u00a0La pr\u00e1ctica recomendada es utilizar un identificador persistente de un lenguaje controlado como el Tesauro Getty de Nombres Geogr\u00e1ficos."
#     },
#     "zh-Hans": {
#       "label": "\u5c9b\u7fa4",
#       "definition": "\u4e8b\u4ef6\u53d1\u751f\u5730\u70b9\u7684\u5c9b\u7fa4\u540d\u79f0\u3002\u5efa\u8bae\u6700\u4f73\u505a\u6cd5\u662f\u4f7f\u7528\u4e00\u4e2a\u63a7\u5236\u6027\u8bcd\u6c47\uff0c\u5982\u5730\u540d\u76d6\u8482\u8bcd\u5e93\u3002"
#     }
#   },
#   "e003": {
#     "es": {
#       "label": "Reino",
#       "definition": "El nombre cient\u00edfico completo del reino en el que se clasifica el tax\u00f3n. "
#     },
#     "zh-Hans": {
#       "label": "\u754c",
#       "definition": "\u5206\u7c7b\u5355\u5143\u6240\u5c5e\u754c\u7684\u5b8c\u6574\u5b66\u540d\u3002"
#     }
#   },
#   "e004": {
#     "es": {
#       "label": "Edad tard\u00eda o estad\u00edo superior",
#       "definition": "El nombre completo de la edad geocronol\u00f3gica m\u00e1s tard\u00eda posible o etapa cronoestratigr\u00e1fica m\u00e1s alta, atribuible al horizonte estratigr\u00e1fico donde se recolect\u00f3 el objeto catalogado. "
#     },
#     "zh-Hans": {
#       "label": "\u6700\u665a\u5730\u8d28\u5e74\u4ee3\u6216\u6700\u9ad8\u5e74\u4ee3\u5730\u5c42",
#       "definition": "\u91c7\u96c6\u7f16\u76ee\u9879\u6240\u5728\u5730\u5c42\u5730\u5e73\u7ebf\u7684\u53ef\u80fd\u6700\u665a\u7684\u5730\u8d28\u5e74\u4ee3\u6216\u6700\u9ad8\u5e74\u4ee3\u5730\u5c42\u7684\u5b8c\u6574\u540d\u79f0\u3002"
#     }
#   },
#   "e005": {
#     "es": {
# ...
#     }
#   },
#   "e022": {
#     "es": {
#       "label": "ID de la medici\u00f3n",
#       "definition": "Un identificador para Medici\u00f3n o hecho (la informaci\u00f3n relativa a las mediciones, hechos, caracter\u00edsticas o aseveraciones).\u00a0Puede ser un identificador \u00fanico global o un identificador espec\u00edfico para el conjunto de datos. "
#     },
#     "zh-Hans": {
#       "label": "\u6d4b\u91cf\u7f16\u53f7",
#       "definition": "\u6d4b\u91cf\u6216\u4e8b\u5b9e\uff08\u5173\u4e8e\u6d4b\u91cf\uff0c\u4e8b\u5b9e\uff0c\u7279\u5f81\u6216\u63a8\u65ad\u7684\u4fe1\u606f\uff09\u7684\u6807\u8bc6\u7b26\uff0c\u53ef\u80fd\u662f\u4e00\u4e2a\u5168\u5c40\u552f\u4e00\u6807\u8bc6\u7b26\u6216\u8005\u4e00\u4e2a\u6570\u636e\u96c6\u7279\u6709\u7684\u6807\u8bc6\u7b26\u3002"
#     }
#   },
#   "e023": {
#     "es": {
#       "label": "M\u00e9todo de medici\u00f3n",
#       "definition": "Una descripci\u00f3n o referencia (publicaci\u00f3n, URI) del m\u00e9todo o protocolo utilizado para determinar la medici\u00f3n, hecho, caracter\u00edstica o aseveraci\u00f3n. "
#     },
#     "zh-Hans": {
#       "label": "\u6d4b\u91cf\u65b9\u6cd5",
#       "definition": "\u7528\u6765\u786e\u5b9a\u6d4b\u91cf\uff0c\u4e8b\u5b9e\uff0c\u7279\u5f81\u6216\u8005\u63a8\u65ad\u7684\u65b9\u6cd5\u6216\u8349\u6848\u7684\u63cf\u8ff0\u6216\u8005\u53c2\u8003\u3002"
#     }
#   },
#   "e024": {
#     "es": {
#       "label": "Comentarios de la medici\u00f3n",
#       "definition": "Comentarios o anotaciones que acompa\u00f1an a Medici\u00f3n o hecho. "
#     },
#     "zh-Hans": {
#       "label": "\u6d4b\u91cf\u5907\u6ce8",
#       "definition": "\u9644\u5728\u201c\u6d4b\u91cf\u6216\u4e8b\u5b9e\u201d\u4e0a\u7684\u8bc4\u8bba\u548c\u6ce8\u91ca\u3002"
#     }
#   },
#   "e025": {
#     "es": {
#       "label": "Tipo de medici\u00f3n",
#       "definition": "La naturaleza de la medici\u00f3n, hecho, caracter\u00edstica o aseveraci\u00f3n.\u00a0La pr\u00e1ctica recomendada es el uso de un lenguaje controlado. "
#     },
#     "zh-Hans": {
#       "label": "\u6d4b\u91cf\u7c7b\u578b",
#       "definition": "\u6d4b\u91cf\uff0c\u4e8b\u5b9e\uff0c\u7279\u5f81\uff0c\u548c\u63a8\u65ad\u7684\u6027\u8d28\u3002\u6700\u597d\u7684\u505a\u6cd5\u662f\u4f7f\u7528\u4e00\u4e2a\u63a7\u5236\u6027\u8bcd\u6c47\u3002"
#     }
#   },
#   "e026": {
#     "es": {
#       "label": "Unidad de medici\u00f3n",
#       "definition": "Las unidades asociadas con Valor de la Medici\u00f3n.\u00a0La pr\u00e1ctica recomendada es utilizar el Sistema Internacional de Unidades (SI). "
#     },
#     "zh-Hans": {
#       "label": "\u6d4b\u91cf\u5355\u4f4d",
#       "definition": "\u4e0e\u6d4b\u91cf\u503c\u76f8\u5173\u7684\u5355\u4f4d\u6700\u597d\u91c7\u7528\u56fd\u9645\u5355\u4f4d\u7cfb\u7edf\uff08SI\uff09\u3002"
#     }
#   },
#   "e027": {
#     "es": {
#       "label": "Valor de la medici\u00f3n",
#       "definition": "El valor de la medici\u00f3n, hecho, caracter\u00edstica o aseveraci\u00f3n. "
#     },
#     "zh-Hans": {
#       "label": "\u6d4b\u91cf\u503c",
#       "definition": "\u6d4b\u91cf\uff0c\u4e8b\u5b9e\uff0c\u7279\u5f81\uff0c\u548c\u63a8\u65ad\u7684\u503c\u3002"
#     }
#   },
#   "e028": {
#     "es": {
#       "label": "Miembro",
#       "definition": "El nombre completo del miembro litoestratigr\u00e1fico del cual se colect\u00f3 el elemento catalogado. "
#     },
#     "zh-Hans": {
#       "label": "\u6210\u5458",
#       "definition": "\u91c7\u96c6\u7f16\u76ee\u9879\u6240\u5728\u5730\u5c42\u6210\u5458\u7684\u5b8c\u6574\u540d\u79f0\u3002"
#     }
#   },
#   "e029": {
#     "es": {
#       "label": "Profundidad m\u00ednima en metros",
#       "definition": "La menor profundidad de un rango de profundidad por debajo de la superficie local, en metros. "
#     },
#     "zh-Hans": {
#       "label": "\u6700\u5c0f\u6df1\u5ea6\uff08\u7c73\uff09",
#       "definition": "\u5730\u8868\u4ee5\u4e0b\u8f83\u4f4e\u7684\u6df1\u5ea6\uff0c\u4ee5\u201c\u7c73\u201d\u4e3a\u5355\u4f4d\u3002"
#     }
#   },
#   "e030": {
#     "es": {
#       "label": "M\u00ednima distancia de la superficie en metros",
#       "definition": "La menor distancia en un rango de distancia desde una superficie de referencia en direcci\u00f3n vertical, en metros.\u00a0Utilice valores positivos para las ubicaciones por encima de la superficie, valores negativos para ubicaciones por debajo.\u00a0Si las medidas de p"
#     },
#     "zh-Hans": {
#       "label": "\u53c2\u8003\u8868\u9762\u4ee5\u4e0a\u7684\u6700\u5c0f\u8ddd\u79bb\uff08\u7c73\uff09",
#       "definition": "\u5728\u5782\u76f4\u65b9\u5411\uff0c\u8ddd\u79bb\u53c2\u8003\u8868\u9762\u8f83\u5c0f\u7684\u8ddd\u79bb\u8303\u56f4\u5185\u7684\u8ddd\u79bb\uff0c\u4ee5\u201c\u7c73\u201d\u4e3a\u5355\u4f4d\u3002\u4f7f\u7528\u6b63\u503c\u4ee3\u8868\u8868\u9762\u4ee5\u4e0a\u7684\u4f4d\u7f6e\uff0c\u8d1f\u503c\u4ee3\u8868\u8868\u9762\u4ee5\u4e0b\u7684\u4f4d\u7f6e\u3002\u5982\u679c\u5df2\u7ecf\u7ed9\u51fa\u6df1\u5ea6\u7684\u6d4b\u91cf\u503c\uff0c\u90a3\u4e48\u53c2\u8003\u8868\u9762\u7684\u4f4d\u7f6e\u7531\u6df1\u5ea6\u786e\u5b9a\uff0c\u5426\u5219\u53c2\u8003\u8868\u9762\u7684\u4f4d\u7f6e\u7531\u6d77\u62d4\u786e\u5b9a\u3002"
#     }
#   },
#   "e031": {
#     "es": {
#       "label": "Elevaci\u00f3n m\u00ednima en metros",
#       "definition": "El l\u00edmite inferior del rango de elevaci\u00f3n (altitud, generalmente por encima del nivel del mar), en metros. "
#     },
#     "zh-Hans": {
#       "label": "\u6700\u4f4e\u6d77\u62d4\uff08\u7c73\uff09",
#       "definition": "\u6d77\u62d4\uff08\u6d77\u5e73\u9762\u4ee5\u4e0a\u7684\u9ad8\u5ea6\uff09\u8303\u56f4\u7684\u4e0b\u9650\uff0c\u4ee5\u201c\u7c73\u201d\u4e3a\u5355\u4f4d\u3002"
#     }
#   },
#   "e032": {
#     "es": {
#       "label": "Mes",
#       "definition": "El mes ordinal en que ocurri\u00f3 el evento. "
#     },
#     "zh-Hans": {
#       "label": "\u6708\u4efd",
#       "definition": "\u4e8b\u4ef6\u53d1\u751f\u7684\u6708\u4efd\u5e8f\u53f7\u3002"
#     }
#   },
#   "e033": {
#     "es": {
#       "label": "Municipio",
#       "definition": "El nombre completo, sin abreviar de la siguiente regi\u00f3n administrativa de menor jerarqu\u00eda que condado (ciudad, municipio, etc.) en el que la ubicaci\u00f3n se produce.\u00a0No utilice este elemento para el nombre de un lugar cercano que no contiene la ubicaci\u00f3n rea"
#     },
#     "zh-Hans": {
#       "label": "\u81ea\u6cbb\u5e02",
#       "definition": "\u4e8b\u4ef6\u53d1\u751f\u7684\u5b8c\u6574\u3001\u672a\u7f29\u5199\u7684\u5730\u70b9\u540d\u79f0\uff0c\u6bd4\u53bf\uff08\u5e02\u3001\u81ea\u6cbb\u533a\u7b49\uff09\u66f4\u5c0f\u7684\u884c\u653f\u533a\u57df\u3002\u5bf9\u4e8e\u9644\u8fd1\u4e0d\u5305\u542b\u5b9e\u9645\u5730\u70b9\u7684\u5df2\u547d\u540d\u5730\u533a\u4e0d\u8981\u4f7f\u7528\u8fd9\u4e2a\u8bcd\u8bed\u3002"
#     }
#   },
#   "e034": {
#     "es": {
#       "label": "Nombre de acuerdo con",
#       "definition": "La referencia a la fuente en la que est\u00e1 definida o impl\u00edcita la circunscripci\u00f3n conceptual del tax\u00f3n - tradicionalmente representado por el Lat\u00edn \"sensu\" o \"sec.\"\u00a0(de secundum, que significa \"seg\u00fan\").\u00a0Para los taxones que resultan de las identificaciones"
#     },
#     "zh-Hans": {
#       "label": "\u540d\u79f0\u4f9d\u636e",
#       "definition": "\u53c2\u8003\u6e90\u4e2d\u5b9a\u4e49\u6216\u6697\u793a\u4e86\u5177\u4f53\u7c7b\u7fa4\u7684\u6982\u5ff5\u754c\u9650\uff0c\u7167\u60ef\u4f8b\u8868\u793a\u4e3a\u62c9\u4e01\u8bed\"sensu\"\u6216\"sec.\"\uff08\u6309\u7167\u4f9d\u636e\uff0c\u610f\u601d\u662f\u201c\u6839\u636e\u201d\uff09\u3002\u5bf9\u4e8e\u4e00\u4e2a\u9274\u5b9a\u7ed3\u679c\u7684\u7c7b\u7fa4\uff0c\u5e94\u7ed9\u51fa\u53c2\u8003\u5173\u952e\u8bcd\uff0c\u4e13\u9898\u8bba\u6587\uff0c\u4e13\u5bb6\u53ca\u5176\u4ed6\u8d44\u6e90\u3002"
#     }
#   },
#   "e035": {
#     "es": {
#       "label": "ID nombre de acuerdo con",
#       "definition": "Un identificador de la fuente en la que est\u00e1 definida o impl\u00edcita la circunscripci\u00f3n conceptual del tax\u00f3n espec\u00edfico.\u00a0Ver Nombre de acuerdo con. Ejemplo: \"doi:10.1016/S0269-915X(97)80026-2\"."
#     },
#     "zh-Hans": {
#       "label": "\u540d\u79f0\u4f9d\u636e\u7f16\u53f7",
#       "definition": "\u53c2\u8003\u6e90\u4e2d\u5b9a\u4e49\u6216\u6697\u793a\u5177\u4f53\u7c7b\u7fa4\u6982\u5ff5\u754c\u9650\u7684\u6807\u8bc6\u7b26\uff0c\u53c2\u89c1\u201c\u540d\u79f0\u4f9d\u636e\u201d\u3002"
#     }
#   },
#   "e036": {
#     "es": {
#       "label": "Nombre publicado en  ",
#       "definition": "Una referencia para la publicaci\u00f3n en que se estableci\u00f3 originalmente Nombre Cient\u00edfico bajo las reglas del C\u00f3digo Nomenclatural asociado. "
#     },
#     "zh-Hans": {
#       "label": "\u53d1\u5e03\u540d\u79f0",
#       "definition": "\u5728\u76f8\u5173\u7684\u547d\u540d\u89c4\u5219\u4e0b\uff0c\u786e\u5b9a\u6700\u521d\u5b66\u540d\u7684\u51fa\u7248\u53c2\u8003\u7269\u3002"
#     }
#   },
#   "e037": {
#     "es": {
#       "label": "ID del nombre publicado en",
#       "definition": "Un identificador de la publicaci\u00f3n en que se estableci\u00f3 originalmente Nombre cient\u00edfico bajo las reglas del C\u00f3digo nomenclatural asociado. "
#     },
#     "zh-Hans": {
#       "label": "\u540d\u79f0\u53d1\u5e03\u7f16\u53f7",
#       "definition": "\u5728\u76f8\u5173\u7684\u547d\u540d\u89c4\u5219\u4e0b\uff0c\u786e\u5b9a\u6700\u521d\u5b66\u540d\u7684\u51fa\u7248\u7269\u6807\u8bc6\u7b26\u3002"
#     }
#   },
#   "e038": {
#     "es": {
#       "label": "Nombre publicado en a\u00f1o",
#       "definition": "El a\u00f1o de cuatro d\u00edgitos en el que se public\u00f3 el Nombre cient\u00edfico. "
#     },
#     "zh-Hans": {
#       "label": "\u540d\u79f0\u53d1\u5e03\u5e74\u4efd",
#       "definition": "\u5b66\u540d\u53d1\u5e03\u7684\u56db\u4f4d\u516c\u5386\u5e74\u4efd\u3002"
#     }
#   },
#   "e039": {
#     "es": {
#       "label": "C\u00f3digo nomenclatural",
#       "definition": "El c\u00f3digo de nomenclatura (o c\u00f3digos en el caso de un nombre ambireinal) en virtud del cual se construye el Nombre Cient\u00edfico.\u00a0La pr\u00e1ctica recomendada es el uso de un lenguaje controlado. "
#     },
#     "zh-Hans": {
#       "label": "\u547d\u540d\u51c6\u5219",
#       "definition": "\u521b\u5efa\u5b66\u540d\u6240\u9075\u5faa\u7684\u547d\u540d\u51c6\u5219\u3002\u5efa\u8bae\u6700\u4f73\u505a\u6cd5\u662f\u4f7f\u7528\u4e00\u4e2a\u63a7\u5236\u6027\u8bcd\u6c47\u3002"
#     }
#   },
#   "e040": {
#     "es": {
#       "label": "Estado nomenclatural",
#       "definition": "El estatus relacionado con la publicaci\u00f3n original del nombre y su conformidad con las normas pertinentes de nomenclatura.\u00a0Se basa esencialmente en un algoritmo de acuerdo a las reglas de negociaci\u00f3n del c\u00f3digo.\u00a0No requiere opini\u00f3n taxon\u00f3mica. "
#     },
#     "zh-Hans": {
#       "label": "\u547d\u540d\u72b6\u6001",
#       "definition": "\u4e0e\u540d\u79f0\u7684\u6700\u521d\u51fa\u7248\u7269\u76f8\u5173\u7684\u72b6\u6001\u53ca\u4e0e\u547d\u540d\u76f8\u5173\u89c4\u5219\u7684\u4e00\u81f4\u6027\u3002\u672c\u8d28\u4e0a\u57fa\u4e8e\u4e00\u4e2a\u6839\u636e\u4e1a\u52a1\u89c4\u5219\u4ee3\u7801\u7684\u7b97\u6cd5\uff0c\u4e0d\u9700\u8981\u5206\u7c7b\u7684\u610f\u89c1\u3002"
#     }
#   },
#   "e041": {
#     "es": {
#       "label": "ID del registro biol\u00f3gico",
#       "definition": "Un identificador del Registro biol\u00f3gico (a cambio de un registro digital particular del Registro biol\u00f3gico).\u00a0En ausencia de un identificador \u00fanico global persistente, se debe construir uno a partir de una combinaci\u00f3n de identificadores en el registro de m"
#     },
#     "zh-Hans": {
#       "label": "\u4e8b\u4ef6\u7f16\u53f7",
#       "definition": "\u4e00\u4e2a\u4e8b\u4ef6\u7684\u6807\u8bc6\u7b26\uff08\u5e76\u975e\u4e00\u4e2a\u4e8b\u4ef6\u7684\u5177\u4f53\u6570\u5b57\u8bb0\u5f55\uff09\u3002\u5728\u7f3a\u4e4f\u5168\u5c40\u552f\u4e00\u6807\u8bc6\u7b26\u7684\u60c5\u51b5\u4e0b\uff0c\u4ece\u6700\u63a5\u8fd1\u5168\u5c40\u552f\u4e00\u4e8b\u4ef6\u7f16\u53f7\u7684\u8bb0\u5f55\u4e2d\u6784\u5efa\u4e00\u4e2a\u6807\u8bc6\u7b26\u3002"
#     }
#   },
#   "e042": {
#     "es": {
#       "label": "Comentarios del registro biol\u00f3gico",
#       "definition": "Comentarios o anotaciones sobre el Registro Biol\u00f3gico. "
#     },
#     "zh-Hans": {
#       "label": "\u4e8b\u4ef6\u5907\u6ce8",
#       "definition": "\u5173\u4e8e\u8fd9\u4e2a\u4e8b\u4ef6\u7684\u8bc4\u8bba\u548c\u6ce8\u91ca\u3002"
#     }
#   },
#   "e043": {
#     "es": {
#       "label": "Estado del registro biol\u00f3gico",
#       "definition": "Una declaraci\u00f3n sobre la presencia o ausencia de un tax\u00f3n en una ubicaci\u00f3n.\u00a0La pr\u00e1ctica recomendada es el uso de un lenguaje controlado. "
#     },
#     "zh-Hans": {
#       "label": "\u4e8b\u4ef6\u72b6\u6001",
#       "definition": "\u5173\u4e8e\u4e00\u4e2a\u7c7b\u7fa4\u5728\u4e00\u4e2a\u5730\u70b9\u5b58\u5728\u6216\u8005\u4e0d\u5b58\u5728\u7684\u58f0\u660e\u3002\u5efa\u8bae\u6700\u4f73\u505a\u6cd5\u662f\u4f7f\u7528\u4e00\u4e2a\u63a7\u5236\u6027\u8bcd\u6c47\u3002"
#     }
#   },
#   "e044": {
#     "es": {
#       "label": "Orden",
#       "definition": "El nombre cient\u00edfico completo del orden en el que se clasifica el tax\u00f3n. "
#     },
#     "zh-Hans": {
#       "label": "\u76ee",
#       "definition": "\u5206\u7c7b\u5355\u5143\u6240\u5c5e\u76ee\u7684\u5b8c\u6574\u5b66\u540d\u3002"
#     }
#   },
#   "e045": {
#     "es": {
#       "label": "Uso del nombre original",
#       "definition": "El nombre del tax\u00f3n, con informaci\u00f3n de autor\u00eda y fecha si se conoce, tal como apareci\u00f3 originalmente cuando se estableci\u00f3 por primera vez bajo las reglas del C\u00f3digo Nomenclatural asociadas.\u00a0El basi\u00f3nimo (bot\u00e1nica) o basi\u00f3nimo (bacteriolog\u00eda) de Nombre Ci"
#     },
#     "zh-Hans": {
#       "label": "\u6700\u521d\u4f7f\u7528\u540d\u79f0",
#       "definition": "\u5728\u76f8\u5173\u7684\u547d\u540d\u89c4\u5219\u4e0b\u7b2c\u4e00\u6b21\u88ab\u5efa\u7acb\u7684\u6700\u521d\u51fa\u73b0\u7684\u7c7b\u7fa4\u540d\u79f0\uff0c\u5982\u679c\u77e5\u9053\u7684\u8bdd\uff0c\u9644\u4f5c\u8005\u548c\u65e5\u671f\u4fe1\u606f\u3002\u5b66\u540d\u7684\u5f02\u540d\u6216\u57fa\u540d\uff0c\u6216\u7528\u6765\u66ff\u6362\u540d\u79f0\u7684\u540c\u97f3\u8bcd\u3002"
#     }
#   },
#   "e046": {
#     "es": {
#       "label": "ID del uso del nombre original",
#       "definition": "Un identificador para el uso del nombre (significado documentado del nombre de acuerdo a una fuente) en el que se estableci\u00f3 originalmente, el elemento terminal de Nombre Cient\u00edfico bajo las reglas del C\u00f3digo Nomenclatural asociado. "
#     },
#     "zh-Hans": {
#       "label": "\u6700\u521d\u4f7f\u7528\u540d\u79f0\u7f16\u53f7",
#       "definition": "\u5b66\u540d\u5728\u76f8\u5173\u547d\u540d\u89c4\u5219\u4e0b\u6700\u521d\u5efa\u7acb\u65f6\uff0c\u5b66\u540d\u7684\u672b\u7aef\u7ec4\u6210\u4e0a\u7684\u540d\u79f0\u4f7f\u7528\u6807\u8bc6\u7b26\u3002"
#     }
#   },
#   "e047": {
#     "es": {
#       "label": "Otros n\u00fameros de cat\u00e1logo",
#       "definition": "Una lista (concatenada y separada) de n\u00fameros de cat\u00e1logos anteriores o alternativos, calificados, u otros identificadores de uso humano para el mismo Registro Biol\u00f3gico, ya sea en el actual o cualquier otro conjunto de datos o colecci\u00f3n. "
#     },
#     "zh-Hans": {
#       "label": "\u5176\u5b83\u76ee\u5f55\u7f16\u53f7",
#       "definition": "\u65e0\u8bba\u5728\u5f53\u524d\u6216\u5176\u4ed6\u4efb\u4f55\u6570\u636e\u96c6\uff0c\u540c\u4e00\u4e8b\u4ef6\u4e2d\u4ee5\u524d\u6216\u5907\u7528\u7684\u5b8c\u5168\u5408\u683c\u7684\u76ee\u5f55\u53f7\u6216\u5176\u4ed6\u4eba\u4f7f\u7528\u7684\u6807\u8bc6\u7b26\u5217\u8868\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u3002"
#     }
#   },
#   "e048": {
#     "es": {
#       "label": "C\u00f3digo de la instituci\u00f3n propietaria",
#       "definition": "El nombre (o acr\u00f3nimo) en uso por la instituci\u00f3n que tiene la propiedad del objeto(s) o informaci\u00f3n referida en el registro. "
#     },
#     "zh-Hans": {
#       "label": "\u6240\u6709\u8005\u673a\u6784\u4ee3\u7801",
#       "definition": "\u8bb0\u5f55\u4e2d\u663e\u793a\u7684\u5bf9\u7269\u54c1\u6216\u4fe1\u606f\u4eab\u6709\u6240\u6709\u6743\u7684\u673a\u6784\u540d\u79f0\uff08\u6216\u7f29\u5199\uff09\u3002"
#     }
#   }
# }

# %%
term_info = []
term_dict = {}
frame = pd.read_csv(github_base_url + database_name + '/' + database_name + '.csv', na_filter=False)
for index,row in frame.iterrows():
    term_dict = {}
    term_dict['localname'] = row['term_localName']
    term_dict['iri'] = namespace_iri + row['term_localName']
    term_dict['label'] = []
    term_dict['label'].append({'language': 'en', 'value': row['label']})
    for language in languages:
        term_dict['label'].append({'language': language, 'value': translations_dictionary[row['term_localName']][language]['label']})
    term_dict['definition'] = []
    term_dict['definition'].append({'language': 'en', 'value': row['definition']})
    for language in languages:
        term_dict['definition'].append({'language': language, 'value': translations_dictionary[row['term_localName']][language]['definition']})
    term_dict['cv_string'] = row['controlled_value_string']
    if row['skos_inScheme'] != '':
        term_dict['scheme'] = namespace_iri + row['skos_inScheme']
    else:
        term_dict['scheme'] = ''
    term_dict['type'] = row['type']
    if has_broader:
        if row['skos_broader'] != '':
            term_dict['broader'] = namespace_iri + row['skos_broader']
        else:
            term_dict['broader'] = ''
    if has_exactMatch:
        if row['skos_exactMatch'] != '':
            term_dict['match'] = namespace_iri + row['skos_exactMatch']
        else:
            term_dict['match'] = ''
    term_dict['value'] = row['controlled_value_string']
    term_info.append(term_dict)
print(json.dumps(term_info, indent = 2))
# Out:
# [
#   {
#     "localname": "m",
#     "iri": "http://rs.tdwg.org/format/values/m",
#     "label": [
#       {
#         "language": "en",
#         "value": "media types and physical media concept scheme"
#       },
#       {
#         "language": "es",
#         "value": "Nombre aceptado en uso"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u516c\u8ba4\u4f7f\u7528\u540d\u79f0"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "concept scheme for IANA media types and various physical media items"
#       },
#       {
#         "language": "es",
#         "value": "El nombre completo, con autor\u00eda e informaci\u00f3n de fecha si se conoce, del tax\u00f3n actualmente v\u00e1lido (zool\u00f3gico) o aceptado (bot\u00e1nico). "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u76ee\u524d\u6709\u6548\uff08\u52a8\u7269\u5b66\uff09\u7684\u6216\u516c\u8ba4\uff08\u690d\u7269\u5b66\uff09\u7684\u5206\u7c7b\u5355\u5143\u5168\u79f0\uff0c\u5982\u5df2\u77e5\u6765\u6e90\u548c\u65e5\u671f\u4fe1\u606f\u5219\u9700\u6ce8\u660e\u3002"
#       }
#     ],
#     "cv_string": "",
#     "scheme": "",
#     "type": "http://www.w3.org/2004/02/skos/core#ConceptScheme",
#     "broader": "",
#     "match": "",
#     "value": ""
#   },
#   {
#     "localname": "e",
#     "iri": "http://rs.tdwg.org/format/values/e",
#     "label": [
#       {
#         "language": "en",
#         "value": "file extensions concept scheme"
#       },
#       {
#         "language": "es",
#         "value": "Nombre aceptado en uso - ID"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u516c\u8ba4\u4f7f\u7528\u540d\u79f0\u7f16\u53f7"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "concept scheme based on conventional file extensions for media types"
#       },
#       {
#         "language": "es",
#         "value": "Un identificador para el nombre en uso (significado del nombre, documentado de acuerdo con alguna fuente) del tax\u00f3n actualmente v\u00e1lido (zool\u00f3gico) o aceptado (bot\u00e1nico).   "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u76ee\u524d\u6709\u6548\uff08\u52a8\u7269\u5b66\uff09\u7684\u6216\u516c\u8ba4\uff08\u690d\u7269\u5b66\uff09\u7684\u5206\u7c7b\u5355\u5143\u7684\u540d\u79f0\u4f7f\u7528\uff08\u6839\u636e\u6765\u6e90\u6240\u53d6\u540d\u79f0\u7684\u5b58\u6863\u8bb0\u5f55\u65b9\u6cd5\uff09\u6807\u8bc6\u7b26\u3002"
#       }
#     ],
#     "cv_string": "",
#     "scheme": "",
#     "type": "http://www.w3.org/2004/02/skos/core#ConceptScheme",
#     "broader": "",
#     "match": "",
#     "value": ""
#   },
#   {
#     "localname": "m001",
#     "iri": "http://rs.tdwg.org/format/values/m001",
#     "label": [
#       {
#         "language": "en",
#         "value": "application"
#       },
#       {
#         "language": "es",
#         "value": "Medios asociados"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u76f8\u5173\u5a92\u4ecb"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media type for application"
#       },
#       {
#         "language": "es",
#         "value": "Una lista (concatenada o delimitada) de identificadores (publicaci\u00f3n, identificador \u00fanico global, URI) de los medios asociados con el registro biol\u00f3gico."
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u53d1\u73b0\u5a92\u4ecb\u7684\uff08\u53d1\u8868\u3001\u5168\u5c40\u552f\u4e00\u6807\u8bc6\u7b26\u3001\u7edf\u4e00\u8d44\u6e90\u6807\u8bc6\u7b26\u7b49\uff09\u6807\u8bc6\u7b26\u4e4b\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u5217\u8868\u3002"
#       }
#     ],
#     "cv_string": "application",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "",
#     "match": "",
#     "value": "application"
#   },
#   {
#     "localname": "m002",
#     "iri": "http://rs.tdwg.org/format/values/m002",
#     "label": [
#       {
#         "language": "en",
#         "value": "audio"
#       },
#       {
#         "language": "es",
#         "value": "Registros biol\u00f3gicos asociados"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u76f8\u5173\u4e8b\u4ef6"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media type for audio"
#       },
#       {
#         "language": "es",
#         "value": "Una lista (concatenada y separada) de los identificadores de otros registros biol\u00f3gicos y su relaci\u00f3n con este Registro Biol\u00f3gico. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5176\u4ed6\u53d1\u73b0\u8bb0\u5f55\u53ca\u5176\u4e0e\u53d1\u73b0\u4fe1\u606f\u76f8\u5173\u8054\u7684\u6807\u8bc6\u7b26\u4e4b\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u5217\u8868\u3002"
#       }
#     ],
#     "cv_string": "audio",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "",
#     "match": "",
#     "value": "audio"
#   },
#   {
#     "localname": "m003",
#     "iri": "http://rs.tdwg.org/format/values/m003",
#     "label": [
#       {
#         "language": "en",
#         "value": "image"
#       },
#       {
#         "language": "es",
#         "value": "Referencias asociadas"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u76f8\u5173\u53c2\u8003"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media type for image"
#       },
#       {
#         "language": "es",
#         "value": "Una lista (concatenada y separada) de los identificadores (publicaci\u00f3n, referencia bibliogr\u00e1fica, identificador \u00fanico global, URI) de la literatura asociada con el Registro Biol\u00f3gico. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u4e0e\u53d1\u73b0\u60c5\u51b5\u76f8\u5173\u4e4b\u6587\u732e\u7684\uff08\u53d1\u8868\u3001\u53c2\u8003\u6587\u732e\u3001\u5168\u5c40\u552f\u4e00\u6807\u8bc6\u7b26\u3001\u7edf\u4e00\u8d44\u6e90\u6807\u8bc6\u7b26\u7b49\uff09\u6807\u8bc6\u7b26\u4e4b\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u5217\u8868\u3002"
#       }
#     ],
#     "cv_string": "image",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "",
#     "match": "",
#     "value": "image"
#   },
#   {
#     "localname": "m004",
#     "iri": "http://rs.tdwg.org/format/values/m004",
#     "label": [
#       {
#         "language": "en",
#         "value": "model"
#       },
#       {
#         "language": "es",
#         "value": "Secuencias asociadas"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u76f8\u5173\u5e8f\u5217"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media type for model"
#       },
#       {
#         "language": "es",
#         "value": "Una lista (concatenada y separada) de los identificadores (publicaci\u00f3n, identificador \u00fanico global, URI) de la informaci\u00f3n de la secuencia gen\u00e9tica asociada con el Registro Biol\u00f3gico. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u4e0e\u53d1\u73b0\u60c5\u51b5\u76f8\u5173\u4e4b\u57fa\u56e0\u5e8f\u5217\u4fe1\u606f\u7684\uff08\u53d1\u8868\u3001\u5168\u5c40\u552f\u4e00\u6807\u8bc6\u7b26\u3001\u7edf\u4e00\u8d44\u6e90\u6807\u8bc6\u7b26\u7b49\uff09\u6807\u8bc6\u7b26\u4e4b\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u5217\u8868\u3002"
#       }
#     ],
#     "cv_string": "model",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "",
#     "match": "",
#     "value": "model"
#   },
#   {
#     "localname": "m005",
#     "iri": "http://rs.tdwg.org/format/values/m005",
#     "label": [
#       {
#         "language": "en",
#         "value": "text"
#       },
#       {
#         "language": "es",
#         "value": "Taxones asociados"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u76f8\u5173\u7c7b\u7fa4"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media type for text"
#       },
#       {
#         "language": "es",
#         "value": "Una lista (concatenada y separada) de los identificadores o nombres de taxones y su asociaci\u00f3n con el Registro Biol\u00f3gico."
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u4e0e\u53d1\u73b0\u60c5\u51b5\u76f8\u5173\u7684\u6807\u8bc6\u7b26\u6216\u5206\u7c7b\u5355\u5143\u540d\u79f0\u4e4b\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u5217\u8868\u3002"
#       }
#     ],
#     "cv_string": "text",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "",
#     "match": "",
#     "value": "text"
#   },
#   {
#     "localname": "m006",
#     "iri": "http://rs.tdwg.org/format/values/m006",
#     "label": [
#       {
#         "language": "en",
#         "value": "video"
#       },
#       {
#         "language": "es",
#         "value": "Base del registro"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u8bb0\u5f55\u57fa\u7840"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media type for video"
#       },
#       {
#         "language": "es",
#         "value": "La naturaleza espec\u00edfica del registro de datos - un subtipo de Tipo.\u00a0La pr\u00e1ctica recomendada es el uso de lenguaje controlado como el vocabulario controlado para Tipo de Darwin Core (http://rs.tdwg.org/dwc/terms/type-vocabulary/index.htm). "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u6570\u636e\u8bb0\u5f55\u7684\u7279\u6709\u5c5e\u6027\u2014\u2014dcterms:type\u7684\u5b50\u7c7b\u3002\u5efa\u8bae\u6700\u597d\u4f7f\u7528\u63a7\u5236\u6027\u8bcd\u6c47\uff0c\u5982\u8fbe\u5c14\u6587\u6838\u5fc3\u7c7b\u578b\u8bcd\u6c47\uff08http://rs.tdwg.org/dwc/terms/type-vocabulary/index.htm\uff09\u3002"
#       }
#     ],
#     "cv_string": "video",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "",
#     "match": "",
#     "value": "video"
#   },
#   {
#     "localname": "m007",
#     "iri": "http://rs.tdwg.org/format/values/m007",
#     "label": [
#       {
#         "language": "en",
#         "value": "PNG"
#       },
#       {
#         "language": "es",
#         "value": "Capa"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5ca9\u5e8a"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for portable network graphics images"
#       },
#       {
#         "language": "es",
#         "value": "El nombre completo de la capa litoestratigr\u00e1fica de la cual se colect\u00f3 el elemento catalogado. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u91c7\u96c6\u6536\u5f55\u5bf9\u8c61\u7684\u5ca9\u5e8a\u7684\u5168\u79f0\u3002"
#       }
#     ],
#     "cv_string": "image/png",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m003",
#     "match": "",
#     "value": "image/png"
#   },
#   {
#     "localname": "m008",
#     "iri": "http://rs.tdwg.org/format/values/m008",
#     "label": [
#       {
#         "language": "en",
#         "value": "JPEG"
#       },
#       {
#         "language": "es",
#         "value": "Comportamiento"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u884c\u4e3a"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for JPEG images"
#       },
#       {
#         "language": "es",
#         "value": "Una descripci\u00f3n de la conducta mostrada por el sujeto en el momento del Registro Biol\u00f3gico.\u00a0La pr\u00e1ctica recomendada es el uso de un lenguaje controlado."
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5bf9\u8bb0\u5f55\u53d1\u73b0\u8fc7\u7a0b\u4e2d\u76ee\u6807\u884c\u4e3a\u7684\u63cf\u8ff0\u3002\u5efa\u8bae\u6700\u597d\u4f7f\u7528\u63a7\u5236\u6027\u8bcd\u6c47\u3002"
#       }
#     ],
#     "cv_string": "image/jpeg",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m003",
#     "match": "",
#     "value": "image/jpeg"
#   },
#   {
#     "localname": "m009",
#     "iri": "http://rs.tdwg.org/format/values/m009",
#     "label": [
#       {
#         "language": "en",
#         "value": "BMP"
#       },
#       {
#         "language": "es",
#         "value": "N\u00famero de cat\u00e1logo"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u76ee\u5f55\u7f16\u53f7"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for bitmap images"
#       },
#       {
#         "language": "es",
#         "value": "Un identificador (preferiblemente \u00fanico) para el registro dentro del conjunto de datos o colecci\u00f3n. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u6570\u636e\u96c6\u6216\u4fdd\u85cf\u4fe1\u606f\u4e2d\u7684\u8bb0\u5f55\u6807\u8bc6\u7b26\uff08\u6700\u597d\u662f\u552f\u4e00\u7684\uff09\u3002"
#       }
#     ],
#     "cv_string": "image/bmp",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m003",
#     "match": "",
#     "value": "image/bmp"
#   },
#   {
#     "localname": "m010",
#     "iri": "http://rs.tdwg.org/format/values/m010",
#     "label": [
#       {
#         "language": "en",
#         "value": "GIF"
#       },
#       {
#         "language": "es",
#         "value": "Clase"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u7eb2"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for GIF images"
#       },
#       {
#         "language": "es",
#         "value": "El nombre cient\u00edfico completo de la clase en la que se clasifica el tax\u00f3n."
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5206\u7c7b\u5355\u5143\u6240\u5c5e\u7eb2\u7684\u5b8c\u6574\u5b66\u540d\u3002"
#       }
#     ],
#     "cv_string": "image/gif",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m003",
#     "match": "",
#     "value": "image/gif"
#   },
#   {
#     "localname": "m011",
#     "iri": "http://rs.tdwg.org/format/values/m011",
#     "label": [
#       {
#         "language": "en",
#         "value": "TIFF"
#       },
#       {
#         "language": "es",
#         "value": "C\u00f3digo de la colecci\u00f3n"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u4fdd\u85cf\u4ee3\u7801"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for TIFF images"
#       },
#       {
#         "language": "es",
#         "value": "El nombre, acr\u00f3nimo, coden, o iniciales que identifican la colecci\u00f3n o conjunto de datos del que procede el registro. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u6807\u8bc6\u751f\u6210\u8bb0\u5f55\u7684\u4fdd\u85cf\u4fe1\u606f\u6216\u6570\u636e\u96c6\u7684\u540d\u79f0\u3001\u9996\u5b57\u6bcd\u7f29\u7565\u8bcd\u3001\u5206\u7c7b\u7f16\u53f7\u6216\u8bcd\u8d77\u9996\u5b57\u6bcd"
#       }
#     ],
#     "cv_string": "image/tiff",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m003",
#     "match": "",
#     "value": "image/tiff"
#   },
#   {
#     "localname": "m012",
#     "iri": "http://rs.tdwg.org/format/values/m012",
#     "label": [
#       {
#         "language": "en",
#         "value": "MP4 video"
#       },
#       {
#         "language": "es",
#         "value": "ID de la colecci\u00f3n"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u4fdd\u85cf\u7f16\u53f7"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for MP4 videos"
#       },
#       {
#         "language": "es",
#         "value": "Un identificador de la colecci\u00f3n o conjunto de datos del que procede el registro. Para espec\u00edmenes f\u00edsicos, la pr\u00e1ctica recomendada es utilizar el identificador de un \u00edndice de colecci\u00f3n tal como el \u00cdndice de Colecciones de Biodiversidad (http://www.biodi"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u751f\u6210\u8bb0\u5f55\u7684\u4fdd\u85cf\u4fe1\u606f\u6216\u6570\u636e\u96c6\u7684\u6807\u8bc6\u7b26\u3002\u9488\u5bf9\u5b9e\u4f53\u6807\u672c\uff0c\u5efa\u8bae\u6700\u597d\u4f7f\u7528\u4fdd\u85cf\u6ce8\u518c\u6807\u8bc6\u7b26\uff0c\u5982\u751f\u7269\u591a\u6837\u6027\u4fdd\u85cf\u7d22\u5f15(http://www.biodiversitycollectionsindex.org/)\u3002"
#       }
#     ],
#     "cv_string": "video/mp4",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m006",
#     "match": "",
#     "value": "video/mp4"
#   },
#   {
#     "localname": "m013",
#     "iri": "http://rs.tdwg.org/format/values/m013",
#     "label": [
#       {
#         "language": "en",
#         "value": "MPEG"
#       },
#       {
#         "language": "es",
#         "value": "Continente"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u6d32"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for MPEG videos"
#       },
#       {
#         "language": "es",
#         "value": "El nombre del continente en el que la ubicaci\u00f3n ocurre.\u00a0La pr\u00e1ctica recomendada es el uso de un lenguaje controlado, como la norma ISO 3166 de c\u00f3digos de Continente. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u53d1\u73b0\u5730\u70b9\u6240\u5728\u7684\u5927\u6d32\u540d\u3002\u5efa\u8bae\u6700\u597d\u4f7f\u7528\u63a7\u5236\u6027\u8bcd\u6c47\uff0c\u5982\u76d6\u63d0\u5730\u7406\u540d\u79f0\u7d22\u5f15\u5178\u6216\u56fd\u9645\u6807\u51c6\u5316\u7ec4\u7ec73166\u6d32\u4ee3\u7801\u3002"
#       }
#     ],
#     "cv_string": "video/mpeg",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m006",
#     "match": "",
#     "value": "video/mpeg"
#   },
#   {
#     "localname": "m014",
#     "iri": "http://rs.tdwg.org/format/values/m014",
#     "label": [
#       {
#         "language": "en",
#         "value": "QuickTime"
#       },
#       {
#         "language": "es",
#         "value": "Precisi\u00f3n de las coordenadas"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5750\u6807\u7cbe\u5ea6"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for QuickTime videos"
#       },
#       {
#         "language": "es",
#         "value": "Una representaci\u00f3n decimal de la precisi\u00f3n de las coordenadas provistas en Latitud Decimal y Longitud Decimal. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u7cbe\u786e\u5230\u5c0f\u6570\u7684\u7eac\u5ea6\u548c\u7ecf\u5ea6\u5750\u6807\u7684\u5c0f\u6570\u793a\u6570\u3002"
#       }
#     ],
#     "cv_string": "video/quicktime",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m006",
#     "match": "",
#     "value": "video/quicktime"
#   },
#   {
#     "localname": "m015",
#     "iri": "http://rs.tdwg.org/format/values/m015",
#     "label": [
#       {
#         "language": "en",
#         "value": "MP4 audio"
#       },
#       {
#         "language": "es",
#         "value": " Incertidumbre de las coordenadas en metros"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5750\u6807\u4e0d\u786e\u5b9a\u6027\uff08\u4ee5\u7c73\u4e3a\u5355\u4f4d\uff09"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for MP4 audio"
#       },
#       {
#         "language": "es",
#         "value": "La distancia horizontal (en metros) de la Latitud Decimal y Longitud Decimal provistas describiendo el c\u00edrculo m\u00e1s peque\u00f1o que contiene la totalidad de la ubicaci\u00f3n.\u00a0Deje el valor vac\u00edo si la incertidumbre es desconocida, no se puede estimar, o no es apli"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5230\u6db5\u76d6\u6574\u4e2a\u5730\u70b9\u7684\u6700\u5c0f\u5706\u5f62\u533a\u57df\u7684\u5c0f\u6570\u7eac\u5ea6\u548c\u7ecf\u5ea6\u7684\u6c34\u5e73\u8ddd\u79bb\uff08\u4ee5\u201c\u7c73\u201d\u4e3a\u5355\u4f4d\uff09\u3002\u82e5\u672a\u77e5\u3001\u65e0\u6cd5\u4f30\u7b97\u6216\u4e0d\u9002\u7528\uff08\u7531\u4e8e\u6ca1\u6709\u5750\u6807\uff09\uff0c\u5219\u503c\u4e3a\u7a7a\u3002\u6b64\u9879\u4e2d0\u4e0d\u662f\u6709\u6548\u503c\u3002"
#       }
#     ],
#     "cv_string": "audio/mp4",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m002",
#     "match": "",
#     "value": "audio/mp4"
#   },
#   {
#     "localname": "m016",
#     "iri": "http://rs.tdwg.org/format/values/m016",
#     "label": [
#       {
#         "language": "en",
#         "value": "MP3"
#       },
#       {
#         "language": "es",
#         "value": "Pa\u00eds"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u56fd\u5bb6"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for MP3 audio"
#       },
#       {
#         "language": "es",
#         "value": "El nombre del pa\u00eds o unidad administrativa de mayor jerarqu\u00eda de la ubicaci\u00f3n.\u00a0La pr\u00e1ctica recomendada es utilizar un identificador persistente de un lenguaje controlado como el Tesauro Getty de Nombres Geogr\u00e1ficos. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u53d1\u73b0\u5730\u70b9\u7684\u56fd\u5bb6\u6216\u4e3b\u8981\u884c\u653f\u533a\u5212\u540d\u79f0\u3002\u5efa\u8bae\u6700\u597d\u4f7f\u7528\u63a7\u5236\u6027\u8bcd\u6c47\uff0c\u5982\u76d6\u63d0\u5730\u7406\u540d\u79f0\u7d22\u5f15\u3002"
#       }
#     ],
#     "cv_string": "audio/mpeg",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m002",
#     "match": "",
#     "value": "audio/mpeg"
#   },
#   {
#     "localname": "m017",
#     "iri": "http://rs.tdwg.org/format/values/m017",
#     "label": [
#       {
#         "language": "en",
#         "value": "X3D VRML"
#       },
#       {
#         "language": "es",
#         "value": "C\u00f3digo del pa\u00eds"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u56fd\u5bb6\u4ee3\u7801"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for X3D VRML models"
#       },
#       {
#         "language": "es",
#         "value": "El c\u00f3digo est\u00e1ndar para el pa\u00eds de la ubicaci\u00f3n.\u00a0La pr\u00e1ctica recomendada es el uso de ISO 3166-1-alfa-2 de c\u00f3digos de pa\u00edses. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u53d1\u73b0\u5730\u70b9\u7684\u6807\u51c6\u56fd\u5bb6\u4ee3\u7801\u3002\u5efa\u8bae\u6700\u597d\u4f7f\u7528\u56fd\u9645\u6807\u51c6\u5316\u7ec4\u7ec73166-1-\u963f\u5c14\u6cd5-2\u56fd\u5bb6\u4ee3\u7801\u3002"
#       }
#     ],
#     "cv_string": "model/x3d-vrml",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m004",
#     "match": "",
#     "value": "model/x3d-vrml"
#   },
#   {
#     "localname": "m018",
#     "iri": "http://rs.tdwg.org/format/values/m018",
#     "label": [
#       {
#         "language": "en",
#         "value": "PDF"
#       },
#       {
#         "language": "es",
#         "value": "Condado"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u90e1/\u53bf"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for PDF documents"
#       },
#       {
#         "language": "es",
#         "value": "El nombre completo, sin abreviar de la siguiente regi\u00f3n administrativa de menor jerarqu\u00eda que Estado Provincia (condado, departamento, etc.) de la ubicaci\u00f3n."
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u53d1\u73b0\u5730\u70b9\u6240\u5728\u7684\u9664\u5dde/\u7701\u4e4b\u5916\u7684\u6b21\u4e00\u7ea7\u884c\u653f\u533a\u5212\uff08\u53bf\u3001\u90e1\u3001\u884c\u653f\u533a\u7b49\uff09\u3002"
#       }
#     ],
#     "cv_string": "application/pdf",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m001",
#     "match": "",
#     "value": "application/pdf"
#   },
#   {
#     "localname": "m019",
#     "iri": "http://rs.tdwg.org/format/values/m019",
#     "label": [
#       {
#         "language": "en",
#         "value": "plain text"
#       },
#       {
#         "language": "es",
#         "value": "Generalizaci\u00f3n de los datos"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u6570\u636e\u6982\u62ec"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for plain text"
#       },
#       {
#         "language": "es",
#         "value": "Las medidas adoptadas para que los datos compartidos sean menos espec\u00edficos o completos que en su forma original.\u00a0Sugiere que datos alternativos de mayor calidad pueden estar disponibles bajo petici\u00f3n."
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u4e3a\u4f7f\u5171\u4eab\u6570\u636e\u8f83\u4e4b\u5176\u539f\u59cb\u5f62\u5f0f\u4e0d\u90a3\u4e48\u7cbe\u786e\u6216\u5b8c\u6574\u6240\u91c7\u53d6\u7684\u884c\u52a8\u3002\u5efa\u8bae\u4ee5\u66f4\u9ad8\u8d28\u91cf\u7684\u66ff\u4ee3\u6570\u636e\u5907\u7d22\u3002"
#       }
#     ],
#     "cv_string": "text/plain",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m005",
#     "match": "",
#     "value": "text/plain"
#   },
#   {
#     "localname": "m020",
#     "iri": "http://rs.tdwg.org/format/values/m020",
#     "label": [
#       {
#         "language": "en",
#         "value": "Word (pre-2003) document"
#       },
#       {
#         "language": "es",
#         "value": "ID del conjunto de datos"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u6570\u636e\u96c6\u7f16\u53f7"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for Microsoft Word (2003 and before) documents"
#       },
#       {
#         "language": "es",
#         "value": "Un identificador para el conjunto de datos.\u00a0Puede ser un identificador \u00fanico global o un identificador espec\u00edfico de una colecci\u00f3n o instituci\u00f3n."
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u6570\u636e\u96c6\u7684\u6807\u8bc6\u7b26\u3002\u53ef\u80fd\u662f\u4e00\u4e2a\u5168\u5c40\u552f\u4e00\u6807\u8bc6\u7b26\u6216\u4e00\u4e2a\u4fdd\u85cf\u4e2d\u5fc3\u6216\u7814\u7a76\u673a\u6784\u7684\u7279\u5b9a\u6807\u8bc6\u7b26\u3002"
#       }
#     ],
#     "cv_string": "application/msword",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m001",
#     "match": "",
#     "value": "application/msword"
#   },
#   {
#     "localname": "m021",
#     "iri": "http://rs.tdwg.org/format/values/m021",
#     "label": [
#       {
#         "language": "en",
#         "value": "Word (post-2007) document"
#       },
#       {
#         "language": "es",
#         "value": "Nombre del conjunto de datos"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u6570\u636e\u96c6\u540d\u79f0"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for Microsoft Word (2007 and after) documents"
#       },
#       {
#         "language": "es",
#         "value": "El nombre que identifica el conjunto de datos del cual se deriv\u00f3 el registro.  "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u6807\u8bc6\u751f\u6210\u8bb0\u5f55\u7684\u6570\u636e\u96c6\u7684\u540d\u79f0\u3002"
#       }
#     ],
#     "cv_string": "application/vnd.openxmlformats-officedocument.wordprocessingml.document",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m001",
#     "match": "",
#     "value": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#   },
#   {
#     "localname": "m022",
#     "iri": "http://rs.tdwg.org/format/values/m022",
#     "label": [
#       {
#         "language": "en",
#         "value": "Digital Negative"
#       },
#       {
#         "language": "es",
#         "value": "Fecha de identificaci\u00f3n"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u9274\u5b9a\u65e5\u671f"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for Digital Negative images"
#       },
#       {
#         "language": "es",
#         "value": "La fecha en que fue identificado el sujeto como representativo del tax\u00f3n.\u00a0La pr\u00e1ctica recomendada es utilizar un esquema de codificaci\u00f3n, como ISO 8601:2004 (E). "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u6d89\u53ca\u88ab\u89c6\u4e3a\u4ee3\u8868\u5206\u7c7b\u5355\u5143\u7684\u4e3b\u4f53\u7684\u6570\u636e\u3002\u5efa\u8bae\u6700\u597d\u4f7f\u7528\u7f16\u7801\u65b9\u6848\uff0c\u5982ISO 8601:2004(E)\u3002"
#       }
#     ],
#     "cv_string": "image/x-adobe-dng",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m003",
#     "match": "",
#     "value": "image/x-adobe-dng"
#   },
#   {
#     "localname": "m023",
#     "iri": "http://rs.tdwg.org/format/values/m023",
#     "label": [
#       {
#         "language": "en",
#         "value": "CR2"
#       },
#       {
#         "language": "es",
#         "value": "D\u00eda"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5929"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for Canon Raw images"
#       },
#       {
#         "language": "es",
#         "value": "El d\u00eda en n\u00fameros enteros, del mes en que ocurri\u00f3 el evento. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u4e8b\u4ef6\u53d1\u751f\u7684\u6574\u6570\u5929\u3002"
#       }
#     ],
#     "cv_string": "image/x-canon-cr2",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m003",
#     "match": "",
#     "value": "image/x-canon-cr2"
#   },
#   {
#     "localname": "m024",
#     "iri": "http://rs.tdwg.org/format/values/m024",
#     "label": [
#       {
#         "language": "en",
#         "value": "JPEG 2000"
#       },
#       {
#         "language": "es",
#         "value": "Latitud decimal"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5341\u8fdb\u5236\u7eac\u5ea6"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for JPEG 2000 images"
#       },
#       {
#         "language": "es",
#         "value": "La latitud geogr\u00e1fica (en grados decimales, utilizando el sistema de referencia espacial provisto en Datum Geod\u00e9sico) del centro geogr\u00e1fico de una ubicaci\u00f3n.\u00a0Los valores positivos se encuentran al norte del ecuador, los valores negativos est\u00e1n al sur del "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5730\u70b9\u7684\u5730\u7406\u4e2d\u5fc3\u7684\u7eac\u5ea6\uff08\u4ee5\u5c0f\u6570\u8868\u793a\uff0c\u91c7\u7528\u5927\u5730\u57fa\u51c6\u4e2d\u63d0\u4f9b\u7684\u7a7a\u95f4\u53c2\u7167\u7cfb\u7edf\uff09\u3002\u6b63\u503c\u4ee3\u8868\u8d64\u9053\u4ee5\u5317\uff0c\u8d1f\u503c\u4ee3\u8868\u8d64\u9053\u4ee5\u5357\u3002\u6cd5\u5b9a\u503c\u4ecb\u4e8e-90\u81f390\uff08\u542b\uff09\u4e4b\u95f4\u3002"
#       }
#     ],
#     "cv_string": "image/jp2",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m003",
#     "match": "",
#     "value": "image/jp2"
#   },
#   {
#     "localname": "m025",
#     "iri": "http://rs.tdwg.org/format/values/m025",
#     "label": [
#       {
#         "language": "en",
#         "value": "WAVE"
#       },
#       {
#         "language": "es",
#         "value": "Longitud decimal"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5341\u8fdb\u5236\u7ecf\u5ea6"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for WAVE audio"
#       },
#       {
#         "language": "es",
#         "value": "La longitud geogr\u00e1fica (en grados decimales, mediante el sistema de referencia espacial provisto en Datum Geod\u00e9sico) del centro geogr\u00e1fico de un lugar.\u00a0Los valores positivos se encuentran al este del meridiano de Greenwich, los valores negativos se encuen"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5730\u70b9\u7684\u5730\u7406\u4e2d\u5fc3\u7684\u7ecf\u5ea6\uff08\u4ee5\u5c0f\u6570\u8868\u793a\uff0c\u91c7\u7528\u5927\u5730\u57fa\u51c6\u4e2d\u63d0\u4f9b\u7684\u7a7a\u95f4\u53c2\u7167\u7cfb\u7edf\uff09\u3002\u6b63\u503c\u4ee3\u8868\u683c\u6797\u5a01\u6cbb\u5b50\u5348\u7ebf\u4ee5\u897f\uff0c\u8d1f\u503c\u4ee3\u8868\u683c\u6797\u5a01\u6cbb\u5b50\u5348\u7ebf\u4ee5\u4e1c\u3002\u6cd5\u5b9a\u503c\u4ecb\u4e8e-180\u81f3180\uff08\u542b\uff09\u4e4b\u95f4\u3002"
#       }
#     ],
#     "cv_string": "audio/vnd.wave",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m002",
#     "match": "",
#     "value": "audio/vnd.wave"
#   },
#   {
#     "localname": "m026",
#     "iri": "http://rs.tdwg.org/format/values/m026",
#     "label": [
#       {
#         "language": "en",
#         "value": "Nikon NEF Raw"
#       },
#       {
#         "language": "es",
#         "value": "Disposici\u00f3n"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5bc4\u5b58"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for Nikon NEF Raw images"
#       },
#       {
#         "language": "es",
#         "value": "El estado actual de un esp\u00e9cimen con respecto a la colecci\u00f3n identificada en C\u00f3digo de la Colecci\u00f3n o ID de la Colecci\u00f3n.\u00a0La pr\u00e1ctica recomendada es el uso de un lenguaje controlado. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u4e0e\u786e\u5b9a\u4e86\u4fdd\u85cf\u4ee3\u7801\u6216\u4fdd\u85cf\u8bc6\u522b\u7801\u7684\u4fdd\u85cf\u7269\u76f8\u5173\u7684\u6807\u672c\u7684\u5f53\u524d\u72b6\u6001\u3002\u63a8\u8350\u4f7f\u7528\u63a7\u5236\u8bcd\u8868\u3002"
#       }
#     ],
#     "cv_string": "image/x-nikon-nef",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m003",
#     "match": "",
#     "value": "image/x-nikon-nef"
#   },
#   {
#     "localname": "m027",
#     "iri": "http://rs.tdwg.org/format/values/m027",
#     "label": [
#       {
#         "language": "en",
#         "value": "M4V"
#       },
#       {
#         "language": "es",
#         "value": "Propiedades din\u00e1micas"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u52a8\u6001\u5c5e\u6027"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for Apple M4V videos"
#       },
#       {
#         "language": "es",
#         "value": "Una lista (concatenada y separada) de las medidas, hechos, caracter\u00edsticas, o aseveraciones adicionales sobre el registro. Su intenci\u00f3n es proporcionar un mecanismo para contenido estructurado como pares de valor.  "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5173\u4e8e\u8bb0\u5f55\u7684\u5176\u4ed6\u6d4b\u91cf\u3001\u60c5\u51b5\u3001\u7279\u5f81\u3001\u5224\u5b9a\u7b49\u4fe1\u606f\u7684\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u5217\u8868\u3002\u610f\u5728\u4e3a\u8bf8\u5982\u952e\u503c\u5bf9\u7b49\u7684\u7ed3\u6784\u5316\u5185\u5bb9\u8bbe\u7acb\u673a\u5236\u3002"
#       }
#     ],
#     "cv_string": "video/x-m4v",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m006",
#     "match": "",
#     "value": "video/x-m4v"
#   },
#   {
#     "localname": "m028",
#     "iri": "http://rs.tdwg.org/format/values/m028",
#     "label": [
#       {
#         "language": "en",
#         "value": "3GPP"
#       },
#       {
#         "language": "es",
#         "value": "Edad temprana o estad\u00edo inferior"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u6700\u65e9\u5730\u8d28\u5e74\u4ee3\u6216\u6700\u4f4e\u5e74\u4ee3\u5730\u5c42"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for 3GPP video"
#       },
#       {
#         "language": "es",
#         "value": "El nombre completo de la edad geocronol\u00f3gica m\u00e1s temprana posible o la etapa cronoestratigr\u00e1fica m\u00e1s baja, atribuible al horizonte estratigr\u00e1fico donde se recolect\u00f3 el objeto catalogado. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u7f16\u76ee\u9879\u6240\u91c7\u96c6\u7684\u5730\u5c42\u5c42\u4f4d\u6240\u5c5e\u4e4b\u53ef\u80fd\u7684\u6700\u65e9\u7684\u5730\u8d28\u5e74\u4ee3\u6216\u6700\u4f4e\u7684\u5e74\u4ee3\u5730\u5c42\u7684\u5168\u79f0\u3002"
#       }
#     ],
#     "cv_string": "\u200evideo/3gpp",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m006",
#     "match": "",
#     "value": "\u200evideo/3gpp"
#   },
#   {
#     "localname": "m029",
#     "iri": "http://rs.tdwg.org/format/values/m029",
#     "label": [
#       {
#         "language": "en",
#         "value": "AVI"
#       },
#       {
#         "language": "es",
#         "value": "E\u00f3n temprano o eonotema inferior"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u6700\u65e9\u5730\u8d28\u5b99\u6216\u6700\u4f4e\u5730\u5c42\u5b87"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for AVI video"
#       },
#       {
#         "language": "es",
#         "value": "El nombre completo del e\u00f3n geocronol\u00f3gico m\u00e1s temprano o el eratema crono-estratigr\u00e1fico m\u00e1s bajo, o el nombre informal (\"Prec\u00e1mbrico\") atribuible al horizonte estratigr\u00e1fico donde se recolect\u00f3 el objeto catalogado. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u7f16\u76ee\u9879\u6240\u91c7\u96c6\u7684\u5730\u5c42\u5c42\u4f4d\u6240\u5c5e\u4e4b\u53ef\u80fd\u7684\u6700\u65e9\u7684\u5730\u8d28\u5b99\u6216\u6700\u4f4e\u7684\u5730\u5c42\u5b87\u7684\u5168\u79f0\u6216\u975e\u6b63\u5f0f\u540d\u79f0\uff08\u201c\u524d\u5bd2\u6b66\u7eaa\u201d\uff09\u3002"
#       }
#     ],
#     "cv_string": "video/vnd.avi",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m006",
#     "match": "",
#     "value": "video/vnd.avi"
#   },
#   {
#     "localname": "m030",
#     "iri": "http://rs.tdwg.org/format/values/m030",
#     "label": [
#       {
#         "language": "en",
#         "value": "AMR"
#       },
#       {
#         "language": "es",
#         "value": "\u00c9poca temprana o serie inferior"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u6700\u65e9\u5730\u8d28\u4e16\u6216\u6700\u4f4e\u5730\u5c42\u7edf"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for Adaptive Multi-Rate audio"
#       },
#       {
#         "language": "es",
#         "value": "El nombre completo de la \u00e9poca geocronol\u00f3gica m\u00e1s temprana o la serie cronoestratigr\u00e1fica m\u00e1s baja posible, atribuible al horizonte estratigr\u00e1fico donde se recolect\u00f3 el objeto catalogado. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u7f16\u76ee\u9879\u6240\u91c7\u96c6\u7684\u5730\u5c42\u5c42\u4f4d\u6240\u5c5e\u4e4b\u53ef\u80fd\u7684\u6700\u65e9\u7684\u5730\u8d28\u4e16\u6216\u6700\u4f4e\u7684\u5730\u5c42\u7edf\u7684\u5168\u79f0\u3002"
#       }
#     ],
#     "cv_string": "audio/AMR",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m002",
#     "match": "",
#     "value": "audio/AMR"
#   },
#   {
#     "localname": "m031",
#     "iri": "http://rs.tdwg.org/format/values/m031",
#     "label": [
#       {
#         "language": "en",
#         "value": "AIFF"
#       },
#       {
#         "language": "es",
#         "value": "Era temprana o eratema inferior"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u6700\u65e9\u5730\u8d28\u4ee3\u6216\u6700\u4f4e\u5730\u5c42\u754c"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for Audio Interchange File Format audio"
#       },
#       {
#         "language": "es",
#         "value": "El nombre completo de la era geocronol\u00f3gica m\u00e1s temprana o el eratema crono-estratigr\u00e1fico m\u00e1s bajo, atribuible al horizonte estratigr\u00e1fico donde se recolect\u00f3 el objeto catalogado. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u7f16\u76ee\u9879\u6240\u91c7\u96c6\u7684\u5730\u5c42\u5c42\u4f4d\u6240\u5c5e\u4e4b\u53ef\u80fd\u7684\u6700\u65e9\u7684\u5730\u8d28\u4ee3\u6216\u6700\u4f4e\u7684\u5730\u5c42\u754c\u7684\u5168\u79f0\u3002"
#       }
#     ],
#     "cv_string": "audio/x-aiff",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m002",
#     "match": "",
#     "value": "audio/x-aiff"
#   },
#   {
#     "localname": "m032",
#     "iri": "http://rs.tdwg.org/format/values/m032",
#     "label": [
#       {
#         "language": "en",
#         "value": "OGG audio"
#       },
#       {
#         "language": "es",
#         "value": "Periodo temprano o sistema inferior"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u6700\u65e9\u5730\u8d28\u7eaa\u6216\u6700\u4f4e\u5730\u5c42\u7cfb"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for OGG audio"
#       },
#       {
#         "language": "es",
#         "value": "Puede corresponder a: a) un indicador de la existencia de, b) una referencia a (publicaci\u00f3n, URI), o c) el texto de las notas tomadas en campo sobre el evento."
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u7f16\u76ee\u9879\u6240\u91c7\u96c6\u7684\u5730\u5c42\u5c42\u4f4d\u6240\u5c5e\u4e4b\u53ef\u80fd\u7684\u6700\u65e9\u7684\u5730\u8d28\u7eaa\u6216\u6700\u4f4e\u7684\u5730\u5c42\u7cfb\u7684\u5168\u79f0\u3002"
#       }
#     ],
#     "cv_string": "audio/ogg",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m002",
#     "match": "",
#     "value": "audio/ogg"
#   },
#   {
#     "localname": "m033",
#     "iri": "http://rs.tdwg.org/format/values/m033",
#     "label": [
#       {
#         "language": "en",
#         "value": "OGG video"
#       },
#       {
#         "language": "es",
#         "value": "D\u00eda final del a\u00f1o"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5f53\u5e74\u7ed3\u675f\u65e5"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for OGG video"
#       },
#       {
#         "language": "es",
#         "value": "El \u00faltimo d\u00eda ordinal del a\u00f1o en que ocurri\u00f3 el evento (1 para el 1\u00ba de enero, 365 para el 31 de diciembre, excepto en un a\u00f1o bisiesto, en cuyo caso es 366)."
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u4e8b\u4ef6\u53d1\u751f\u5f53\u5e74\u7684\u6700\u65b0\u65e5\u671f\u53f7\uff08\u9664\u4e86\u95f0\u5e74\u6709366\u5929\u7684\u60c5\u51b5\uff0c1\u4ee3\u88681\u67081\u65e5\uff0c365\u4ee3\u886812\u670831\u65e5\uff09\u3002"
#       }
#     ],
#     "cv_string": "video/ogg",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m006",
#     "match": "",
#     "value": "video/ogg"
#   },
#   {
#     "localname": "m034",
#     "iri": "http://rs.tdwg.org/format/values/m034",
#     "label": [
#       {
#         "language": "en",
#         "value": "OGG multiplex"
#       },
#       {
#         "language": "es",
#         "value": "Medios de establecimiento"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u786e\u5b9a\u65b9\u6cd5"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for OGG multiplex"
#       },
#       {
#         "language": "es",
#         "value": "El proceso por el cual el individuo(s) biol\u00f3gico(s) representado en el Registro Biol\u00f3gico se estableci\u00f3 en el lugar.\u00a0La pr\u00e1ctica recomendada es el uso de un lenguaje controlado. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5728\u91c7\u96c6\u5730\u70b9\u786e\u5b9a\u751f\u7269\u4e2a\u4f53\u5728\u4e8b\u4ef6\u4e2d\u8868\u73b0\u7684\u8fc7\u7a0b\u3002\u5efa\u8bae\u6700\u4f73\u505a\u6cd5\u662f\u4f7f\u7528\u4e00\u4e2a\u63a7\u5236\u6027\u8bcd\u6c47\u3002"
#       }
#     ],
#     "cv_string": "application/ogg",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m001",
#     "match": "",
#     "value": "application/ogg"
#   },
#   {
#     "localname": "m035",
#     "iri": "http://rs.tdwg.org/format/values/m035",
#     "label": [
#       {
#         "language": "en",
#         "value": "Kodak Photo CD image"
#       },
#       {
#         "language": "es",
#         "value": "Fecha del evento"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u4e8b\u4ef6\u65e5\u671f"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for Kodak Photo CD image"
#       },
#       {
#         "language": "es",
#         "value": "La fecha y hora o el intervalo durante el cual se produjo un evento.\u00a0Para los registros de especies, esta es la fecha y hora cuando el evento se registr\u00f3.\u00a0No es adecuado para un momento en un contexto geol\u00f3gico.\u00a0La pr\u00e1ctica recomendada es utilizar un esqu"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u4e8b\u4ef6\u53d1\u751f\u7684\u65e5\u671f\u6216\u95f4\u9694\u3002\u5bf9\u4e8e\u5df2\u53d1\u751f\u7684\u4e8b\u4ef6\u8fd9\u662f\u88ab\u8bb0\u5f55\u7684\u65e5\u671f\u3002\t\t\t\t\t\t\u4e0d\u9002\u5408\u5730\u8d28\u80cc\u666f\u65f6\u95f4\u3002\u5efa\u8bae\u6700\u4f73\u505a\u6cd5\u662f\u4f7f\u7528\u4e00\u4e2a\u7f16\u7801\u65b9\u6848\uff0c\u4f8b\u5982ISO 8601:2004(E)\u3002"
#       }
#     ],
#     "cv_string": "image/x-photo-cd",
#     "scheme": "http://rs.tdwg.org/format/values/m",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "http://rs.tdwg.org/format/values/m003",
#     "match": "",
#     "value": "image/x-photo-cd"
#   },
#   {
#     "localname": "m036",
#     "iri": "http://rs.tdwg.org/format/values/m036",
#     "label": [
#       {
#         "language": "en",
#         "value": "Photoshop"
#       },
#       {
#         "language": "es",
#         "value": "ID del evento"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u4e8b\u4ef6\u7f16\u53f7"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "media subtype for Photoshop images"
#       },
#       {
#         "language": "es",
# ...
#         "language": "zh-Hans",
#         "value": "\u53d1\u5e03\u540d\u79f0"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "file extension for SVG images"
#       },
#       {
#         "language": "es",
#         "value": "Una referencia para la publicaci\u00f3n en que se estableci\u00f3 originalmente Nombre Cient\u00edfico bajo las reglas del C\u00f3digo Nomenclatural asociado. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5728\u76f8\u5173\u7684\u547d\u540d\u89c4\u5219\u4e0b\uff0c\u786e\u5b9a\u6700\u521d\u5b66\u540d\u7684\u51fa\u7248\u53c2\u8003\u7269\u3002"
#       }
#     ],
#     "cv_string": "svg",
#     "scheme": "http://rs.tdwg.org/format/values/e",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "",
#     "match": "http://rs.tdwg.org/format/values/m042",
#     "value": "svg"
#   },
#   {
#     "localname": "e037",
#     "iri": "http://rs.tdwg.org/format/values/e037",
#     "label": [
#       {
#         "language": "en",
#         "value": "OBJ"
#       },
#       {
#         "language": "es",
#         "value": "ID del nombre publicado en"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u540d\u79f0\u53d1\u5e03\u7f16\u53f7"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "file extension for OBJ"
#       },
#       {
#         "language": "es",
#         "value": "Un identificador de la publicaci\u00f3n en que se estableci\u00f3 originalmente Nombre cient\u00edfico bajo las reglas del C\u00f3digo nomenclatural asociado. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5728\u76f8\u5173\u7684\u547d\u540d\u89c4\u5219\u4e0b\uff0c\u786e\u5b9a\u6700\u521d\u5b66\u540d\u7684\u51fa\u7248\u7269\u6807\u8bc6\u7b26\u3002"
#       }
#     ],
#     "cv_string": "obj",
#     "scheme": "http://rs.tdwg.org/format/values/e",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "",
#     "match": "http://rs.tdwg.org/format/values/m062",
#     "value": "obj"
#   },
#   {
#     "localname": "e038",
#     "iri": "http://rs.tdwg.org/format/values/e038",
#     "label": [
#       {
#         "language": "en",
#         "value": "gLTF binary"
#       },
#       {
#         "language": "es",
#         "value": "Nombre publicado en a\u00f1o"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u540d\u79f0\u53d1\u5e03\u5e74\u4efd"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "file extension for Binary GL Transmission Format"
#       },
#       {
#         "language": "es",
#         "value": "El a\u00f1o de cuatro d\u00edgitos en el que se public\u00f3 el Nombre cient\u00edfico. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5b66\u540d\u53d1\u5e03\u7684\u56db\u4f4d\u516c\u5386\u5e74\u4efd\u3002"
#       }
#     ],
#     "cv_string": "glb",
#     "scheme": "http://rs.tdwg.org/format/values/e",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "",
#     "match": "http://rs.tdwg.org/format/values/m063",
#     "value": "glb"
#   },
#   {
#     "localname": "e039",
#     "iri": "http://rs.tdwg.org/format/values/e039",
#     "label": [
#       {
#         "language": "en",
#         "value": "gLTF"
#       },
#       {
#         "language": "es",
#         "value": "C\u00f3digo nomenclatural"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u547d\u540d\u51c6\u5219"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "file extension for GL Transmission Format"
#       },
#       {
#         "language": "es",
#         "value": "El c\u00f3digo de nomenclatura (o c\u00f3digos en el caso de un nombre ambireinal) en virtud del cual se construye el Nombre Cient\u00edfico.\u00a0La pr\u00e1ctica recomendada es el uso de un lenguaje controlado. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u521b\u5efa\u5b66\u540d\u6240\u9075\u5faa\u7684\u547d\u540d\u51c6\u5219\u3002\u5efa\u8bae\u6700\u4f73\u505a\u6cd5\u662f\u4f7f\u7528\u4e00\u4e2a\u63a7\u5236\u6027\u8bcd\u6c47\u3002"
#       }
#     ],
#     "cv_string": "gltf",
#     "scheme": "http://rs.tdwg.org/format/values/e",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "",
#     "match": "http://rs.tdwg.org/format/values/m064",
#     "value": "gltf"
#   },
#   {
#     "localname": "e040",
#     "iri": "http://rs.tdwg.org/format/values/e040",
#     "label": [
#       {
#         "language": "en",
#         "value": "VRML"
#       },
#       {
#         "language": "es",
#         "value": "Estado nomenclatural"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u547d\u540d\u72b6\u6001"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "file extension for Virtual Reality Modeling Language"
#       },
#       {
#         "language": "es",
#         "value": "El estatus relacionado con la publicaci\u00f3n original del nombre y su conformidad con las normas pertinentes de nomenclatura.\u00a0Se basa esencialmente en un algoritmo de acuerdo a las reglas de negociaci\u00f3n del c\u00f3digo.\u00a0No requiere opini\u00f3n taxon\u00f3mica. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u4e0e\u540d\u79f0\u7684\u6700\u521d\u51fa\u7248\u7269\u76f8\u5173\u7684\u72b6\u6001\u53ca\u4e0e\u547d\u540d\u76f8\u5173\u89c4\u5219\u7684\u4e00\u81f4\u6027\u3002\u672c\u8d28\u4e0a\u57fa\u4e8e\u4e00\u4e2a\u6839\u636e\u4e1a\u52a1\u89c4\u5219\u4ee3\u7801\u7684\u7b97\u6cd5\uff0c\u4e0d\u9700\u8981\u5206\u7c7b\u7684\u610f\u89c1\u3002"
#       }
#     ],
#     "cv_string": "wrl",
#     "scheme": "http://rs.tdwg.org/format/values/e",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "",
#     "match": "http://rs.tdwg.org/format/values/m065",
#     "value": "wrl"
#   },
#   {
#     "localname": "e041",
#     "iri": "http://rs.tdwg.org/format/values/e041",
#     "label": [
#       {
#         "language": "en",
#         "value": "DICOM"
#       },
#       {
#         "language": "es",
#         "value": "ID del registro biol\u00f3gico"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u4e8b\u4ef6\u7f16\u53f7"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "file extension for Digital Imaging and Communications in Medicine"
#       },
#       {
#         "language": "es",
#         "value": "Un identificador del Registro biol\u00f3gico (a cambio de un registro digital particular del Registro biol\u00f3gico).\u00a0En ausencia de un identificador \u00fanico global persistente, se debe construir uno a partir de una combinaci\u00f3n de identificadores en el registro de m"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u4e00\u4e2a\u4e8b\u4ef6\u7684\u6807\u8bc6\u7b26\uff08\u5e76\u975e\u4e00\u4e2a\u4e8b\u4ef6\u7684\u5177\u4f53\u6570\u5b57\u8bb0\u5f55\uff09\u3002\u5728\u7f3a\u4e4f\u5168\u5c40\u552f\u4e00\u6807\u8bc6\u7b26\u7684\u60c5\u51b5\u4e0b\uff0c\u4ece\u6700\u63a5\u8fd1\u5168\u5c40\u552f\u4e00\u4e8b\u4ef6\u7f16\u53f7\u7684\u8bb0\u5f55\u4e2d\u6784\u5efa\u4e00\u4e2a\u6807\u8bc6\u7b26\u3002"
#       }
#     ],
#     "cv_string": "dcm",
#     "scheme": "http://rs.tdwg.org/format/values/e",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "",
#     "match": "http://rs.tdwg.org/format/values/m066",
#     "value": "dcm"
#   },
#   {
#     "localname": "e042",
#     "iri": "http://rs.tdwg.org/format/values/e042",
#     "label": [
#       {
#         "language": "en",
#         "value": "MTL"
#       },
#       {
#         "language": "es",
#         "value": "Comentarios del registro biol\u00f3gico"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u4e8b\u4ef6\u5907\u6ce8"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "file extension for OBJ Material Template Library"
#       },
#       {
#         "language": "es",
#         "value": "Comentarios o anotaciones sobre el Registro Biol\u00f3gico. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5173\u4e8e\u8fd9\u4e2a\u4e8b\u4ef6\u7684\u8bc4\u8bba\u548c\u6ce8\u91ca\u3002"
#       }
#     ],
#     "cv_string": "mtl",
#     "scheme": "http://rs.tdwg.org/format/values/e",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "",
#     "match": "http://rs.tdwg.org/format/values/m067",
#     "value": "mtl"
#   },
#   {
#     "localname": "e043",
#     "iri": "http://rs.tdwg.org/format/values/e043",
#     "label": [
#       {
#         "language": "en",
#         "value": "X3D VRML"
#       },
#       {
#         "language": "es",
#         "value": "Estado del registro biol\u00f3gico"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u4e8b\u4ef6\u72b6\u6001"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "file extension for X3D VRML models"
#       },
#       {
#         "language": "es",
#         "value": "Una declaraci\u00f3n sobre la presencia o ausencia de un tax\u00f3n en una ubicaci\u00f3n.\u00a0La pr\u00e1ctica recomendada es el uso de un lenguaje controlado. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5173\u4e8e\u4e00\u4e2a\u7c7b\u7fa4\u5728\u4e00\u4e2a\u5730\u70b9\u5b58\u5728\u6216\u8005\u4e0d\u5b58\u5728\u7684\u58f0\u660e\u3002\u5efa\u8bae\u6700\u4f73\u505a\u6cd5\u662f\u4f7f\u7528\u4e00\u4e2a\u63a7\u5236\u6027\u8bcd\u6c47\u3002"
#       }
#     ],
#     "cv_string": "x3dv",
#     "scheme": "http://rs.tdwg.org/format/values/e",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "",
#     "match": "http://rs.tdwg.org/format/values/m017",
#     "value": "x3dv"
#   },
#   {
#     "localname": "e044",
#     "iri": "http://rs.tdwg.org/format/values/e044",
#     "label": [
#       {
#         "language": "en",
#         "value": "X3D XML"
#       },
#       {
#         "language": "es",
#         "value": "Orden"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u76ee"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "file extension for X3D XML models"
#       },
#       {
#         "language": "es",
#         "value": "El nombre cient\u00edfico completo del orden en el que se clasifica el tax\u00f3n. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5206\u7c7b\u5355\u5143\u6240\u5c5e\u76ee\u7684\u5b8c\u6574\u5b66\u540d\u3002"
#       }
#     ],
#     "cv_string": "x3d",
#     "scheme": "http://rs.tdwg.org/format/values/e",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "",
#     "match": "http://rs.tdwg.org/format/values/m068",
#     "value": "x3d"
#   },
#   {
#     "localname": "e045",
#     "iri": "http://rs.tdwg.org/format/values/e045",
#     "label": [
#       {
#         "language": "en",
#         "value": "CIFF raw image"
#       },
#       {
#         "language": "es",
#         "value": "Uso del nombre original"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u6700\u521d\u4f7f\u7528\u540d\u79f0"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "file extension for Camera Image File Format raw image"
#       },
#       {
#         "language": "es",
#         "value": "El nombre del tax\u00f3n, con informaci\u00f3n de autor\u00eda y fecha si se conoce, tal como apareci\u00f3 originalmente cuando se estableci\u00f3 por primera vez bajo las reglas del C\u00f3digo Nomenclatural asociadas.\u00a0El basi\u00f3nimo (bot\u00e1nica) o basi\u00f3nimo (bacteriolog\u00eda) de Nombre Ci"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5728\u76f8\u5173\u7684\u547d\u540d\u89c4\u5219\u4e0b\u7b2c\u4e00\u6b21\u88ab\u5efa\u7acb\u7684\u6700\u521d\u51fa\u73b0\u7684\u7c7b\u7fa4\u540d\u79f0\uff0c\u5982\u679c\u77e5\u9053\u7684\u8bdd\uff0c\u9644\u4f5c\u8005\u548c\u65e5\u671f\u4fe1\u606f\u3002\u5b66\u540d\u7684\u5f02\u540d\u6216\u57fa\u540d\uff0c\u6216\u7528\u6765\u66ff\u6362\u540d\u79f0\u7684\u540c\u97f3\u8bcd\u3002"
#       }
#     ],
#     "cv_string": "crw",
#     "scheme": "http://rs.tdwg.org/format/values/e",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "",
#     "match": "http://rs.tdwg.org/format/values/m069",
#     "value": "crw"
#   },
#   {
#     "localname": "e046",
#     "iri": "http://rs.tdwg.org/format/values/e046",
#     "label": [
#       {
#         "language": "en",
#         "value": "CR3 raw image"
#       },
#       {
#         "language": "es",
#         "value": "ID del uso del nombre original"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u6700\u521d\u4f7f\u7528\u540d\u79f0\u7f16\u53f7"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "file extension for Canon Raw 3 image"
#       },
#       {
#         "language": "es",
#         "value": "Un identificador para el uso del nombre (significado documentado del nombre de acuerdo a una fuente) en el que se estableci\u00f3 originalmente, el elemento terminal de Nombre Cient\u00edfico bajo las reglas del C\u00f3digo Nomenclatural asociado. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5b66\u540d\u5728\u76f8\u5173\u547d\u540d\u89c4\u5219\u4e0b\u6700\u521d\u5efa\u7acb\u65f6\uff0c\u5b66\u540d\u7684\u672b\u7aef\u7ec4\u6210\u4e0a\u7684\u540d\u79f0\u4f7f\u7528\u6807\u8bc6\u7b26\u3002"
#       }
#     ],
#     "cv_string": "cr3",
#     "scheme": "http://rs.tdwg.org/format/values/e",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "",
#     "match": "http://rs.tdwg.org/format/values/m070",
#     "value": "cr3"
#   },
#   {
#     "localname": "e047",
#     "iri": "http://rs.tdwg.org/format/values/e047",
#     "label": [
#       {
#         "language": "en",
#         "value": "ARW raw image"
#       },
#       {
#         "language": "es",
#         "value": "Otros n\u00fameros de cat\u00e1logo"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u5176\u5b83\u76ee\u5f55\u7f16\u53f7"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "file extension for Sony raw image"
#       },
#       {
#         "language": "es",
#         "value": "Una lista (concatenada y separada) de n\u00fameros de cat\u00e1logos anteriores o alternativos, calificados, u otros identificadores de uso humano para el mismo Registro Biol\u00f3gico, ya sea en el actual o cualquier otro conjunto de datos o colecci\u00f3n. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u65e0\u8bba\u5728\u5f53\u524d\u6216\u5176\u4ed6\u4efb\u4f55\u6570\u636e\u96c6\uff0c\u540c\u4e00\u4e8b\u4ef6\u4e2d\u4ee5\u524d\u6216\u5907\u7528\u7684\u5b8c\u5168\u5408\u683c\u7684\u76ee\u5f55\u53f7\u6216\u5176\u4ed6\u4eba\u4f7f\u7528\u7684\u6807\u8bc6\u7b26\u5217\u8868\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u3002"
#       }
#     ],
#     "cv_string": "arw",
#     "scheme": "http://rs.tdwg.org/format/values/e",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "",
#     "match": "http://rs.tdwg.org/format/values/m071",
#     "value": "arw"
#   },
#   {
#     "localname": "e048",
#     "iri": "http://rs.tdwg.org/format/values/e048",
#     "label": [
#       {
#         "language": "en",
#         "value": "RW2 raw image"
#       },
#       {
#         "language": "es",
#         "value": "C\u00f3digo de la instituci\u00f3n propietaria"
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u6240\u6709\u8005\u673a\u6784\u4ee3\u7801"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "file extension for Panasonic raw image"
#       },
#       {
#         "language": "es",
#         "value": "El nombre (o acr\u00f3nimo) en uso por la instituci\u00f3n que tiene la propiedad del objeto(s) o informaci\u00f3n referida en el registro. "
#       },
#       {
#         "language": "zh-Hans",
#         "value": "\u8bb0\u5f55\u4e2d\u663e\u793a\u7684\u5bf9\u7269\u54c1\u6216\u4fe1\u606f\u4eab\u6709\u6240\u6709\u6743\u7684\u673a\u6784\u540d\u79f0\uff08\u6216\u7f29\u5199\uff09\u3002"
#       }
#     ],
#     "cv_string": "rw2",
#     "scheme": "http://rs.tdwg.org/format/values/e",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "broader": "",
#     "match": "http://rs.tdwg.org/format/values/m072",
#     "value": "rw2"
#   }
# ]

# %%
context_dict = {
    "rdf": "http://www.w3.org/1999/02/22-rdf-syntax-ns#",
    "rdfs": "http://www.w3.org/2000/01/rdf-schema#",
    "skos": "http://www.w3.org/2004/02/skos/core#",
    "xsd": "http://www.w3.org/2001/XMLSchema#"
  }

graph_list = []
for term in term_info:
    term_dict = {}
    term_dict['@id'] = term['iri']
    term_dict['@type'] = term['type']
    if term['value'] != '':
        term_dict['rdf:value'] = term['value']
    if term['scheme'] != '':
        term_dict['skos:inScheme'] = term['scheme']
    if has_broader:
        if term['broader'] != '':
            term_dict['skos:broader'] = term['broader']
    if has_exactMatch:
        if term['match'] != '':
            term_dict['skos:exactMatch'] = term['match']
    label_list = []
    for lang_label in term['label']:
        label_list.append({'@language': lang_label['language'], '@value': lang_label['value']})
    term_dict['skos:prefLabel'] = label_list
    
    def_list = []
    for lang_label in term['definition']:
        def_list.append({'@language': lang_label['language'], '@value': lang_label['value']})
    term_dict['skos:definition'] = def_list
    
    graph_list.append(term_dict)

output = {"@context": context_dict, "@graph": graph_list}
jsonld_output = json.dumps(output, indent = 2)
print(jsonld_output)
# Out:
# {
#   "@context": {
#     "rdf": "http://www.w3.org/1999/02/22-rdf-syntax-ns#",
#     "rdfs": "http://www.w3.org/2000/01/rdf-schema#",
#     "skos": "http://www.w3.org/2004/02/skos/core#",
#     "xsd": "http://www.w3.org/2001/XMLSchema#"
#   },
#   "@graph": [
#     {
#       "@id": "http://rs.tdwg.org/format/values/m",
#       "@type": "http://www.w3.org/2004/02/skos/core#ConceptScheme",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "media types and physical media concept scheme"
#         },
#         {
#           "@language": "es",
#           "@value": "Nombre aceptado en uso"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u516c\u8ba4\u4f7f\u7528\u540d\u79f0"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "concept scheme for IANA media types and various physical media items"
#         },
#         {
#           "@language": "es",
#           "@value": "El nombre completo, con autor\u00eda e informaci\u00f3n de fecha si se conoce, del tax\u00f3n actualmente v\u00e1lido (zool\u00f3gico) o aceptado (bot\u00e1nico). "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u76ee\u524d\u6709\u6548\uff08\u52a8\u7269\u5b66\uff09\u7684\u6216\u516c\u8ba4\uff08\u690d\u7269\u5b66\uff09\u7684\u5206\u7c7b\u5355\u5143\u5168\u79f0\uff0c\u5982\u5df2\u77e5\u6765\u6e90\u548c\u65e5\u671f\u4fe1\u606f\u5219\u9700\u6ce8\u660e\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/e",
#       "@type": "http://www.w3.org/2004/02/skos/core#ConceptScheme",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "file extensions concept scheme"
#         },
#         {
#           "@language": "es",
#           "@value": "Nombre aceptado en uso - ID"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u516c\u8ba4\u4f7f\u7528\u540d\u79f0\u7f16\u53f7"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "concept scheme based on conventional file extensions for media types"
#         },
#         {
#           "@language": "es",
#           "@value": "Un identificador para el nombre en uso (significado del nombre, documentado de acuerdo con alguna fuente) del tax\u00f3n actualmente v\u00e1lido (zool\u00f3gico) o aceptado (bot\u00e1nico).   "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u76ee\u524d\u6709\u6548\uff08\u52a8\u7269\u5b66\uff09\u7684\u6216\u516c\u8ba4\uff08\u690d\u7269\u5b66\uff09\u7684\u5206\u7c7b\u5355\u5143\u7684\u540d\u79f0\u4f7f\u7528\uff08\u6839\u636e\u6765\u6e90\u6240\u53d6\u540d\u79f0\u7684\u5b58\u6863\u8bb0\u5f55\u65b9\u6cd5\uff09\u6807\u8bc6\u7b26\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m001",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "application",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "application"
#         },
#         {
#           "@language": "es",
#           "@value": "Medios asociados"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u76f8\u5173\u5a92\u4ecb"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media type for application"
#         },
#         {
#           "@language": "es",
#           "@value": "Una lista (concatenada o delimitada) de identificadores (publicaci\u00f3n, identificador \u00fanico global, URI) de los medios asociados con el registro biol\u00f3gico."
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u53d1\u73b0\u5a92\u4ecb\u7684\uff08\u53d1\u8868\u3001\u5168\u5c40\u552f\u4e00\u6807\u8bc6\u7b26\u3001\u7edf\u4e00\u8d44\u6e90\u6807\u8bc6\u7b26\u7b49\uff09\u6807\u8bc6\u7b26\u4e4b\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u5217\u8868\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m002",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "audio",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "audio"
#         },
#         {
#           "@language": "es",
#           "@value": "Registros biol\u00f3gicos asociados"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u76f8\u5173\u4e8b\u4ef6"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media type for audio"
#         },
#         {
#           "@language": "es",
#           "@value": "Una lista (concatenada y separada) de los identificadores de otros registros biol\u00f3gicos y su relaci\u00f3n con este Registro Biol\u00f3gico. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5176\u4ed6\u53d1\u73b0\u8bb0\u5f55\u53ca\u5176\u4e0e\u53d1\u73b0\u4fe1\u606f\u76f8\u5173\u8054\u7684\u6807\u8bc6\u7b26\u4e4b\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u5217\u8868\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m003",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "image",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "image"
#         },
#         {
#           "@language": "es",
#           "@value": "Referencias asociadas"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u76f8\u5173\u53c2\u8003"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media type for image"
#         },
#         {
#           "@language": "es",
#           "@value": "Una lista (concatenada y separada) de los identificadores (publicaci\u00f3n, referencia bibliogr\u00e1fica, identificador \u00fanico global, URI) de la literatura asociada con el Registro Biol\u00f3gico. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u4e0e\u53d1\u73b0\u60c5\u51b5\u76f8\u5173\u4e4b\u6587\u732e\u7684\uff08\u53d1\u8868\u3001\u53c2\u8003\u6587\u732e\u3001\u5168\u5c40\u552f\u4e00\u6807\u8bc6\u7b26\u3001\u7edf\u4e00\u8d44\u6e90\u6807\u8bc6\u7b26\u7b49\uff09\u6807\u8bc6\u7b26\u4e4b\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u5217\u8868\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m004",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "model",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "model"
#         },
#         {
#           "@language": "es",
#           "@value": "Secuencias asociadas"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u76f8\u5173\u5e8f\u5217"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media type for model"
#         },
#         {
#           "@language": "es",
#           "@value": "Una lista (concatenada y separada) de los identificadores (publicaci\u00f3n, identificador \u00fanico global, URI) de la informaci\u00f3n de la secuencia gen\u00e9tica asociada con el Registro Biol\u00f3gico. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u4e0e\u53d1\u73b0\u60c5\u51b5\u76f8\u5173\u4e4b\u57fa\u56e0\u5e8f\u5217\u4fe1\u606f\u7684\uff08\u53d1\u8868\u3001\u5168\u5c40\u552f\u4e00\u6807\u8bc6\u7b26\u3001\u7edf\u4e00\u8d44\u6e90\u6807\u8bc6\u7b26\u7b49\uff09\u6807\u8bc6\u7b26\u4e4b\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u5217\u8868\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m005",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "text",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "text"
#         },
#         {
#           "@language": "es",
#           "@value": "Taxones asociados"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u76f8\u5173\u7c7b\u7fa4"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media type for text"
#         },
#         {
#           "@language": "es",
#           "@value": "Una lista (concatenada y separada) de los identificadores o nombres de taxones y su asociaci\u00f3n con el Registro Biol\u00f3gico."
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u4e0e\u53d1\u73b0\u60c5\u51b5\u76f8\u5173\u7684\u6807\u8bc6\u7b26\u6216\u5206\u7c7b\u5355\u5143\u540d\u79f0\u4e4b\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u5217\u8868\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m006",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "video",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "video"
#         },
#         {
#           "@language": "es",
#           "@value": "Base del registro"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u8bb0\u5f55\u57fa\u7840"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media type for video"
#         },
#         {
#           "@language": "es",
#           "@value": "La naturaleza espec\u00edfica del registro de datos - un subtipo de Tipo.\u00a0La pr\u00e1ctica recomendada es el uso de lenguaje controlado como el vocabulario controlado para Tipo de Darwin Core (http://rs.tdwg.org/dwc/terms/type-vocabulary/index.htm). "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u6570\u636e\u8bb0\u5f55\u7684\u7279\u6709\u5c5e\u6027\u2014\u2014dcterms:type\u7684\u5b50\u7c7b\u3002\u5efa\u8bae\u6700\u597d\u4f7f\u7528\u63a7\u5236\u6027\u8bcd\u6c47\uff0c\u5982\u8fbe\u5c14\u6587\u6838\u5fc3\u7c7b\u578b\u8bcd\u6c47\uff08http://rs.tdwg.org/dwc/terms/type-vocabulary/index.htm\uff09\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m007",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "image/png",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m003",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "PNG"
#         },
#         {
#           "@language": "es",
#           "@value": "Capa"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5ca9\u5e8a"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for portable network graphics images"
#         },
#         {
#           "@language": "es",
#           "@value": "El nombre completo de la capa litoestratigr\u00e1fica de la cual se colect\u00f3 el elemento catalogado. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u91c7\u96c6\u6536\u5f55\u5bf9\u8c61\u7684\u5ca9\u5e8a\u7684\u5168\u79f0\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m008",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "image/jpeg",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m003",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "JPEG"
#         },
#         {
#           "@language": "es",
#           "@value": "Comportamiento"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u884c\u4e3a"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for JPEG images"
#         },
#         {
#           "@language": "es",
#           "@value": "Una descripci\u00f3n de la conducta mostrada por el sujeto en el momento del Registro Biol\u00f3gico.\u00a0La pr\u00e1ctica recomendada es el uso de un lenguaje controlado."
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5bf9\u8bb0\u5f55\u53d1\u73b0\u8fc7\u7a0b\u4e2d\u76ee\u6807\u884c\u4e3a\u7684\u63cf\u8ff0\u3002\u5efa\u8bae\u6700\u597d\u4f7f\u7528\u63a7\u5236\u6027\u8bcd\u6c47\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m009",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "image/bmp",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m003",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "BMP"
#         },
#         {
#           "@language": "es",
#           "@value": "N\u00famero de cat\u00e1logo"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u76ee\u5f55\u7f16\u53f7"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for bitmap images"
#         },
#         {
#           "@language": "es",
#           "@value": "Un identificador (preferiblemente \u00fanico) para el registro dentro del conjunto de datos o colecci\u00f3n. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u6570\u636e\u96c6\u6216\u4fdd\u85cf\u4fe1\u606f\u4e2d\u7684\u8bb0\u5f55\u6807\u8bc6\u7b26\uff08\u6700\u597d\u662f\u552f\u4e00\u7684\uff09\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m010",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "image/gif",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m003",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "GIF"
#         },
#         {
#           "@language": "es",
#           "@value": "Clase"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u7eb2"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for GIF images"
#         },
#         {
#           "@language": "es",
#           "@value": "El nombre cient\u00edfico completo de la clase en la que se clasifica el tax\u00f3n."
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5206\u7c7b\u5355\u5143\u6240\u5c5e\u7eb2\u7684\u5b8c\u6574\u5b66\u540d\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m011",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "image/tiff",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m003",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "TIFF"
#         },
#         {
#           "@language": "es",
#           "@value": "C\u00f3digo de la colecci\u00f3n"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u4fdd\u85cf\u4ee3\u7801"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for TIFF images"
#         },
#         {
#           "@language": "es",
#           "@value": "El nombre, acr\u00f3nimo, coden, o iniciales que identifican la colecci\u00f3n o conjunto de datos del que procede el registro. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u6807\u8bc6\u751f\u6210\u8bb0\u5f55\u7684\u4fdd\u85cf\u4fe1\u606f\u6216\u6570\u636e\u96c6\u7684\u540d\u79f0\u3001\u9996\u5b57\u6bcd\u7f29\u7565\u8bcd\u3001\u5206\u7c7b\u7f16\u53f7\u6216\u8bcd\u8d77\u9996\u5b57\u6bcd"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m012",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "video/mp4",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m006",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "MP4 video"
#         },
#         {
#           "@language": "es",
#           "@value": "ID de la colecci\u00f3n"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u4fdd\u85cf\u7f16\u53f7"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for MP4 videos"
#         },
#         {
#           "@language": "es",
#           "@value": "Un identificador de la colecci\u00f3n o conjunto de datos del que procede el registro. Para espec\u00edmenes f\u00edsicos, la pr\u00e1ctica recomendada es utilizar el identificador de un \u00edndice de colecci\u00f3n tal como el \u00cdndice de Colecciones de Biodiversidad (http://www.biodi"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u751f\u6210\u8bb0\u5f55\u7684\u4fdd\u85cf\u4fe1\u606f\u6216\u6570\u636e\u96c6\u7684\u6807\u8bc6\u7b26\u3002\u9488\u5bf9\u5b9e\u4f53\u6807\u672c\uff0c\u5efa\u8bae\u6700\u597d\u4f7f\u7528\u4fdd\u85cf\u6ce8\u518c\u6807\u8bc6\u7b26\uff0c\u5982\u751f\u7269\u591a\u6837\u6027\u4fdd\u85cf\u7d22\u5f15(http://www.biodiversitycollectionsindex.org/)\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m013",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "video/mpeg",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m006",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "MPEG"
#         },
#         {
#           "@language": "es",
#           "@value": "Continente"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u6d32"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for MPEG videos"
#         },
#         {
#           "@language": "es",
#           "@value": "El nombre del continente en el que la ubicaci\u00f3n ocurre.\u00a0La pr\u00e1ctica recomendada es el uso de un lenguaje controlado, como la norma ISO 3166 de c\u00f3digos de Continente. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u53d1\u73b0\u5730\u70b9\u6240\u5728\u7684\u5927\u6d32\u540d\u3002\u5efa\u8bae\u6700\u597d\u4f7f\u7528\u63a7\u5236\u6027\u8bcd\u6c47\uff0c\u5982\u76d6\u63d0\u5730\u7406\u540d\u79f0\u7d22\u5f15\u5178\u6216\u56fd\u9645\u6807\u51c6\u5316\u7ec4\u7ec73166\u6d32\u4ee3\u7801\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m014",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "video/quicktime",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m006",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "QuickTime"
#         },
#         {
#           "@language": "es",
#           "@value": "Precisi\u00f3n de las coordenadas"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5750\u6807\u7cbe\u5ea6"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for QuickTime videos"
#         },
#         {
#           "@language": "es",
#           "@value": "Una representaci\u00f3n decimal de la precisi\u00f3n de las coordenadas provistas en Latitud Decimal y Longitud Decimal. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u7cbe\u786e\u5230\u5c0f\u6570\u7684\u7eac\u5ea6\u548c\u7ecf\u5ea6\u5750\u6807\u7684\u5c0f\u6570\u793a\u6570\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m015",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "audio/mp4",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m002",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "MP4 audio"
#         },
#         {
#           "@language": "es",
#           "@value": " Incertidumbre de las coordenadas en metros"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5750\u6807\u4e0d\u786e\u5b9a\u6027\uff08\u4ee5\u7c73\u4e3a\u5355\u4f4d\uff09"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for MP4 audio"
#         },
#         {
#           "@language": "es",
#           "@value": "La distancia horizontal (en metros) de la Latitud Decimal y Longitud Decimal provistas describiendo el c\u00edrculo m\u00e1s peque\u00f1o que contiene la totalidad de la ubicaci\u00f3n.\u00a0Deje el valor vac\u00edo si la incertidumbre es desconocida, no se puede estimar, o no es apli"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5230\u6db5\u76d6\u6574\u4e2a\u5730\u70b9\u7684\u6700\u5c0f\u5706\u5f62\u533a\u57df\u7684\u5c0f\u6570\u7eac\u5ea6\u548c\u7ecf\u5ea6\u7684\u6c34\u5e73\u8ddd\u79bb\uff08\u4ee5\u201c\u7c73\u201d\u4e3a\u5355\u4f4d\uff09\u3002\u82e5\u672a\u77e5\u3001\u65e0\u6cd5\u4f30\u7b97\u6216\u4e0d\u9002\u7528\uff08\u7531\u4e8e\u6ca1\u6709\u5750\u6807\uff09\uff0c\u5219\u503c\u4e3a\u7a7a\u3002\u6b64\u9879\u4e2d0\u4e0d\u662f\u6709\u6548\u503c\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m016",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "audio/mpeg",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m002",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "MP3"
#         },
#         {
#           "@language": "es",
#           "@value": "Pa\u00eds"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u56fd\u5bb6"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for MP3 audio"
#         },
#         {
#           "@language": "es",
#           "@value": "El nombre del pa\u00eds o unidad administrativa de mayor jerarqu\u00eda de la ubicaci\u00f3n.\u00a0La pr\u00e1ctica recomendada es utilizar un identificador persistente de un lenguaje controlado como el Tesauro Getty de Nombres Geogr\u00e1ficos. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u53d1\u73b0\u5730\u70b9\u7684\u56fd\u5bb6\u6216\u4e3b\u8981\u884c\u653f\u533a\u5212\u540d\u79f0\u3002\u5efa\u8bae\u6700\u597d\u4f7f\u7528\u63a7\u5236\u6027\u8bcd\u6c47\uff0c\u5982\u76d6\u63d0\u5730\u7406\u540d\u79f0\u7d22\u5f15\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m017",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "model/x3d-vrml",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m004",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "X3D VRML"
#         },
#         {
#           "@language": "es",
#           "@value": "C\u00f3digo del pa\u00eds"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u56fd\u5bb6\u4ee3\u7801"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for X3D VRML models"
#         },
#         {
#           "@language": "es",
#           "@value": "El c\u00f3digo est\u00e1ndar para el pa\u00eds de la ubicaci\u00f3n.\u00a0La pr\u00e1ctica recomendada es el uso de ISO 3166-1-alfa-2 de c\u00f3digos de pa\u00edses. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u53d1\u73b0\u5730\u70b9\u7684\u6807\u51c6\u56fd\u5bb6\u4ee3\u7801\u3002\u5efa\u8bae\u6700\u597d\u4f7f\u7528\u56fd\u9645\u6807\u51c6\u5316\u7ec4\u7ec73166-1-\u963f\u5c14\u6cd5-2\u56fd\u5bb6\u4ee3\u7801\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m018",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "application/pdf",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m001",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "PDF"
#         },
#         {
#           "@language": "es",
#           "@value": "Condado"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u90e1/\u53bf"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for PDF documents"
#         },
#         {
#           "@language": "es",
#           "@value": "El nombre completo, sin abreviar de la siguiente regi\u00f3n administrativa de menor jerarqu\u00eda que Estado Provincia (condado, departamento, etc.) de la ubicaci\u00f3n."
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u53d1\u73b0\u5730\u70b9\u6240\u5728\u7684\u9664\u5dde/\u7701\u4e4b\u5916\u7684\u6b21\u4e00\u7ea7\u884c\u653f\u533a\u5212\uff08\u53bf\u3001\u90e1\u3001\u884c\u653f\u533a\u7b49\uff09\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m019",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "text/plain",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m005",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "plain text"
#         },
#         {
#           "@language": "es",
#           "@value": "Generalizaci\u00f3n de los datos"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u6570\u636e\u6982\u62ec"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for plain text"
#         },
#         {
#           "@language": "es",
#           "@value": "Las medidas adoptadas para que los datos compartidos sean menos espec\u00edficos o completos que en su forma original.\u00a0Sugiere que datos alternativos de mayor calidad pueden estar disponibles bajo petici\u00f3n."
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u4e3a\u4f7f\u5171\u4eab\u6570\u636e\u8f83\u4e4b\u5176\u539f\u59cb\u5f62\u5f0f\u4e0d\u90a3\u4e48\u7cbe\u786e\u6216\u5b8c\u6574\u6240\u91c7\u53d6\u7684\u884c\u52a8\u3002\u5efa\u8bae\u4ee5\u66f4\u9ad8\u8d28\u91cf\u7684\u66ff\u4ee3\u6570\u636e\u5907\u7d22\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m020",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "application/msword",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m001",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "Word (pre-2003) document"
#         },
#         {
#           "@language": "es",
#           "@value": "ID del conjunto de datos"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u6570\u636e\u96c6\u7f16\u53f7"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for Microsoft Word (2003 and before) documents"
#         },
#         {
#           "@language": "es",
#           "@value": "Un identificador para el conjunto de datos.\u00a0Puede ser un identificador \u00fanico global o un identificador espec\u00edfico de una colecci\u00f3n o instituci\u00f3n."
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u6570\u636e\u96c6\u7684\u6807\u8bc6\u7b26\u3002\u53ef\u80fd\u662f\u4e00\u4e2a\u5168\u5c40\u552f\u4e00\u6807\u8bc6\u7b26\u6216\u4e00\u4e2a\u4fdd\u85cf\u4e2d\u5fc3\u6216\u7814\u7a76\u673a\u6784\u7684\u7279\u5b9a\u6807\u8bc6\u7b26\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m021",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "application/vnd.openxmlformats-officedocument.wordprocessingml.document",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m001",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "Word (post-2007) document"
#         },
#         {
#           "@language": "es",
#           "@value": "Nombre del conjunto de datos"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u6570\u636e\u96c6\u540d\u79f0"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for Microsoft Word (2007 and after) documents"
#         },
#         {
#           "@language": "es",
#           "@value": "El nombre que identifica el conjunto de datos del cual se deriv\u00f3 el registro.  "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u6807\u8bc6\u751f\u6210\u8bb0\u5f55\u7684\u6570\u636e\u96c6\u7684\u540d\u79f0\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m022",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "image/x-adobe-dng",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m003",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "Digital Negative"
#         },
#         {
#           "@language": "es",
#           "@value": "Fecha de identificaci\u00f3n"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u9274\u5b9a\u65e5\u671f"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for Digital Negative images"
#         },
#         {
#           "@language": "es",
#           "@value": "La fecha en que fue identificado el sujeto como representativo del tax\u00f3n.\u00a0La pr\u00e1ctica recomendada es utilizar un esquema de codificaci\u00f3n, como ISO 8601:2004 (E). "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u6d89\u53ca\u88ab\u89c6\u4e3a\u4ee3\u8868\u5206\u7c7b\u5355\u5143\u7684\u4e3b\u4f53\u7684\u6570\u636e\u3002\u5efa\u8bae\u6700\u597d\u4f7f\u7528\u7f16\u7801\u65b9\u6848\uff0c\u5982ISO 8601:2004(E)\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m023",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "image/x-canon-cr2",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m003",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "CR2"
#         },
#         {
#           "@language": "es",
#           "@value": "D\u00eda"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5929"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for Canon Raw images"
#         },
#         {
#           "@language": "es",
#           "@value": "El d\u00eda en n\u00fameros enteros, del mes en que ocurri\u00f3 el evento. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u4e8b\u4ef6\u53d1\u751f\u7684\u6574\u6570\u5929\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m024",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "image/jp2",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m003",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "JPEG 2000"
#         },
#         {
#           "@language": "es",
#           "@value": "Latitud decimal"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5341\u8fdb\u5236\u7eac\u5ea6"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for JPEG 2000 images"
#         },
#         {
#           "@language": "es",
#           "@value": "La latitud geogr\u00e1fica (en grados decimales, utilizando el sistema de referencia espacial provisto en Datum Geod\u00e9sico) del centro geogr\u00e1fico de una ubicaci\u00f3n.\u00a0Los valores positivos se encuentran al norte del ecuador, los valores negativos est\u00e1n al sur del "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5730\u70b9\u7684\u5730\u7406\u4e2d\u5fc3\u7684\u7eac\u5ea6\uff08\u4ee5\u5c0f\u6570\u8868\u793a\uff0c\u91c7\u7528\u5927\u5730\u57fa\u51c6\u4e2d\u63d0\u4f9b\u7684\u7a7a\u95f4\u53c2\u7167\u7cfb\u7edf\uff09\u3002\u6b63\u503c\u4ee3\u8868\u8d64\u9053\u4ee5\u5317\uff0c\u8d1f\u503c\u4ee3\u8868\u8d64\u9053\u4ee5\u5357\u3002\u6cd5\u5b9a\u503c\u4ecb\u4e8e-90\u81f390\uff08\u542b\uff09\u4e4b\u95f4\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m025",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "audio/vnd.wave",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m002",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "WAVE"
#         },
#         {
#           "@language": "es",
#           "@value": "Longitud decimal"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5341\u8fdb\u5236\u7ecf\u5ea6"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for WAVE audio"
#         },
#         {
#           "@language": "es",
#           "@value": "La longitud geogr\u00e1fica (en grados decimales, mediante el sistema de referencia espacial provisto en Datum Geod\u00e9sico) del centro geogr\u00e1fico de un lugar.\u00a0Los valores positivos se encuentran al este del meridiano de Greenwich, los valores negativos se encuen"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5730\u70b9\u7684\u5730\u7406\u4e2d\u5fc3\u7684\u7ecf\u5ea6\uff08\u4ee5\u5c0f\u6570\u8868\u793a\uff0c\u91c7\u7528\u5927\u5730\u57fa\u51c6\u4e2d\u63d0\u4f9b\u7684\u7a7a\u95f4\u53c2\u7167\u7cfb\u7edf\uff09\u3002\u6b63\u503c\u4ee3\u8868\u683c\u6797\u5a01\u6cbb\u5b50\u5348\u7ebf\u4ee5\u897f\uff0c\u8d1f\u503c\u4ee3\u8868\u683c\u6797\u5a01\u6cbb\u5b50\u5348\u7ebf\u4ee5\u4e1c\u3002\u6cd5\u5b9a\u503c\u4ecb\u4e8e-180\u81f3180\uff08\u542b\uff09\u4e4b\u95f4\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m026",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "image/x-nikon-nef",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m003",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "Nikon NEF Raw"
#         },
#         {
#           "@language": "es",
#           "@value": "Disposici\u00f3n"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5bc4\u5b58"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for Nikon NEF Raw images"
#         },
#         {
#           "@language": "es",
#           "@value": "El estado actual de un esp\u00e9cimen con respecto a la colecci\u00f3n identificada en C\u00f3digo de la Colecci\u00f3n o ID de la Colecci\u00f3n.\u00a0La pr\u00e1ctica recomendada es el uso de un lenguaje controlado. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u4e0e\u786e\u5b9a\u4e86\u4fdd\u85cf\u4ee3\u7801\u6216\u4fdd\u85cf\u8bc6\u522b\u7801\u7684\u4fdd\u85cf\u7269\u76f8\u5173\u7684\u6807\u672c\u7684\u5f53\u524d\u72b6\u6001\u3002\u63a8\u8350\u4f7f\u7528\u63a7\u5236\u8bcd\u8868\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m027",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "video/x-m4v",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m006",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "M4V"
#         },
#         {
#           "@language": "es",
#           "@value": "Propiedades din\u00e1micas"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u52a8\u6001\u5c5e\u6027"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for Apple M4V videos"
#         },
#         {
#           "@language": "es",
#           "@value": "Una lista (concatenada y separada) de las medidas, hechos, caracter\u00edsticas, o aseveraciones adicionales sobre el registro. Su intenci\u00f3n es proporcionar un mecanismo para contenido estructurado como pares de valor.  "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5173\u4e8e\u8bb0\u5f55\u7684\u5176\u4ed6\u6d4b\u91cf\u3001\u60c5\u51b5\u3001\u7279\u5f81\u3001\u5224\u5b9a\u7b49\u4fe1\u606f\u7684\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u5217\u8868\u3002\u610f\u5728\u4e3a\u8bf8\u5982\u952e\u503c\u5bf9\u7b49\u7684\u7ed3\u6784\u5316\u5185\u5bb9\u8bbe\u7acb\u673a\u5236\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m028",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "\u200evideo/3gpp",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m006",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "3GPP"
#         },
#         {
#           "@language": "es",
#           "@value": "Edad temprana o estad\u00edo inferior"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u6700\u65e9\u5730\u8d28\u5e74\u4ee3\u6216\u6700\u4f4e\u5e74\u4ee3\u5730\u5c42"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for 3GPP video"
#         },
#         {
#           "@language": "es",
#           "@value": "El nombre completo de la edad geocronol\u00f3gica m\u00e1s temprana posible o la etapa cronoestratigr\u00e1fica m\u00e1s baja, atribuible al horizonte estratigr\u00e1fico donde se recolect\u00f3 el objeto catalogado. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u7f16\u76ee\u9879\u6240\u91c7\u96c6\u7684\u5730\u5c42\u5c42\u4f4d\u6240\u5c5e\u4e4b\u53ef\u80fd\u7684\u6700\u65e9\u7684\u5730\u8d28\u5e74\u4ee3\u6216\u6700\u4f4e\u7684\u5e74\u4ee3\u5730\u5c42\u7684\u5168\u79f0\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m029",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "video/vnd.avi",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m006",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "AVI"
#         },
#         {
#           "@language": "es",
#           "@value": "E\u00f3n temprano o eonotema inferior"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u6700\u65e9\u5730\u8d28\u5b99\u6216\u6700\u4f4e\u5730\u5c42\u5b87"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for AVI video"
#         },
#         {
#           "@language": "es",
#           "@value": "El nombre completo del e\u00f3n geocronol\u00f3gico m\u00e1s temprano o el eratema crono-estratigr\u00e1fico m\u00e1s bajo, o el nombre informal (\"Prec\u00e1mbrico\") atribuible al horizonte estratigr\u00e1fico donde se recolect\u00f3 el objeto catalogado. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u7f16\u76ee\u9879\u6240\u91c7\u96c6\u7684\u5730\u5c42\u5c42\u4f4d\u6240\u5c5e\u4e4b\u53ef\u80fd\u7684\u6700\u65e9\u7684\u5730\u8d28\u5b99\u6216\u6700\u4f4e\u7684\u5730\u5c42\u5b87\u7684\u5168\u79f0\u6216\u975e\u6b63\u5f0f\u540d\u79f0\uff08\u201c\u524d\u5bd2\u6b66\u7eaa\u201d\uff09\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m030",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "audio/AMR",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m002",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "AMR"
#         },
#         {
#           "@language": "es",
#           "@value": "\u00c9poca temprana o serie inferior"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u6700\u65e9\u5730\u8d28\u4e16\u6216\u6700\u4f4e\u5730\u5c42\u7edf"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for Adaptive Multi-Rate audio"
#         },
#         {
#           "@language": "es",
#           "@value": "El nombre completo de la \u00e9poca geocronol\u00f3gica m\u00e1s temprana o la serie cronoestratigr\u00e1fica m\u00e1s baja posible, atribuible al horizonte estratigr\u00e1fico donde se recolect\u00f3 el objeto catalogado. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u7f16\u76ee\u9879\u6240\u91c7\u96c6\u7684\u5730\u5c42\u5c42\u4f4d\u6240\u5c5e\u4e4b\u53ef\u80fd\u7684\u6700\u65e9\u7684\u5730\u8d28\u4e16\u6216\u6700\u4f4e\u7684\u5730\u5c42\u7edf\u7684\u5168\u79f0\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m031",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "audio/x-aiff",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m002",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "AIFF"
#         },
#         {
#           "@language": "es",
#           "@value": "Era temprana o eratema inferior"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u6700\u65e9\u5730\u8d28\u4ee3\u6216\u6700\u4f4e\u5730\u5c42\u754c"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for Audio Interchange File Format audio"
#         },
#         {
#           "@language": "es",
#           "@value": "El nombre completo de la era geocronol\u00f3gica m\u00e1s temprana o el eratema crono-estratigr\u00e1fico m\u00e1s bajo, atribuible al horizonte estratigr\u00e1fico donde se recolect\u00f3 el objeto catalogado. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u7f16\u76ee\u9879\u6240\u91c7\u96c6\u7684\u5730\u5c42\u5c42\u4f4d\u6240\u5c5e\u4e4b\u53ef\u80fd\u7684\u6700\u65e9\u7684\u5730\u8d28\u4ee3\u6216\u6700\u4f4e\u7684\u5730\u5c42\u754c\u7684\u5168\u79f0\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m032",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "audio/ogg",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m002",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "OGG audio"
#         },
#         {
#           "@language": "es",
#           "@value": "Periodo temprano o sistema inferior"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u6700\u65e9\u5730\u8d28\u7eaa\u6216\u6700\u4f4e\u5730\u5c42\u7cfb"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for OGG audio"
#         },
#         {
#           "@language": "es",
#           "@value": "Puede corresponder a: a) un indicador de la existencia de, b) una referencia a (publicaci\u00f3n, URI), o c) el texto de las notas tomadas en campo sobre el evento."
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u7f16\u76ee\u9879\u6240\u91c7\u96c6\u7684\u5730\u5c42\u5c42\u4f4d\u6240\u5c5e\u4e4b\u53ef\u80fd\u7684\u6700\u65e9\u7684\u5730\u8d28\u7eaa\u6216\u6700\u4f4e\u7684\u5730\u5c42\u7cfb\u7684\u5168\u79f0\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m033",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "video/ogg",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m006",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "OGG video"
#         },
#         {
#           "@language": "es",
#           "@value": "D\u00eda final del a\u00f1o"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5f53\u5e74\u7ed3\u675f\u65e5"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for OGG video"
#         },
#         {
#           "@language": "es",
#           "@value": "El \u00faltimo d\u00eda ordinal del a\u00f1o en que ocurri\u00f3 el evento (1 para el 1\u00ba de enero, 365 para el 31 de diciembre, excepto en un a\u00f1o bisiesto, en cuyo caso es 366)."
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u4e8b\u4ef6\u53d1\u751f\u5f53\u5e74\u7684\u6700\u65b0\u65e5\u671f\u53f7\uff08\u9664\u4e86\u95f0\u5e74\u6709366\u5929\u7684\u60c5\u51b5\uff0c1\u4ee3\u88681\u67081\u65e5\uff0c365\u4ee3\u886812\u670831\u65e5\uff09\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m034",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "application/ogg",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m001",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "OGG multiplex"
#         },
#         {
#           "@language": "es",
#           "@value": "Medios de establecimiento"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u786e\u5b9a\u65b9\u6cd5"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for OGG multiplex"
#         },
#         {
#           "@language": "es",
#           "@value": "El proceso por el cual el individuo(s) biol\u00f3gico(s) representado en el Registro Biol\u00f3gico se estableci\u00f3 en el lugar.\u00a0La pr\u00e1ctica recomendada es el uso de un lenguaje controlado. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5728\u91c7\u96c6\u5730\u70b9\u786e\u5b9a\u751f\u7269\u4e2a\u4f53\u5728\u4e8b\u4ef6\u4e2d\u8868\u73b0\u7684\u8fc7\u7a0b\u3002\u5efa\u8bae\u6700\u4f73\u505a\u6cd5\u662f\u4f7f\u7528\u4e00\u4e2a\u63a7\u5236\u6027\u8bcd\u6c47\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/m035",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "image/x-photo-cd",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/m",
#       "skos:broader": "http://rs.tdwg.org/format/values/m003",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "Kodak Photo CD image"
#         },
#         {
#           "@language": "es",
#           "@value": "Fecha del evento"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u4e8b\u4ef6\u65e5\u671f"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "media subtype for Kodak Photo CD image"
#         },
#         {
#           "@language": "es",
# ...
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5728\u76f8\u5173\u7684\u547d\u540d\u89c4\u5219\u4e0b\uff0c\u786e\u5b9a\u6700\u521d\u5b66\u540d\u7684\u51fa\u7248\u53c2\u8003\u7269\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/e037",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "obj",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/e",
#       "skos:exactMatch": "http://rs.tdwg.org/format/values/m062",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "OBJ"
#         },
#         {
#           "@language": "es",
#           "@value": "ID del nombre publicado en"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u540d\u79f0\u53d1\u5e03\u7f16\u53f7"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "file extension for OBJ"
#         },
#         {
#           "@language": "es",
#           "@value": "Un identificador de la publicaci\u00f3n en que se estableci\u00f3 originalmente Nombre cient\u00edfico bajo las reglas del C\u00f3digo nomenclatural asociado. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5728\u76f8\u5173\u7684\u547d\u540d\u89c4\u5219\u4e0b\uff0c\u786e\u5b9a\u6700\u521d\u5b66\u540d\u7684\u51fa\u7248\u7269\u6807\u8bc6\u7b26\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/e038",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "glb",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/e",
#       "skos:exactMatch": "http://rs.tdwg.org/format/values/m063",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "gLTF binary"
#         },
#         {
#           "@language": "es",
#           "@value": "Nombre publicado en a\u00f1o"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u540d\u79f0\u53d1\u5e03\u5e74\u4efd"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "file extension for Binary GL Transmission Format"
#         },
#         {
#           "@language": "es",
#           "@value": "El a\u00f1o de cuatro d\u00edgitos en el que se public\u00f3 el Nombre cient\u00edfico. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5b66\u540d\u53d1\u5e03\u7684\u56db\u4f4d\u516c\u5386\u5e74\u4efd\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/e039",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "gltf",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/e",
#       "skos:exactMatch": "http://rs.tdwg.org/format/values/m064",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "gLTF"
#         },
#         {
#           "@language": "es",
#           "@value": "C\u00f3digo nomenclatural"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u547d\u540d\u51c6\u5219"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "file extension for GL Transmission Format"
#         },
#         {
#           "@language": "es",
#           "@value": "El c\u00f3digo de nomenclatura (o c\u00f3digos en el caso de un nombre ambireinal) en virtud del cual se construye el Nombre Cient\u00edfico.\u00a0La pr\u00e1ctica recomendada es el uso de un lenguaje controlado. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u521b\u5efa\u5b66\u540d\u6240\u9075\u5faa\u7684\u547d\u540d\u51c6\u5219\u3002\u5efa\u8bae\u6700\u4f73\u505a\u6cd5\u662f\u4f7f\u7528\u4e00\u4e2a\u63a7\u5236\u6027\u8bcd\u6c47\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/e040",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "wrl",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/e",
#       "skos:exactMatch": "http://rs.tdwg.org/format/values/m065",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "VRML"
#         },
#         {
#           "@language": "es",
#           "@value": "Estado nomenclatural"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u547d\u540d\u72b6\u6001"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "file extension for Virtual Reality Modeling Language"
#         },
#         {
#           "@language": "es",
#           "@value": "El estatus relacionado con la publicaci\u00f3n original del nombre y su conformidad con las normas pertinentes de nomenclatura.\u00a0Se basa esencialmente en un algoritmo de acuerdo a las reglas de negociaci\u00f3n del c\u00f3digo.\u00a0No requiere opini\u00f3n taxon\u00f3mica. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u4e0e\u540d\u79f0\u7684\u6700\u521d\u51fa\u7248\u7269\u76f8\u5173\u7684\u72b6\u6001\u53ca\u4e0e\u547d\u540d\u76f8\u5173\u89c4\u5219\u7684\u4e00\u81f4\u6027\u3002\u672c\u8d28\u4e0a\u57fa\u4e8e\u4e00\u4e2a\u6839\u636e\u4e1a\u52a1\u89c4\u5219\u4ee3\u7801\u7684\u7b97\u6cd5\uff0c\u4e0d\u9700\u8981\u5206\u7c7b\u7684\u610f\u89c1\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/e041",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "dcm",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/e",
#       "skos:exactMatch": "http://rs.tdwg.org/format/values/m066",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "DICOM"
#         },
#         {
#           "@language": "es",
#           "@value": "ID del registro biol\u00f3gico"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u4e8b\u4ef6\u7f16\u53f7"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "file extension for Digital Imaging and Communications in Medicine"
#         },
#         {
#           "@language": "es",
#           "@value": "Un identificador del Registro biol\u00f3gico (a cambio de un registro digital particular del Registro biol\u00f3gico).\u00a0En ausencia de un identificador \u00fanico global persistente, se debe construir uno a partir de una combinaci\u00f3n de identificadores en el registro de m"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u4e00\u4e2a\u4e8b\u4ef6\u7684\u6807\u8bc6\u7b26\uff08\u5e76\u975e\u4e00\u4e2a\u4e8b\u4ef6\u7684\u5177\u4f53\u6570\u5b57\u8bb0\u5f55\uff09\u3002\u5728\u7f3a\u4e4f\u5168\u5c40\u552f\u4e00\u6807\u8bc6\u7b26\u7684\u60c5\u51b5\u4e0b\uff0c\u4ece\u6700\u63a5\u8fd1\u5168\u5c40\u552f\u4e00\u4e8b\u4ef6\u7f16\u53f7\u7684\u8bb0\u5f55\u4e2d\u6784\u5efa\u4e00\u4e2a\u6807\u8bc6\u7b26\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/e042",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "mtl",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/e",
#       "skos:exactMatch": "http://rs.tdwg.org/format/values/m067",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "MTL"
#         },
#         {
#           "@language": "es",
#           "@value": "Comentarios del registro biol\u00f3gico"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u4e8b\u4ef6\u5907\u6ce8"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "file extension for OBJ Material Template Library"
#         },
#         {
#           "@language": "es",
#           "@value": "Comentarios o anotaciones sobre el Registro Biol\u00f3gico. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5173\u4e8e\u8fd9\u4e2a\u4e8b\u4ef6\u7684\u8bc4\u8bba\u548c\u6ce8\u91ca\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/e043",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "x3dv",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/e",
#       "skos:exactMatch": "http://rs.tdwg.org/format/values/m017",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "X3D VRML"
#         },
#         {
#           "@language": "es",
#           "@value": "Estado del registro biol\u00f3gico"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u4e8b\u4ef6\u72b6\u6001"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "file extension for X3D VRML models"
#         },
#         {
#           "@language": "es",
#           "@value": "Una declaraci\u00f3n sobre la presencia o ausencia de un tax\u00f3n en una ubicaci\u00f3n.\u00a0La pr\u00e1ctica recomendada es el uso de un lenguaje controlado. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5173\u4e8e\u4e00\u4e2a\u7c7b\u7fa4\u5728\u4e00\u4e2a\u5730\u70b9\u5b58\u5728\u6216\u8005\u4e0d\u5b58\u5728\u7684\u58f0\u660e\u3002\u5efa\u8bae\u6700\u4f73\u505a\u6cd5\u662f\u4f7f\u7528\u4e00\u4e2a\u63a7\u5236\u6027\u8bcd\u6c47\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/e044",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "x3d",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/e",
#       "skos:exactMatch": "http://rs.tdwg.org/format/values/m068",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "X3D XML"
#         },
#         {
#           "@language": "es",
#           "@value": "Orden"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u76ee"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "file extension for X3D XML models"
#         },
#         {
#           "@language": "es",
#           "@value": "El nombre cient\u00edfico completo del orden en el que se clasifica el tax\u00f3n. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5206\u7c7b\u5355\u5143\u6240\u5c5e\u76ee\u7684\u5b8c\u6574\u5b66\u540d\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/e045",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "crw",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/e",
#       "skos:exactMatch": "http://rs.tdwg.org/format/values/m069",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "CIFF raw image"
#         },
#         {
#           "@language": "es",
#           "@value": "Uso del nombre original"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u6700\u521d\u4f7f\u7528\u540d\u79f0"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "file extension for Camera Image File Format raw image"
#         },
#         {
#           "@language": "es",
#           "@value": "El nombre del tax\u00f3n, con informaci\u00f3n de autor\u00eda y fecha si se conoce, tal como apareci\u00f3 originalmente cuando se estableci\u00f3 por primera vez bajo las reglas del C\u00f3digo Nomenclatural asociadas.\u00a0El basi\u00f3nimo (bot\u00e1nica) o basi\u00f3nimo (bacteriolog\u00eda) de Nombre Ci"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5728\u76f8\u5173\u7684\u547d\u540d\u89c4\u5219\u4e0b\u7b2c\u4e00\u6b21\u88ab\u5efa\u7acb\u7684\u6700\u521d\u51fa\u73b0\u7684\u7c7b\u7fa4\u540d\u79f0\uff0c\u5982\u679c\u77e5\u9053\u7684\u8bdd\uff0c\u9644\u4f5c\u8005\u548c\u65e5\u671f\u4fe1\u606f\u3002\u5b66\u540d\u7684\u5f02\u540d\u6216\u57fa\u540d\uff0c\u6216\u7528\u6765\u66ff\u6362\u540d\u79f0\u7684\u540c\u97f3\u8bcd\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/e046",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "cr3",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/e",
#       "skos:exactMatch": "http://rs.tdwg.org/format/values/m070",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "CR3 raw image"
#         },
#         {
#           "@language": "es",
#           "@value": "ID del uso del nombre original"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u6700\u521d\u4f7f\u7528\u540d\u79f0\u7f16\u53f7"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "file extension for Canon Raw 3 image"
#         },
#         {
#           "@language": "es",
#           "@value": "Un identificador para el uso del nombre (significado documentado del nombre de acuerdo a una fuente) en el que se estableci\u00f3 originalmente, el elemento terminal de Nombre Cient\u00edfico bajo las reglas del C\u00f3digo Nomenclatural asociado. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5b66\u540d\u5728\u76f8\u5173\u547d\u540d\u89c4\u5219\u4e0b\u6700\u521d\u5efa\u7acb\u65f6\uff0c\u5b66\u540d\u7684\u672b\u7aef\u7ec4\u6210\u4e0a\u7684\u540d\u79f0\u4f7f\u7528\u6807\u8bc6\u7b26\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/e047",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "arw",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/e",
#       "skos:exactMatch": "http://rs.tdwg.org/format/values/m071",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "ARW raw image"
#         },
#         {
#           "@language": "es",
#           "@value": "Otros n\u00fameros de cat\u00e1logo"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u5176\u5b83\u76ee\u5f55\u7f16\u53f7"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "file extension for Sony raw image"
#         },
#         {
#           "@language": "es",
#           "@value": "Una lista (concatenada y separada) de n\u00fameros de cat\u00e1logos anteriores o alternativos, calificados, u otros identificadores de uso humano para el mismo Registro Biol\u00f3gico, ya sea en el actual o cualquier otro conjunto de datos o colecci\u00f3n. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u65e0\u8bba\u5728\u5f53\u524d\u6216\u5176\u4ed6\u4efb\u4f55\u6570\u636e\u96c6\uff0c\u540c\u4e00\u4e8b\u4ef6\u4e2d\u4ee5\u524d\u6216\u5907\u7528\u7684\u5b8c\u5168\u5408\u683c\u7684\u76ee\u5f55\u53f7\u6216\u5176\u4ed6\u4eba\u4f7f\u7528\u7684\u6807\u8bc6\u7b26\u5217\u8868\uff08\u8fde\u63a5\u7684\u6216\u5206\u5f00\u7684\uff09\u3002"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/format/values/e048",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "rw2",
#       "skos:inScheme": "http://rs.tdwg.org/format/values/e",
#       "skos:exactMatch": "http://rs.tdwg.org/format/values/m072",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "RW2 raw image"
#         },
#         {
#           "@language": "es",
#           "@value": "C\u00f3digo de la instituci\u00f3n propietaria"
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u6240\u6709\u8005\u673a\u6784\u4ee3\u7801"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "file extension for Panasonic raw image"
#         },
#         {
#           "@language": "es",
#           "@value": "El nombre (o acr\u00f3nimo) en uso por la instituci\u00f3n que tiene la propiedad del objeto(s) o informaci\u00f3n referida en el registro. "
#         },
#         {
#           "@language": "zh-Hans",
#           "@value": "\u8bb0\u5f55\u4e2d\u663e\u793a\u7684\u5bf9\u7269\u54c1\u6216\u4fe1\u606f\u4eab\u6709\u6240\u6709\u6743\u7684\u673a\u6784\u540d\u79f0\uff08\u6216\u7f29\u5199\uff09\u3002"
#         }
#       ]
#     }
#   ]
# }

# %%
outputObject = open(out_filename, 'wt', encoding='utf-8')
outputObject.write(jsonld_output)
outputObject.close()
    
print('done')
# Out:
# done

# %%
decisions_df = pd.read_csv('https://raw.githubusercontent.com/tdwg/rs.tdwg.org/master/decisions/decisions-links.csv', na_filter=False)

# generate a table for each term, with terms grouped by category

# generate the Markdown for the terms table
text = '## 4 Vocabulary\n'
for category in range(0,len(display_order)):
    if organized_in_categories:
        text += '### 4.' + str(category + 1) + ' ' + display_label[category] + '\n'
        text += '\n'
        text += display_comments[category] # insert the comments for the category, if any.
        filtered_table = terms_sorted_by_localname[terms_sorted_by_localname['tdwgutility_organizedInClass']==display_order[category]]
        filtered_table.reset_index(drop=True, inplace=True)
    else:
        filtered_table = terms_sorted_by_localname
        filtered_table.reset_index(drop=True, inplace=True)

    for row_index,row in filtered_table.iterrows():
        text += '<table>\n'
        curie = row['pref_ns_prefix'] + ":" + row['term_localName']
        curieAnchor = curie.replace(':','_')
        text += '\t<thead>\n'
        text += '\t\t<tr>\n'
        text += '\t\t\t<th colspan="2"><a id="' + curieAnchor + '"></a>Term Name  ' + curie + '</th>\n'
        text += '\t\t</tr>\n'
        text += '\t</thead>\n'
        text += '\t<tbody>\n'
        text += '\t\t<tr>\n'
        text += '\t\t\t<td>Term IRI</td>\n'
        uri = row['pref_ns_uri'] + row['term_localName']
        text += '\t\t\t<td><a href="' + uri + '">' + uri + '</a></td>\n'
        text += '\t\t</tr>\n'
        text += '\t\t<tr>\n'
        text += '\t\t\t<td>Modified</td>\n'
        text += '\t\t\t<td>' + row['term_modified'] + '</td>\n'
        text += '\t\t</tr>\n'

        if row['version_iri'] != '':
            text += '\t\t<tr>\n'
            text += '\t\t\t<td>Term version IRI</td>\n'
            text += '\t\t\t<td><a href="' + row['version_iri'] + '">' + row['version_iri'] + '</a></td>\n'
            text += '\t\t</tr>\n'

        text += '\t\t<tr>\n'
        text += '\t\t\t<td>Label</td>\n'
        text += '\t\t\t<td>' + row['label'] + '</td>\n'
        text += '\t\t</tr>\n'

        if row['term_deprecated'] != '':
            text += '\t\t<tr>\n'
            text += '\t\t\t<td></td>\n'
            text += '\t\t\t<td><strong>This term is deprecated and should no longer be used.</strong></td>\n'
            text += '\t\t</tr>\n'

        text += '\t\t<tr>\n'
        text += '\t\t\t<td>Definition</td>\n'
        text += '\t\t\t<td>' + row['definition'] + '</td>\n'
        text += '\t\t</tr>\n'

        if row['usage'] != '':
            text += '\t\t<tr>\n'
            text += '\t\t\t<td>Usage</td>\n'
            text += '\t\t\t<td>' + createLinks(row['usage']) + '</td>\n'
            text += '\t\t</tr>\n'

        if row['notes'] != '':
            text += '\t\t<tr>\n'
            text += '\t\t\t<td>Notes</td>\n'
            text += '\t\t\t<td>' + createLinks(row['notes']) + '</td>\n'
            text += '\t\t</tr>\n'

        if row['examples'] != '':
            text += '\t\t<tr>\n'
            text += '\t\t\t<td>Examples</td>\n'
            text += '\t\t\t<td>' + createLinks(row['examples']) + '</td>\n'
            text += '\t\t</tr>\n'

        if (vocab_type == 2 or vocab_type == 3) and row['controlled_value_string'] != '': # controlled vocabulary
            text += '\t\t<tr>\n'
            text += '\t\t\t<td>Controlled value</td>\n'
            text += '\t\t\t<td>' + row['controlled_value_string'] + '</td>\n'
            text += '\t\t</tr>\n'

        if vocab_type == 3 and row['skos_broader'] != '': # controlled vocabulary with skos:broader relationships
            text += '\t\t<tr>\n'
            text += '\t\t\t<td>Has broader concept</td>\n'
            curieAnchor = row['skos_broader'].replace(':','_')
            text += '\t\t\t<td><a href="#' + curieAnchor + '">' + row['skos_broader'] + '</a></td>\n'
            text += '\t\t</tr>\n'

        text += '\t\t<tr>\n'
        text += '\t\t\t<td>Type</td>\n'
        if row['type'] == 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property':
            text += '\t\t\t<td>Property</td>\n'
        elif row['type'] == 'http://www.w3.org/2000/01/rdf-schema#Class':
            text += '\t\t\t<td>Class</td>\n'
        elif row['type'] == 'http://www.w3.org/2004/02/skos/core#Concept':
            text += '\t\t\t<td>Concept</td>\n'
        else:
            text += '\t\t\t<td>' + row['type'] + '</td>\n' # this should rarely happen
        text += '\t\t</tr>\n'

        # Look up decisions related to this term
        for drow_index,drow in decisions_df.iterrows():
            if drow['linked_affected_resource'] == uri:
                text += '\t\t<tr>\n'
                text += '\t\t\t<td>Executive Committee decision</td>\n'
                text += '\t\t\t<td><a href="http://rs.tdwg.org/decisions/' + drow['decision_localName'] + '">http://rs.tdwg.org/decisions/' + drow['decision_localName'] + '</a></td>\n'
                text += '\t\t</tr>\n'                        

        text += '\t</tbody>\n'
        text += '</table>\n'
        text += '\n'
    text += '\n'
term_table = text

print(term_table)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-4d7603cf176e> in <module>
#       5 # generate the Markdown for the terms table
#       6 text = '## 4 Vocabulary\n'
# ----> 7 for category in range(0,len(display_order)):
#       8     if organized_in_categories:
#       9         text += '### 4.' + str(category + 1) + ' ' + display_label[category] + '\n'
#
# NameError: name 'display_order' is not defined

# %% [markdown]
# Modify to display the indices that you want

# %%
text = index_by_label + term_table
#text = index_by_name + index_by_label + term_table

# %%
# read in header and footer, merge with terms table, and output

headerObject = open(headerFileName, 'rt', encoding='utf-8')
header = headerObject.read()
headerObject.close()

footerObject = open(footerFileName, 'rt', encoding='utf-8')
footer = footerObject.read()
footerObject.close()

output = header + text + footer
outputObject = open(outFileName, 'wt', encoding='utf-8')
outputObject.write(output)
outputObject.close()
    
print('done')
# Out:
# done
