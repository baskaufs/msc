# %% [markdown]
# Script to investigate ways to optimize guessing for the game Wordle: https://wordlegame.org/
#
# This program is released under a GNU General Public License v3.0 http://www.gnu.org/licenses/gpl-3.0
# Author: Steve Baskauf
# 2022-01-17

# %% [markdown]
# # Script setup
#
# Run the following cell before running any of the cells in the rest of the notebook

# %%
import urllib.request
import json
from math import sqrt
import random

# Global variables.
lowercase = 'abcdefghijklmnopqrstuvwxyz'
uppercase = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
letters_in_game = 5
number_all_words = 2529 # based on five-letter words from wordlist "6 of 12". See http://wordlist.aspell.net/12dicts-readme/#nof12

# Download full wordlist to avoid a bunch of HTTP calls
url = 'https://gist.github.com/baskaufs/8c5f187e41f37af7e395c7094eb796d8/raw/cc40500c0ecc7b4e33dedf96451d26ef6362af2b/five_letter_6of12.txt'           
file_object = urllib.request.urlopen(url)
full_wordlist = file_object.read().decode('utf-8').split('\n')[:-1] # need to get rid of empty string caused by trailing newline

# ---------
# Functions
# ---------

def sort_funct(row):
    """Specify key to sort by. Return the value to sort."""
    return row['value']

def generate_guess_code(guessed_word, actual_word):
    """Generate code required for input. Return a string of comma-separated values."""
    code = ['', '', '', '', '']
    non_positioned_letters_actual = []
    
    # Place codes for correct letters in correct positions
    for position in range(letters_in_game):
        if actual_word[position] == guessed_word[position]:
            code[position] = actual_word[position].upper()
        else:
            non_positioned_letters_actual.append(actual_word[position])
    
    # Place codes for other letters
    for position in range(letters_in_game):
        if code[position] == '': # Skip correct positioned letters
            if guessed_word[position] in non_positioned_letters_actual: # a guessed letter is in the word
                code[position] = guessed_word[position]
                # Need to remove letter in case it occurs in the word a second time
                non_positioned_letters_actual.remove(guessed_word[position])
            else:
                code[position] = '-' + guessed_word[position]
                
    code_string = ",".join(code)
    return(code_string)

def score_words_by_random(wordle):
    random_word = random.choice(wordle.wordlist)
    return [{'word': random_word, 'value': 0}]

def score_words_by_remaining(wordle):
    # Calculate scores for all words
    score_list = []
    count = 0
    for word_to_score in wordle.wordlist:
        count += 1
        #print(count, word_to_score)

        # Create a list of zeros to keep track of the distributions for the possible words
        distribution = []
        for number in range(wordle.n + 1):
            distribution.append(0)

        score_sum = 0
        for possible_puzzle_word in wordle.wordlist:
            #print(possible_puzzle_word)
            guess_code = generate_guess_code(word_to_score, possible_puzzle_word)
            #print(guess_code)
            
            # Generate a new word list with reset tracking variables
            possibility_wordle_list = Wordle_list(guess=guess_code, wordlist=wordle.wordlist)
            words_remaining_for_possible = possibility_wordle_list.n
            #print(words_remaining_for_possible)
            distribution[words_remaining_for_possible] += 1
            #print(distribution)
            score_sum += words_remaining_for_possible
            #print(score_sum)

        score = score_sum / wordle.n
        #print(score)
        #print(distribution)
        #print()
            
        score_list.append({'word': word_to_score, 'value': score, 'distribution': distribution})
        
        ''' Only used this when testing first word choices, otherwise it slows things down unnecessarily.
        # Write after each word in case it crashes
        with open('remain_word_scores.json', 'wt', encoding='utf-8') as file_object:
            file_object.write(json.dumps(score_list))
        '''
        
    score_list.sort(key = sort_funct)
    return score_list

def score_words_by_information(wordle):
    # There is a weird edge case for words with double letters, like "yummy" where the algorithm gets it
    # down to 2 words, but then picks a different word than either of the two remaining words because it 
    # thinks it still needs to learn about the second of the double letters, even though that second 
    # letter is the same in both words. So it wastes a turn trying to learn about something that 
    # doesn't matter. In this case, it would be better to just guess and get the word or miss and 
    # get it the next time. So the following code handles that case:
    
    # Random option:
    if wordle.n == 2:
        choice_list = list(wordle.wordlist)
        first_word = random.choice(choice_list)
        choice_list.remove(first_word)
        return [{'word': first_word, 'value': 1.0, 'distribution': [0,1]}, {'word': choice_list[0], 'value': 1.0, 'distribution': [0,1]}]
    
    '''
    # Fixed option (always pick the first word):
    if wordle.n == 2:
        return [{'word': wordle.wordlist[0], 'value': 1.0, 'distribution': [0,1]}, {'word': wordle.wordlist[1], 'value': 1.0, 'distribution': [0,1]}]
    '''
    
    # If there's only one word left, pick it
    if wordle.n == 1:
        return [{'word': wordle.wordlist[0], 'value': 0, 'distribution': [0]}]
    
    # Letters in the remaining words will have frequencies in the returned dict of > 0
    letter_frequencies_remaining = calculate_total_frequency(wordle.wordlist, wordle.position_known)[1]
    #print(letter_frequencies_remaining)
    #print(wordle.position_known)
    
    # Create a dict to hold scored words
    word_storage = {}
    for number in range(1, letters_in_game + 1):
        word_storage[str(number)] = [] # Create a list to hold the words with that number of letters
    
    for word in full_wordlist:
        # Get the unique letters from the word
        unique_letters_list = list(dict.fromkeys(list(word)))
        # Count the number remaining letters in unique letters in word
        number_remaining_letters_in_word = 0
        for unique_letter in unique_letters_list:
            if letter_frequencies_remaining[unique_letter] > 0:
                number_remaining_letters_in_word += 1
        if number_remaining_letters_in_word > 0:
            word_storage[str(number_remaining_letters_in_word)].append(word)
    #print(word_storage)
    #print()
    
    # Figure out which of the lists that contain words has the higest number of letters.
    for number in range(letters_in_game, 0, -1):
        if len(word_storage[str(number)]) > 0:
            break
    #print('max letters is', number)
    #print()
             
    # Score all of the words in the list of words with the highest number of letters in the possible puzzle words
    score_list = []
    count = 0
    for word_to_score in word_storage[str(number)]:
        count += 1
        #print(count, word_to_score)

        # Create a list of zeros to keep track of the distributions for the possible words
        distribution = []
        for number in range(wordle.n + 1):
            distribution.append(0)

        score_sum = 0
        for possible_puzzle_word in wordle.wordlist:
            #print(possible_puzzle_word)
            guess_code = generate_guess_code(word_to_score, possible_puzzle_word)
            #print(guess_code)
            
            # Generate a new word list based on the possible puzzle words
            possibility_wordle_list = Wordle_list(guess=guess_code, wordlist=wordle.wordlist)
            words_remaining_for_possible = possibility_wordle_list.n
            #print(words_remaining_for_possible)
            distribution[words_remaining_for_possible] += 1
            #print(distribution)
            score_sum += words_remaining_for_possible
            #print(score_sum)

        score = score_sum / wordle.n
        #print(score)
        #print(distribution)
        #print()
            
        score_list.append({'word': word_to_score, 'value': score, 'distribution': distribution})
        
        # Only used this when testing first word choices, otherwise it slows things down unnecessarily.
        # Write after each word in case it crashes
        #with open('remain_word_scores.json', 'wt', encoding='utf-8') as file_object:
        #   file_object.write(json.dumps(score_list))
  
    score_list.sort(key = sort_funct)
    return score_list


def score_words_by_frequency(overall_weight, position_weight, switchover, wordle):
    """Generate a score for a word based on rank of letter frequencies. Return a list of dicts."""
    # Create list of ordinal dictionaries by position
    position_ordinals = []
    for position in range(letters_in_game):
        position_ordinals.append(wordle.ordinals(position))
    overall_ordinals = wordle.ordinals()
       
    # Scale the weights depending on what fraction of the words are left to determine.
    # For all words, scaled_overall_weight = overall_weight and scaled_position_weight = position_weight
    # For two words, scaled_overall_weight = 0 and scaled_position_weight = 1. The penalty should go away
    # with two words because they will always be equally likely.

    # Add numeric override to increasing position weight
    if wordle.n < switchover:

        fraction_words_remaining = (wordle.n - 2) / (number_all_words)
        # NOTE: after experimentation, doing a linear scaling seems to phase out the overall weight too early,
        # particularly when it gets to the range of 20 to 100 words. 
        # I tried using part of a circle with radius of 1 as a different function, but it's performance was worse.
        # So I went back to the original, simpler method.
        '''
        try: # Trap negatives for very small numbers of words
            scaled_overall_weight = sqrt(1 - (1 - fraction_words_remaining)**2) * overall_weight
        except:
            scaled_overall_weight = 0
        '''
        # Scaling based on linear phaseout
        scaled_overall_weight = fraction_words_remaining * overall_weight
        scaled_position_weight = 1 - scaled_overall_weight
        #print('scaled_position_weight:', scaled_position_weight)
        #print('scaled_overall_weight:', scaled_overall_weight)

    else:
        scaled_overall_weight = overall_weight
        scaled_position_weight = position_weight
            
    # Calculate scores for all words
    score_list = []
    for word in wordle.wordlist:
        position_score = 0
        for position in range(letters_in_game):
            position_score += position_ordinals[position][word[position]]
            
        unique_letters_list = list(dict.fromkeys(list(word)))
        overall_score = 0
        for unique_letter in unique_letters_list:
            overall_score += overall_ordinals[unique_letter]
        # Add penalty for not using all possible positions. 
        # Not using a position is worse than guessing the least frequent letter
        for penalty in range(letters_in_game-len(unique_letters_list)):
            overall_score += 26
            
        score_list.append({'word': word, 'value': overall_score * scaled_overall_weight + position_score * scaled_position_weight})
    score_list.sort(key = sort_funct)
    
    return score_list

def calculate_frequency(position, word_list):
    """Determine the frequencies of letters by position in word (0 to 4). Return a tuple with descending ordered list of letter frequencies and dictionary with letter keys."""
    freq_list = []
    freq_dict = {}
    for letter in lowercase:
        frequency = 0
        for word in word_list:
            if letter == word[position]:
                frequency += 1
        freq_list.append({'letter': letter, 'value': frequency})
        freq_dict[letter] = frequency
    freq_list.sort(key = sort_funct, reverse=True)
    return freq_list, freq_dict
    
def calculate_total_frequency(wordlist, position_known):
    """Determine the frequencies of letters in all positions whose position_known value is True. Return a tuple with descending ordered list of letter frequencies and dictionary with letter keys."""
    freq_dict = {}
    for letter in lowercase:
        freq_dict[letter] = 0

    # Add up the frequencies for each position
    for pos in range(letters_in_game):
        if not position_known[pos]:
            temp_dict = calculate_frequency(pos, wordlist)[1]
            for letter in lowercase:
                freq_dict[letter] += temp_dict[letter]

    # Create the list of frequencies
    freq_list = []
    for letter in lowercase:
        freq_list.append({'letter': letter, 'value': freq_dict[letter]})
    freq_list.sort(key = sort_funct, reverse=True)
    return freq_list, freq_dict

# ---------
# Classes
# ---------

class Wordle_list():
    """Represents a screened list of words that may have been screened after a guess.
    
    Methods:
    - frequencies  Optional argument specifying the position within the word. If omitted, frequencies are for all positions.
    - ordinals  Optional argument specifying the position within the word. If omitted, ordinals are for all positions.
    
    Instance variables:
    - n  Number of words in the list
    - wordlist  A list containing the words after applying a screen based on the guess code parameter.
    - unique  A list derived from the wordlist by filtering for unique words.
    """
    
    def __init__(self, **kwargs):
        """Instantiate a screened list of words.
        
        Arguments:
        - wordlist  A list containing words to be screened. If omitted, the original curated list of English words is used.
        - guess  A string of codes separated by commas indicating the results of a guess. If omitted or malformed, no screening is carried out on the list.
        """
        
        try:
            guess_string = kwargs['guess']
        except:
            guess_string = ''
            
        try:
            self.letters_in = kwargs['letters_in']
        except:
            self.letters_in = []
            
        try:
            self.letters_out = kwargs['letters_out']
        except:
            self.letters_out = []
            
        try:
            self.position_known = kwargs['position_known']
        except:
            self.position_known = []
            for position in range(letters_in_game):
                self.position_known.append('')            
            
        try:
            self.print_lists = kwargs['print_lists']
        except:
            self.print_lists = False
            
        try:
            self.wordlist = kwargs['wordlist']
        except:
            # List of 5698 five-letter words extracted from 100000 common English words. Was mising some common words
            #url = 'https://gist.githubusercontent.com/baskaufs/d43301918b5fc2583ef884d6014c25d4/raw/b0b02c703f7bd361c5e32c0a2f1eba39d075b0b1/five_letter.txt'
            # Alternate file from https://www.wordgamedictionary.com/word-lists/5-letter-words/5-letter-words.json
            #url = 'https://gist.githubusercontent.com/baskaufs/aa458449891fe4d36e51b87c8f8d58c7/raw/b23c349ab83e1098782208f4eb08ee949c4a89e7/five_letter.txt'
            
            # The 6 of 12 list is a high-quality curated list of American English words. Capitalization is consistent
            # and abbreviations are marked so they can be removed. The number of extracted words is similar to the number
            # that Wordle said he used (about 2500). So this seems about right. http://wordlist.aspell.net/12dicts-readme/#nof12
            ''' Just do this once at the start
            url = 'https://gist.github.com/baskaufs/8c5f187e41f37af7e395c7094eb796d8/raw/cc40500c0ecc7b4e33dedf96451d26ef6362af2b/five_letter_6of12.txt'           
            file_object = urllib.request.urlopen(url)
            self.wordlist = file_object.read().decode('utf-8').split('\n')[:-1] # need to get rid of empty string caused by trailing newline
            '''
            self.wordlist = full_wordlist

        # Use guess information to screen out words from wordlist
        try:
            if guess_string:
                # Guess is a string with position guesses separated by commas. 
                # Uppercase letters are correct letter, correct position
                # Lowercase letters are correct letter, incorrect position
                # Lowercase letters with prepended minus are letters not in word.
                guess_list = guess_string.split(',')
                guess_letter_list = []
                for letter_guess in guess_list:
                    if letter_guess[0].lower() in lowercase:
                        guess_letter_list.append(letter_guess[0].lower())

                # First need to limit to words with letters with newly discovered positions.
                for position in range(letters_in_game):
                    if guess_list[position][0] in uppercase:
                        # No screening necessary if position already known because screening was done before
                        if not self.position_known[position]: # will evaluate False if ''
                            known_letter = guess_list[position][0].lower()
                            new_list = []
                            for word in self.wordlist:
                                if word[position] == known_letter:
                                    new_list.append(word)
                            self.wordlist = new_list
                            # Set the letter instead of an empty string in the positions list
                            self.position_known[position] = known_letter

                if self.print_lists:
                    print('wordlist after restricting to words with letters in right positions:', self.wordlist)
                    print()

                # Eliminate words that don't have enough of the known letters in incorrect positions
                # First need to find out what information about known letters is in this guess

                # Add the letter to the known letters if new information about it
                for letter in lowercase:
                    # Find out how many more there are of the letter in the guess than in the list of known letters
                    more_of_letter = guess_letter_list.count(letter) - self.letters_in.count(letter)
                    # If there are additional letters, then add that many to the list of known letters
                    if more_of_letter > 0:
                        for add in range(more_of_letter):
                            self.letters_in.append(letter)

                # Now screen the wordlist for only words that have enough of each known letter
                new_list = list(self.wordlist) # apply list conversion function to make a copy of the wordlist
                for word in self.wordlist:
                    remove = False
                    for letter in lowercase:
                        # Set word for removal if it has fewer of a letter than the known number of that letter
                        if word.count(letter) < self.letters_in.count(letter):
                            remove = True
                    if remove:
                        new_list.remove(word)
                self.wordlist = new_list

                if self.print_lists:
                    print('wordlist after removing words without known letters:', self.wordlist)
                    print()


                # We also have to eliminate any words that have the new known but incorrectly positioned letter 
                # in the position where it was guessed
                for position in range(letters_in_game):
                    if guess_list[position][0] in lowercase:
                        new_list = list(self.wordlist)
                        for word in self.wordlist:
                            if word[position] == guess_list[position][0]:
                                new_list.remove(word)
                        self.wordlist = new_list
                if self.print_lists:
                    print('wordlist after removing words with known letter in guessed position:', self.wordlist)
                    print()                    

                # Eliminate words that contain letters known to not be in the word
                for position in range(letters_in_game):
                    if guess_list[position][0] == '-': # incorrect letter marker
                        incorrect_letter = guess_list[position][1].lower()
                        # Only screen if it's a new one
                        if not incorrect_letter in self.letters_out:
                            # NOTE: Correct operation of this test depends on the first occurrence of that letter in a guess
                            # word being scored as present and the second occurrence being scored as absent. I haven't
                            # tested this with the real app to see if this is actually the behavior.
                            
                            # New code
                            self.letters_out.append(incorrect_letter)
                            # Remove words with too many of the incorrect letter
                            new_list = list(self.wordlist)
                            for word in self.wordlist:
                                # The number has to be more than the number of that letter known to be correct in the word
                                if word.count(incorrect_letter) > self.letters_in.count(incorrect_letter):
                                    new_list.remove(word)
                            self.wordlist = new_list

                            ''' Old faulty code
                            if self.letters_in.count(incorrect_letter) == 0: 
                                self.letters_out.append(incorrect_letter)
                                # Remove any words that have that letter in any position
                                new_list = list(self.wordlist)
                                for word in self.wordlist:
                                    remove = False
                                    for position in range(letters_in_game): # set to remove if letter occurs any number of times
                                        if word[position] == incorrect_letter:
                                            remove = True
                                    if remove:
                                        new_list.remove(word)
                                self.wordlist = new_list
                            '''

                if self.print_lists:
                    print('wordlist after removing words with incorrect letters:', self.wordlist)
                    print()
                    
            else:
                # Don't do any screening if there isn't a guess
                if self.print_lists:
                    print('No screen applied.')
        
        except:
            # Don't do any screening if there isn't a guess or guess string is malformed
            if self.print_lists:
                print('Error. Was the guess string malformed? No screen applied.')
        
        # Create list of words with unique letters in unknown positions
        unique_letter_words = []
        for word in self.wordlist:
            letter_list = []
            # Check each letter in the word and add to list if it's in a position that isn't yet known.
            for position in range(letters_in_game):
                if not self.position_known[position]:
                    letter_list.append(word[position])
            unique_letter_list = list(dict.fromkeys(letter_list))
            if len(unique_letter_list) == len(letter_list):
                unique_letter_words.append(word)
        self.unique = unique_letter_words
        
        self.n = len(self.wordlist)

    def frequencies(self, position=-1):
        """Calculate frequencies by position, or of all letters if position omitted. Return a tuple with descending ordered list of letter frequencies and dictionary with letter keys."""
        # If a position is given, just return the frequencies for that position directly
        if position >= 0:
            freq_list, freq_dict = calculate_frequency(position, self.wordlist)
            
        # Calculate frequencies for the whole words
        else:
            # Create list of empty strings for all positions unknown.
            position_known = []
            for position in range(letters_in_game):
                position_known.append('')            
            freq_list, freq_dict = calculate_total_frequency(self.wordlist, position_known)

        return freq_list, freq_dict
    
    def ordinals(self, position=-1):
        """Determine ordinals for letters by position, or of all letters if position omitted. Return a dictionary with letter keys."""
        # If a position is given, just return the frequencies for that position only
        if position >= 0:
            freq_list = calculate_frequency(position, self.wordlist)[0]
        else:
            # Create list of empty strings for all positions unknown.
            position_known = []
            for position in range(letters_in_game):
                position_known.append('')            
            freq_list = calculate_total_frequency(self.wordlist, position_known)[0]
            
        # Need to give the same ordinal number to letters with the same frequency
        ordinal_of_last_letter = 0
        frequency_of_last_letter = -1
        ordinal_dict = {}
        for letter_freq_number in range(26):
            if freq_list[letter_freq_number]['value'] == frequency_of_last_letter:
                ordinal_dict[freq_list[letter_freq_number]['letter']] = ordinal_of_last_letter
            else:
                ordinal_dict[freq_list[letter_freq_number]['letter']] = letter_freq_number
                frequency_of_last_letter = freq_list[letter_freq_number]['value']
                ordinal_of_last_letter = letter_freq_number

        return ordinal_dict

# %% [markdown]
# ## Calculate stats for raw list
#
# Run these cells if you are curious to see some stats about the word set that are used to optimize guessing.

# %%
wordle = Wordle_list()
print(wordle.n)
print(len(wordle.unique))
print(json.dumps(wordle.frequencies()[0],indent=2))
print(json.dumps(wordle.frequencies()[1],indent=2))
print(json.dumps(wordle.ordinals(),indent=2))

# %%
# Create the list of frequencies by number of occurrences in word
# Thought I might use this for something, but didn't.
freq_list = []
for letter in lowercase:
    number_list = [0, 0, 0, 0, 0, 0]
    for word in wordle.wordlist:
        letter_count = word.count(letter)
        number_list[letter_count] += 1
    freq_dict = {}
    for frequency in range(6):
        freq_dict[str(frequency)] = number_list[frequency]
    freq_list.append({letter: freq_dict})
print(json.dumps(freq_list, indent=2))

# %% [markdown]
# # Test of rating words by frequencies
#
# The following cell ranks words to determine the best first guess, using unique-letter words and the frequency weights. The second cell ranks words to use as the best second guess using unique-letter words and none of the letters in the first guess.

# %%
# Generate word list
wordle = Wordle_list()

overall_weight = 0.6
position_weight = 1 - overall_weight
switchover = 11

score_list = score_words_by_frequency(overall_weight, position_weight, switchover, wordle)
print(json.dumps(score_list[:10], indent=2))

# %%
# Calculate best second word (eliminating the letters from the first word)
# By default, the top scoring word from the previous cell is used. To override this, uncomment the second line 
# and use your own word.
first_word = score_list[0]['word']
#first_word = 'my_choice'
print('Complimentary word to:', first_word)

screened_words = score_list
for letter in first_word:
    remaining_words = []
    for word in screened_words:
        if not letter in word['word']:
            remaining_words.append(word)
    screened_words = remaining_words

print(json.dumps(screened_words[:10], indent=2))

# %% [markdown]
# # Screening algorithm test
#
# The following cells repeatedly apply the following algorithm:
#
# 1. Obtain the list of words containing unique letters in unknown positions from the previously instantiated `Wordle_list` object. The first time it will be generated from the full five-letter word list from GitHub.
# 2. Test the wordlist from using the `score_words_by_frequency()` function.
# 2. Use the best scoring word as the guess and determine the guess results code (from the app or by using the default generated when the puzzle word is known).
# 3. Instantiate a new `Wordle_list` object using the guess results code and the current wordlist, then go back to step 1.
#
# The format of the guess results code is a string (in single quotes) with each of the letter result codes separated by commas and no spaces. Use uppercase letters if the guess was the right letter in the right position, lowercase if it was a right letter in the wrong position, and a lowercase letter preceded by a minus (`-`) character if it was a letter not found in the word. Example: `'B,-a,-n,-k,s'` if `banks` was guessed for the word `boost`
#
# Test words from Wordle answers in 2022 January from [here](https://screenrant.com/wordle-answers-updated-word-puzzle-guide/). The number following word is number of guesses required using the algorithm. To run the test yourself, set the value of `actual_word` to the word (in all lower-case).
#
# In many cases, a stage was reached where there were two words with equal scores. In each case an additional guess would either be the correct answer, or eliminate the other possibility such that one additional guess would be required. Thus for a result of "3 and 0.5", after three guesses, there were two words with equal top scores. Guessing the right one would result in 4 guesses and guessing the wrong one would result in 5 guesses.
#
# ```
#     01/17 - #212 - SHIRE 2 and 0.5 (i.e. reduced to 2 equal-scoring words after second guess)
#     01/16 - #211 - SOLAR 2 and 0.5
#     01/15 - #210 - PANIC 3 and 0.5
#     01/14 - #209 - TANGY 4
#     01/13 - #208 - ABBEY 3
#     01/12 - #207 - FAVOR 3 and 0.5
#     01/11 - #206 - DRINK 2 and 0.5
#     01/10 - #205 - QUERY 3 and 0.5
#     01/09 - #204 - GORGE 3 and 0.5
#     01/08 - #203 - CRANK 3 and 0.333
#     01/07 - #202 - SLUMP 4
#     01/06 - #201 - BANAL 4
#     01/05 - #200 - TIGER 4
#     01/04 - #199 - SIEGE 2 and 0.5
#     01/03 - #198 - TRUSS 3
#     01/02 - #197 - BOOST 2 and 0.5
#     01/01 - #196 - REBUS 3
# ```
#
# These results are similar to a competent human player, but not a lot better.

# %%
# Initial setup

# Choose one of the two scoring systems
# Choices are 'letter frequency' or 'words remaining'
#scoring_system = 'words remaining'
#scoring_system = 'letter frequency'
scoring_system = 'information'
#scoring_system = 'random'

# Choose weights to use for scoring words
overall_weight = 0.6
position_weight = 1 - overall_weight
switchover = 11

# Set actual word for testing or empty string to play real game
actual_word = 'yummy' # known word
# actual_word = '' # word from game

# Instantiate initial Wordle_list object
start = Wordle_list()

print('Scoring system:', scoring_system)
print('Words remaining:', start.n)
print('Percent of words remaining:', start.n / number_all_words * 100)
print()

freq_score_list = score_words_by_frequency(overall_weight, position_weight, switchover, start)

print('Best frequency-based word scores:')
for word in freq_score_list[:10]:
    print(word['word'], word['value'])
print()

# Load the "remaining word" scores for the first-guess words (takes a day to calculate on the fly)
url = 'https://raw.githubusercontent.com/baskaufs/msc/master/python/wordle/words_remaining_tests/remain_word_scores_minimal.json'
file_object = urllib.request.urlopen(url)
remaining_score_list = json.loads(file_object.read().decode('utf-8'))

print('Best "words-remaining" and "information" word scores:')
for word in remaining_score_list[:10]:
    print(word['word'], word['average'])
print()

random_score_list = score_words_by_random(start)
print('Random word choice:')
print(random_score_list[0]['word'])

if scoring_system == 'letter frequency':
    next_guess_word = freq_score_list[0]['word']
elif scoring_system == 'words remaining' or scoring_system == 'information':
    next_guess_word = remaining_score_list[0]['word']
else:
    next_guess_word = random_score_list[0]['word']
print()
print('Next guess word:', next_guess_word)

if actual_word != '':
    next_guess_code = generate_guess_code(next_guess_word, actual_word)

# %%
# First guess

if actual_word == '':
    # Manual entry for real game
    # Example guess for test Wordle from 2022-01-15 "panic" using the top scoring word "arose":
    next_guess_code = '-r,a,-i,-s,-e'

first_guess = Wordle_list(print_lists=True, letters_in=start.letters_in, letters_out=start.letters_out, position_known=start.position_known, guess=next_guess_code, wordlist=start.wordlist)
remaining = first_guess.n

print('First guess code was:', next_guess_code)
print('Words remaining:', remaining)
print('Percent of words remaining:', remaining / number_all_words * 100)
print()

if remaining >= letters_in_game:
    n_print = letters_in_game
else:
    n_print = remaining

freq_score_list = score_words_by_frequency(overall_weight, position_weight, switchover, first_guess)
print('Best frequency-based word scores:')
for word in freq_score_list[:n_print]:
    print(word['word'], word['value'])
print()

# Avoid taking forever if the previous guess word is random, terrible, and results in many possible words.
if scoring_system == 'information' or remaining < 150:
    if remaining > 150:
        print('Calculating. Please wait, then scroll down.')
    information_score_list = score_words_by_information(first_guess)
    print('Best information word scores:')
    for word in information_score_list[:n_print]:
        print(word['word'], word['value'])
    print()

# Avoid taking forever if the previous guess word is random, terrible, and results in many possible words.
if scoring_system == 'words remaining' or remaining < 150:
    if remaining > 150:
        print('Calculating. Please wait, then scroll down.')
    remaining_score_list = score_words_by_remaining(first_guess)
    print('Best words-remaining word scores:')
    for word in remaining_score_list[:n_print]:
        print(word['word'], word['value'])
    print()

random_score_list = score_words_by_random(first_guess)
print('Random word choice:')
print(random_score_list[0]['word'])

if scoring_system == 'letter frequency':
    next_guess_word = freq_score_list[0]['word']
elif scoring_system == 'information':
    next_guess_word = information_score_list[0]['word']
elif scoring_system == 'words remaining':
    next_guess_word = remaining_score_list[0]['word']
else:
    next_guess_word = random_score_list[0]['word']
print()
print('Next guess word:', next_guess_word)

if actual_word != '':
    next_guess_code = generate_guess_code(next_guess_word, actual_word)

# %%
# Second guess

if actual_word == '':
    # Manual entry for real game
    # Example guess for test Wordle from 2022-01-15 "panic" using the top scoring word "canny":
    next_guess_code = 'c,-l,-o,-u,-t'

second_guess = Wordle_list(print_lists=True, letters_in=first_guess.letters_in, letters_out=first_guess.letters_out, position_known=first_guess.position_known, guess=next_guess_code, wordlist=first_guess.wordlist)
remaining = second_guess.n

print('Second guess code was:', next_guess_code)
print('Words remaining:', remaining)
print('Percent of words remaining:', remaining / number_all_words * 100)
print()

if remaining >= letters_in_game:
    n_print = letters_in_game
else:
    n_print = remaining

freq_score_list = score_words_by_frequency(overall_weight, position_weight, switchover, second_guess)
print('Best frequency-based word scores:')
for word in freq_score_list[:n_print]:
    print(word['word'], word['value'])
print()

# Avoid taking forever if the previous guess word is random, terrible, and results in many possible words.
if scoring_system == 'information' or remaining < 150:
    if remaining > 150:
        print('Calculating. Please wait, then scroll down.')
    information_score_list = score_words_by_information(second_guess)
    print('Best information word scores:')
    for word in information_score_list[:n_print]:
        print(word['word'], word['value'])
    print()

# Avoid taking forever if the previous guess word is random, terrible, and results in many possible words.
if scoring_system == 'words remaining' or remaining < 150:
    if remaining > 150:
        print('Calculating. Please wait, then scroll down.')
    remaining_score_list = score_words_by_remaining(second_guess)
    print('Best words-remaining word scores:')
    for word in remaining_score_list[:n_print]:
        print(word['word'], word['value'])
    print()

random_score_list = score_words_by_random(second_guess)
print('Random word choice:')
print(random_score_list[0]['word'])

if scoring_system == 'letter frequency':
    next_guess_word = freq_score_list[0]['word']
elif scoring_system == 'information':
    next_guess_word = information_score_list[0]['word']
elif scoring_system == 'words remaining':
    next_guess_word = remaining_score_list[0]['word']
else:
    next_guess_word = random_score_list[0]['word']
print()
print('Next guess word:', next_guess_word)

if actual_word != '':
    next_guess_code = generate_guess_code(next_guess_word, actual_word)

# %%
# Third guess

if actual_word == '':
    # Manual entry for real game
    # Example guess for test Wordle from 2022-01-15 "panic" using the top scoring word "manic":
    next_guess_code = 'g,-l,-o,r,-y'

third_guess = Wordle_list(print_lists=True, letters_in=second_guess.letters_in, letters_out=second_guess.letters_out, position_known=second_guess.position_known, guess=next_guess_code, wordlist=second_guess.wordlist)
remaining = third_guess.n

print('Third guess code was:', next_guess_code)
print('Words remaining:', remaining)
print('Percent of words remaining:', remaining / number_all_words * 100)
print()

if remaining >= letters_in_game:
    n_print = letters_in_game
else:
    n_print = remaining

freq_score_list = score_words_by_frequency(overall_weight, position_weight, switchover, third_guess)
print('Best frequency-based word scores:')
for word in freq_score_list[:n_print]:
    print(word['word'], word['value'])
print()

print('word list:', third_guess.wordlist)

print()
information_score_list = score_words_by_information(third_guess)
print('Best information word scores:')
for word in information_score_list[:n_print]:
    print(word['word'], word['value'])
print()

print('word list:', third_guess.wordlist)

remaining_score_list = score_words_by_remaining(third_guess)
print('Best words-remaining word scores:')
for word in remaining_score_list[:n_print]:
    print(word['word'], word['value'])
print()

random_score_list = score_words_by_random(third_guess)
print('Random word choice:')
print(random_score_list[0]['word'])

if scoring_system == 'letter frequency':
    next_guess_word = freq_score_list[0]['word']
elif scoring_system == 'information':
    next_guess_word = information_score_list[0]['word']
elif scoring_system == 'words remaining':
    next_guess_word = remaining_score_list[0]['word']
else:
    next_guess_word = random_score_list[0]['word']
print()
print('Next guess word:', next_guess_word)

if actual_word != '':
    next_guess_code = generate_guess_code(next_guess_word, actual_word)

# %%
# Fourth guess

if actual_word == '':
    # Manual entry for real game
    # Example guess for test Wordle from 2022-01-15 "panic" using the top scoring word "panic":
    next_guess_code = '-p,R,I,M,P'

fourth_guess = Wordle_list(print_lists=True, letters_in=third_guess.letters_in, letters_out=third_guess.letters_out, position_known=third_guess.position_known, guess=next_guess_code, wordlist=third_guess.wordlist)
remaining = fourth_guess.n

print('Fourth guess code was:', next_guess_code)
print('Words remaining:', remaining)
print('Percent of words remaining:', remaining / number_all_words * 100)
print()

if remaining >= letters_in_game:
    n_print = letters_in_game
else:
    n_print = remaining

freq_score_list = score_words_by_frequency(overall_weight, position_weight, switchover, fourth_guess)
print('Best frequency-based word scores:')
for word in freq_score_list[:n_print]:
    print(word['word'], word['value'])
print()

information_score_list = score_words_by_information(fourth_guess)
print('Best information word scores:')
for word in information_score_list[:n_print]:
    print(word['word'], word['value'])
print()

remaining_score_list = score_words_by_remaining(fourth_guess)
print('Best words-remaining word scores:')
for word in remaining_score_list[:n_print]:
    print(word['word'], word['value'])
print()

random_score_list = score_words_by_random(fourth_guess)
print('Random word choice:')
print(random_score_list[0]['word'])

if scoring_system == 'letter frequency':
    next_guess_word = freq_score_list[0]['word']
elif scoring_system == 'information':
    next_guess_word = information_score_list[0]['word']
elif scoring_system == 'words remaining':
    next_guess_word = remaining_score_list[0]['word']
else:
    next_guess_word = random_score_list[0]['word']
print()
print('Next guess word:', next_guess_word)

if actual_word != '':
    next_guess_code = generate_guess_code(next_guess_word, actual_word)

# %%
# Fifth guess

if actual_word == '':
    # Manual entry for real game
    # Example guess for test Wordle from 2022-01-15 "panic" using the top scoring word "panic":
    next_guess_code = 'P,A,N,I,C'

fifth_guess = Wordle_list(print_lists=True, letters_in=fourth_guess.letters_in, letters_out=fourth_guess.letters_out, position_known=fourth_guess.position_known, guess=next_guess_code, wordlist=fourth_guess.wordlist)
remaining = fifth_guess.n

print('Fifth guess code was:', next_guess_code)
print('Words remaining:', remaining)
print('Percent of words remaining:', remaining / number_all_words * 100)
print()

if remaining >= letters_in_game:
    n_print = letters_in_game
else:
    n_print = remaining

freq_score_list = score_words_by_frequency(overall_weight, position_weight, switchover, fifth_guess)
print('Best frequency-based word scores:')
for word in freq_score_list[:n_print]:
    print(word['word'], word['value'])
print()

information_score_list = score_words_by_information(fifth_guess)
print('Best information word scores:')
for word in information_score_list[:n_print]:
    print(word['word'], word['value'])
print()

remaining_score_list = score_words_by_remaining(fifth_guess)
print('Best words-remaining word scores:')
for word in remaining_score_list[:n_print]:
    print(word['word'], word['value'])
print()

random_score_list = score_words_by_random(fifth_guess)
print('Random word choice:')
print(random_score_list[0]['word'])

if scoring_system == 'letter frequency':
    next_guess_word = freq_score_list[0]['word']
elif scoring_system == 'information':
    next_guess_word = information_score_list[0]['word']
elif scoring_system == 'words remaining':
    next_guess_word = remaining_score_list[0]['word']
else:
    next_guess_word = random_score_list[0]['word']
print()
print('Next guess word:', next_guess_word)

if actual_word != '':
    next_guess_code = generate_guess_code(next_guess_word, actual_word)

# %%
# Sixth guess

if actual_word == '':
    # Manual entry for real game
    # Example guess for test Wordle from 2022-01-15 "panic" using the top scoring word "panic":
    next_guess_code = 'P,A,N,I,C'

sixth_guess = Wordle_list(print_lists=True, letters_in=fifth_guess.letters_in, letters_out=fifth_guess.letters_out, position_known=fifth_guess.position_known, guess=next_guess_code, wordlist=fifth_guess.wordlist)
remaining = sixth_guess.n

print('Sixth guess code was:', next_guess_code)
print('Words remaining:', remaining)
print('Percent of words remaining:', remaining / number_all_words * 100)
print()

if remaining >= letters_in_game:
    n_print = letters_in_game
else:
    n_print = remaining

freq_score_list = score_words_by_frequency(overall_weight, position_weight, switchover, sixth_guess)
print('Best frequency-based word scores:')
for word in freq_score_list[:n_print]:
    print(word['word'], word['value'])
print()

information_score_list = score_words_by_information(fifth_guess)
print('Best information word scores:')
for word in information_score_list[:n_print]:
    print(word['word'], word['value'])
print()

remaining_score_list = score_words_by_remaining(sixth_guess)
print('Best words-remaining word scores:')
for word in remaining_score_list[:n_print]:
    print(word['word'], word['value'])
print()

random_score_list = score_words_by_random(sixth_guess)
print('Random word choice:')
print(random_score_list[0]['word'])

if scoring_system == 'letter frequency':
    next_guess_word = freq_score_list[0]['word']
elif scoring_system == 'information':
    next_guess_word = information_score_list[0]['word']
elif scoring_system == 'words remaining':
    next_guess_word = remaining_score_list[0]['word']
else:
    next_guess_word = random_score_list[0]['word']
print()
print('Next guess word:', next_guess_word)

if actual_word != '':
    next_guess_code = generate_guess_code(next_guess_word, actual_word)

# %% [markdown]
# # Process list of common English words
#
# One-time process listed for historical purposes. Does not need to be run again.
#
# Source of words downloaded from the "6 of 12 list" http://wordlist.aspell.net/12dicts-readme/#nof12

# %%
import json
import requests

# %%
words = []
with open('6of12.txt', 'rt', encoding='utf-8') as file_object:
    for one_line in file_object:
        words.append(one_line.strip())

# %%
print(len(words))
print(words[:10])

# %%
# Remove any words that contain a non-lowercase letter
alphabetic = []
for word in words:
    bad_letter = False
    for character in word:
        if character < 'a' or character > 'z':
            bad_letter = True
    if not bad_letter:
        alphabetic.append(word)
print(len(alphabetic))

# %%
# Remove possible duplicates
dedupe = list(dict.fromkeys(alphabetic))
print(len(dedupe))

# %%
# restrict to 5 letter words
five_letter = []
for word in dedupe:
    if len(word) == 5:
        five_letter.append(word)
print(len(five_letter))

# %%
# Save in file
with open('five_letter_6of12.txt', 'wt', encoding='utf-8') as file_object:
    for word in five_letter:
        print(word, file=file_object)

# %% [markdown]
# # Cell to use for testing fixed second word guess
#
# Or any other experimentation when you want to override automatic asignment of the previous top scoring word as the next guess.

# %%
# top complementary word to 'arose'
guessed_word = 'glint'
#guessed_word = 'rider'
next_guess_code = generate_guess_code(guessed_word, actual_word)
print(next_guess_code)

# %% [markdown]
# # Used this code cell to screen first word performance (one time only).

# %%
# In the scoring function I saved after every word in case the script crashed since it took about a day to run.
# That save is commented out now.

# Generate word list
test_wordle = Wordle_list()

score_list = score_words_by_remaining(test_wordle)

with open('remain_word_scores_final.json', 'wt', encoding='utf-8') as file_object:
    file_object.write(json.dumps(score_list))

# %%
# Process raw remain_words scores
with open('remain_word_scores_final.json', 'rt', encoding='utf-8') as file_object:
    data = json.loads(file_object.read())
    
# Find the largest number of words remaining
max_remain = 0
for word in data:
    distribution = word['distribution']
    #print(distribution)
    for words_remain in range(len(distribution), 0, -1):
        if distribution[words_remain-1] != 0:
            if max_remain < distribution[words_remain-1]:
                max_remain = distribution[words_remain-1]
                print(max_remain, word['word'])
                break
# Max was 1482
output_data = []
minimal_data = []
for word in data:
    distribution = word['distribution']
    # Find max number of leftover words
    for words_remain in range(len(distribution), 0, -1):
        if distribution[words_remain-1] != 0:
            max_remain = distribution[words_remain-1]
            break
    
    output_data.append({'word': word['word'], 'average': word['value'], 'max': max_remain, 'distribution': word['distribution'][:max_remain +1]})
    minimal_data.append({'word': word['word'], 'average': word['value'], 'max': max_remain})
    
with open('remain_word_scores_trimmed.json', 'wt', encoding='utf-8') as file_object:
    file_object.write(json.dumps(output_data))
with open('remain_word_scores_minimal.json', 'wt', encoding='utf-8') as file_object:
    file_object.write(json.dumps(minimal_data, indent=2))

print('done')
