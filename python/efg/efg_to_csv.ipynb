# %%
# Load RDF/XML data into a graph
from rdflib import Graph
import pandas as pd

g = Graph()
g.parse('EFGinRDF.xml', format='xml')

print('number of triples: ', len(g))
# Out:
# number of triples:  797

# %%
# retrieve values needed to construct table
query_string = '''
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>
select distinct ?name ?label ?definition
where {
    # ?term rdfs:isDefinedBy ?name.
    # ?term rdfs:label ?label.
    filter(lang(?label)="en")
    # ?term rdfs:comment ?definition.
    filter(lang(?definition)="en")
}
'''
results = g.query(query_string)

rows = []
for row in results:
    column_dict = {}
    
    # Extract local name from end of IRI
    column_dict['term_localName'] = row.name.split(':')[-1]
    
    # Create human-readable label by replacing dashes with spaces
    column_dict['label'] = row.label.replace('-', ' ')
    
    column_dict['definition'] = row.definition
    column_dict['usage'] = ''
    column_dict['notes'] = ''
    column_dict['examples'] = ''
    column_dict['type'] = 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property'
    column_dict['tdwgutility_organizedInClass'] = ''
    
    print(column_dict)
    rows.append(column_dict)
    
data_frame = pd.DataFrame(rows)
# Out:
# {'term_localName': 'CrystalMeasurement-TitleCitation', 'label': 'CrystalMeasurement TitleCitation', 'definition': rdflib.term.Literal('Formal citation for a paper or electronic publication.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'AnalysisDateTime-DateText', 'label': 'AnalysisDateTime DateText', 'definition': rdflib.term.Literal('Free text to allow for vague dates or description of analysis period.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Alteration', 'label': 'Alteration', 'definition': rdflib.term.Literal('Container for describing metasomatic, metamorphic or diagenetic changes to units', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'HostRockStratigraphy-Bed', 'label': 'HostRockStratigraphy Bed', 'definition': rdflib.term.Literal('The smallest division of a named stratified series normally with well defined division from adjacent deposits.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'CrystalMeasurement-Parameter', 'label': 'CrystalMeasurement Parameter', 'definition': rdflib.term.Literal('Describes type of measurement or fact, such as width, abundance, circumference, temperature etc. or color etc.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'FeedingPredationTraces', 'label': 'FeedingPredationTraces', 'definition': rdflib.term.Literal('Free text description relating to aspects of feeding and predation e.g. ammonite with bite mark from plesiosaur,  shell drilled by predatory gastropod etc.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'HazardText', 'label': 'HazardText', 'definition': rdflib.term.Literal('Free text describing any hazards that may be associated with the specimen/unit e.g. is it radioactive, poisonous, carcinogenic?', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Geologists', 'label': 'Geologists', 'definition': rdflib.term.Literal('The geologist(s) and or organisation responsible for logging the borehole and or maintaining the borehole record.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'CrystalMeasurement-Method', 'label': 'CrystalMeasurement Method', 'definition': rdflib.term.Literal('Method used to make measurement.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'AnalysisReferences-TitleCitation', 'label': 'AnalysisReferences TitleCitation', 'definition': rdflib.term.Literal('Formal citation for a paper or electronic publication.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Geologists-Representation', 'label': 'Geologists Representation', 'definition': rdflib.term.Literal('Language-specific label representation.\n[ATTR: language]', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'HoleDirection', 'label': 'HoleDirection', 'definition': rdflib.term.Literal('Direction and inclination of the borehole or well.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'CrystalForm', 'label': 'CrystalForm', 'definition': rdflib.term.Literal('Container element for describing the crystal form of a mineral unit.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'AnalysisDateTime-ISODateTimeBegin', 'label': 'AnalysisDateTime ISODateTimeBegin', 'definition': rdflib.term.Literal('The exact date (and time) or beginning of a period, expressed in a modified ISO/ANSI 8601 standard structured format.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'CrystalMeasurement', 'label': 'CrystalMeasurement', 'definition': rdflib.term.Literal('Individual measurement or fact related to a crystal unit - container for standard MeasurementOrFact complex type from main schema.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'AnalysisDateTime-TimeZone', 'label': 'AnalysisDateTime TimeZone', 'definition': rdflib.term.Literal('The time zone to which the time-of-day data refer.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'CrystalFormText', 'label': 'CrystalFormText', 'definition': rdflib.term.Literal('Free text description of crystal form.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'AnalysisDateTime', 'label': 'AnalysisDateTime', 'definition': rdflib.term.Literal('When the analysis was carried out.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'CrystalMeasurement-AppliesTo', 'label': 'CrystalMeasurement AppliesTo', 'definition': rdflib.term.Literal('Depending on the use of the type, this can further specify the actual part measured. For example, a measurement of temperature may be a surface, air or sub-surface measurement.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'AnalysisReferences', 'label': 'AnalysisReferences', 'definition': rdflib.term.Literal('Container for 1 or more references related to the analysis.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'BaselineDatum', 'label': 'BaselineDatum', 'definition': rdflib.term.Literal('Text - what is the baseline e.g. top of borehole or base of measured section', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'HostRockStratigraphy', 'label': 'HostRockStratigraphy', 'definition': rdflib.term.Literal('Container for any stratigraphic determination specific to the host rock. For instance the gathering site may include a range of stratigraphic horizons whilst the unit host rock may represent just one. The unit itself might be different if it is allochthonous in origin. Minerals may be of a different age from their host rock.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Geologists-Abbreviation', 'label': 'Geologists Abbreviation', 'definition': rdflib.term.Literal('Restricted to 50 characters maximum length, including blanks (recommended to be shorter!). Label abbreviations are especially important when displaying information in a tabular format.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Geologists-OrgUnit', 'label': 'Geologists OrgUnit', 'definition': rdflib.term.Literal('(vCard:OrgUnit)', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Completeness', 'label': 'Completeness', 'definition': rdflib.term.Literal('Free text descrbing the degree of completeness of the specimen e.g. complete, cephalon only, but may describe completeness of a part e.g. complete skull.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'DipDegrees', 'label': 'DipDegrees', 'definition': rdflib.term.Literal('The dip in degrees of laminae or stratal surfaces in this layer.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Hazard', 'label': 'Hazard', 'definition': rdflib.term.Literal('Container for describing hazards that may be associated with the specimen e.g. radioactive, toxic, carcinogens etc.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Geologists-PreferredName', 'label': 'Geologists PreferredName', 'definition': rdflib.term.Literal("May differ from the first given name: second given name, nickname ('Bob' for 'Robert'), etc. (vCard:Nickname)", lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Geologists-Name', 'label': 'Geologists Name', 'definition': rdflib.term.Literal("Full organization or corporate name in multiple languages (en: 'Botanical Garden of ...', de: 'Botanischer Garten von ...'). vCard:Org.OrgName). The Label mechanism also supports acronyms / abbreviations (no vCard equivalent!).", lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'AnalysisReferences-CitationDetail', 'label': 'AnalysisReferences CitationDetail', 'definition': rdflib.term.Literal('Specific page, figure or illustration number(s) within the reference.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'CrystalMeasurement-Duration', 'label': 'CrystalMeasurement Duration', 'definition': rdflib.term.Literal('Duration of measurement in time.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'EarthScienceSpecimen', 'label': 'EarthScienceSpecimen', 'definition': rdflib.term.Literal('Container for details that generally relate to the management of earth science specimens and their individual stratigraphic age (which may be different or more specific than that recorderd for the gathering site or the host rock.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'CrystalMeasurement-Accuracy', 'label': 'CrystalMeasurement Accuracy', 'definition': rdflib.term.Literal('Statement of accuracy of measurement.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'AnalysisDateTime-TimeOfDayBegin', 'label': 'AnalysisDateTime TimeOfDayBegin', 'definition': rdflib.term.Literal('Time of day in hours from midnight for an exact point in time or for the beginning of a time period.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'DrillMethod', 'label': 'DrillMethod', 'definition': rdflib.term.Literal('How the borehole or well was drilled e.g. reverse circulation drilling, diamond coring, percussion drilling, auger drilling, rotary/barber drilling etc.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'BottomSurface', 'label': 'BottomSurface', 'definition': rdflib.term.Literal('Container for details of bottom surface of layer or stratum.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Geologists-SortingName', 'label': 'Geologists SortingName', 'definition': rdflib.term.Literal('The full name with the elements in preferred sorting sequence (vCard: Sort-String).', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Geologists-Suffix', 'label': 'Geologists Suffix', 'definition': rdflib.term.Literal("Suffix to name that should be output after name, regardless whether it is in sorting sequence (Inherited, Given) or not. Examples: 'Jun.', 'III.'. (vCard:N.Suffix)", lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Contractor', 'label': 'Contractor', 'definition': rdflib.term.Literal('The drilling contractor who carried out the work.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'BottomSurfaceFeature', 'label': 'BottomSurfaceFeature', 'definition': rdflib.term.Literal('Text describing features at the base of a layer or stratum.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'DatingQualifier', 'label': 'DatingQualifier', 'definition': rdflib.term.Literal('Allows for qualification of date terms e.g. early/lower, middle, late/upper.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Geologists-Organisation', 'label': 'Geologists Organisation', 'definition': rdflib.term.Literal('Organisation type from the abcd schema.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'CrystalMeasurement-MeasurementOrFactText', 'label': 'CrystalMeasurement MeasurementOrFactText', 'definition': rdflib.term.Literal('Free text alternative to atomised version.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'AnalysisReferences-AnalysisReference', 'label': 'AnalysisReferences AnalysisReference', 'definition': rdflib.term.Literal('Individual documentary reference linked to an analysis. Uses abcd:Reference Type', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'HostRockStratigraphy-BiostratigraphicAttribution-AppliesTo', 'label': 'HostRockStratigraphy BiostratigraphicAttribution AppliesTo', 'definition': rdflib.term.Literal('Depending on the use of the type, this can further specify the actual part measured. For example, a measurement of temperature may be a surface, air or sub-surface measurement.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'DiageneticChange', 'label': 'DiageneticChange', 'definition': rdflib.term.Literal('Free text for describing any physical and chemical changes that took place in a sediment during the lithification process e.g. compaction, cementation, recrystallisation, dolomitisation and replacement.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'HostRockStratigraphy-BiostratigraphicAttribution', 'label': 'HostRockStratigraphy BiostratigraphicAttribution', 'definition': rdflib.term.Literal('A single declaration of a fossil zone or subzone.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'CrystalMeasurement-CitationDetail', 'label': 'CrystalMeasurement CitationDetail', 'definition': rdflib.term.Literal('Specific page, figure or illustration number(s) within the reference.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'AssemblageOrigin', 'label': 'AssemblageOrigin', 'definition': rdflib.term.Literal('Free text description relating to the mode of origin of the assemblage e.g. unknown, allochthonous, autochthonous, paraautochthonous etc.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'AlterationType', 'label': 'AlterationType', 'definition': rdflib.term.Literal('Free text describing the type of change that has taken place e.g. chloritisation, migmatisation, cataclastic brecciation etc.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'CrystalMeasurements', 'label': 'CrystalMeasurements', 'definition': rdflib.term.Literal('Container for measurements of crystal physical and chemical characteristics.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Geologists-Text', 'label': 'Geologists Text', 'definition': rdflib.term.Literal('Label text in a specific language.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'AnalysisDateTime-TimeOfDayEnd', 'label': 'AnalysisDateTime TimeOfDayEnd', 'definition': rdflib.term.Literal('Time of day in hours from midnight for the end of a time period.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'AnalysisDateTime-ExactDate-DateText', 'label': 'AnalysisDateTime ExactDate DateText', 'definition': rdflib.term.Literal('The date in text format.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'AnalysisDateTime-DayNumberEnd', 'label': 'AnalysisDateTime DayNumberEnd', 'definition': rdflib.term.Literal('The Julian day number of the last day in a period.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'AllocthonousMaterial', 'label': 'AllocthonousMaterial', 'definition': rdflib.term.Literal('Container for descriptive elements related to transported material ranging from glacial erratics to meteorites', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'CrystalMeasurement-LowerValue', 'label': 'CrystalMeasurement LowerValue', 'definition': rdflib.term.Literal('Lower or only value or fact text.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'CommissionedBy', 'label': 'CommissionedBy', 'definition': rdflib.term.Literal('Company or organisation who commissioned the borehole or well.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Certainty', 'label': 'Certainty', 'definition': rdflib.term.Literal('Degree of certainty associated with the date determination e.g. unknown, certain, uncertain, possibly, known wrong.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Geologists-Person', 'label': 'Geologists Person', 'definition': rdflib.term.Literal('Person type from the abcd schema.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'AlterationDegree', 'label': 'AlterationDegree', 'definition': rdflib.term.Literal('Free text describing the degree of alteration or metamorphic phase that has affected a rock. [This element may need to be split into hydrothermal mineralogical change and metamorphic phases]', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'CrystalMeasurement-MeasurementOrFactReference', 'label': 'CrystalMeasurement MeasurementOrFactReference', 'definition': rdflib.term.Literal('Reference (publication) where this measurement was taken from.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'CrystalMeasurement-UpperValue', 'label': 'CrystalMeasurement UpperValue', 'definition': rdflib.term.Literal('Upper value where there is a range.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Bioerosion', 'label': 'Bioerosion', 'definition': rdflib.term.Literal('Free text description of damage due to biological action, such as, boring worms and sponges.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'AnalysisDateTime-DayNumberBegin', 'label': 'AnalysisDateTime DayNumberBegin', 'definition': rdflib.term.Literal('Julian day number in the year for the exact date or for the beginning day of a period', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'CrystalMeasurement-MeasurementDateTime', 'label': 'CrystalMeasurement MeasurementDateTime', 'definition': rdflib.term.Literal('Date and/or Time the measurement was taken.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'CrystalMeasurement-UnitOfMeasurement', 'label': 'CrystalMeasurement UnitOfMeasurement', 'definition': rdflib.term.Literal('Unit of measurement.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'DistanceFromBaseline', 'label': 'DistanceFromBaseline', 'definition': rdflib.term.Literal('Number representing distance measured.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'CrystalMeasurement-URI', 'label': 'CrystalMeasurement URI', 'definition': rdflib.term.Literal('Universal Resource Identifier - Path to electronic source of document.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'AnalysisDateTime-ISODateTimeEnd', 'label': 'AnalysisDateTime ISODateTimeEnd', 'definition': rdflib.term.Literal('The end of a period expressed in a modified ISO/ANSI 8601 standard structured format.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'HostRockStratigraphy-BiostratigraphicAttribution-Abbreviation', 'label': 'HostRockStratigraphy BiostratigraphicAttribution Abbreviation', 'definition': rdflib.term.Literal('Restricted to 50 characters maximum length, including blanks (recommended to be shorter!). Label abbreviations are especially important when displaying information in a tabular format.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'AnalysisDateTime-ExactDate', 'label': 'AnalysisDateTime ExactDate', 'definition': rdflib.term.Literal('Uses DateTime element from ABCD.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Geologists-Prefix', 'label': 'Geologists Prefix', 'definition': rdflib.term.Literal("Prefix to inherited name that should be output before name, but is usually not included in sorting. Examples: 'von', 'Lord'. Compare Title for 'Prof', 'Dr.' (vCard:N.Prefix)", lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Geologists-InheritedName', 'label': 'Geologists InheritedName', 'definition': rdflib.term.Literal("Family names, generational names, clan name, parents/grandparents personal names, etc. This (= last name in western cultures) may be compound ('Fischer von Waldheim', 'da Selva', 'Silvano Morales'). Depending on culture it is not necessarily the name of the parents nor common to the married couple and children, thus 'family name' should be avoided even though used in vCard.  (vCard:N.Family)", lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Geologists-FullName', 'label': 'Geologists FullName', 'definition': rdflib.term.Literal('Preferred form of personal name for display as a string.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Borehole', 'label': 'Borehole', 'definition': rdflib.term.Literal('Container for details specific to boreholes and wells. Does not contain spatial reference as this and details of platform etc. are under Gathering in main ABCD schema - but they could be copied to make an independent schema.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Geologists-OrgUnits', 'label': 'Geologists OrgUnits', 'definition': rdflib.term.Literal('If the contact contains no person definition: the unit within the organization the agent represents; else a list of the various organisational units to which a person may belong. (vCard:OrgUnit)', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'CrystalMeasurement-MeasuredBy', 'label': 'CrystalMeasurement MeasuredBy', 'definition': rdflib.term.Literal('Attribution of the measurement to a Person', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'CrystalMeasurement-IsQuantitative', 'label': 'CrystalMeasurement IsQuantitative', 'definition': rdflib.term.Literal('Flag indicating if the value represents the numerical result of a quantitative measurement (TRUE) or a descriptor with textual or categorical result (FALSE).', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'HostRockStratigraphy-BiostratigraphicAttribution-Accuracy', 'label': 'HostRockStratigraphy BiostratigraphicAttribution Accuracy', 'definition': rdflib.term.Literal('Statement of accuracy of measurement.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'AnalysisDateTime-PeriodExplicit', 'label': 'AnalysisDateTime PeriodExplicit', 'definition': rdflib.term.Literal('Set to True if the event takes place for the period indicated, set to False if it occurs at some point of time during the period, not filled if unknown or no period specified.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'AnalysisReferences-URI', 'label': 'AnalysisReferences URI', 'definition': rdflib.term.Literal('Universal Resource Identifier - Path to electronic source of document.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Encrustation', 'label': 'Encrustation', 'definition': rdflib.term.Literal('Free text description of biological encrustations, such as oysters and tube worms.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'HoleDiameter', 'label': 'HoleDiameter', 'definition': rdflib.term.Literal('Diameter of the borehole in milliimetres.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Geologists-GivenNames', 'label': 'Geologists GivenNames', 'definition': rdflib.term.Literal("The name given to a person as a personal name (= first or christian name in western cultures, including 'middle initials') may contain several words ('Ana Maria', 'Jerry B.'). Applicable only to persons. (vCard:N.Given + vCard:N.Middle)", lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}
# {'term_localName': 'Articulation', 'label': 'Articulation', 'definition': rdflib.term.Literal('Free text description of the articulation in the preserved specimen - applies to invertebrate shells and exoskeletons as well as vertebrate skeletons. e.g. articulated, dis-articulated, single valves etc.', lang='en'), 'usage': '', 'notes': '', 'examples': '', 'type': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property', 'tdwgutility_organizedInClass': ''}

# %%
data_frame
# Out:
#                       term_localName                             label  \
# 0   CrystalMeasurement-TitleCitation  CrystalMeasurement TitleCitation
# 1          AnalysisDateTime-DateText         AnalysisDateTime DateText
# 2                         Alteration                        Alteration
# 3           HostRockStratigraphy-Bed          HostRockStratigraphy Bed
# 4       CrystalMeasurement-Parameter      CrystalMeasurement Parameter
# ..                               ...                               ...
# 81            AnalysisReferences-URI            AnalysisReferences URI
# 82                      Encrustation                      Encrustation
# 83                      HoleDiameter                      HoleDiameter
# 84             Geologists-GivenNames             Geologists GivenNames
# 85                      Articulation                      Articulation
#
#                                            definition usage notes examples  \
# 0   Formal citation for a paper or electronic publ...
# 1   Free text to allow for vague dates or descript...
# 2   Container for describing metasomatic, metamorp...
# 3   The smallest division of a named stratified se...
# 4   Describes type of measurement or fact, such as...
# ..                                                ...   ...   ...      ...
# 81  Universal Resource Identifier - Path to electr...
# 82  Free text description of biological encrustati...
# 83          Diameter of the borehole in milliimetres.
# 84  The name given to a person as a personal name ...
# 85  Free text description of the articulation in t...
#
#                                                  type  \
# 0   http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
# 1   http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
# 2   http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
# 3   http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
# 4   http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
# ..                                                ...
# 81  http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
# 82  http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
# 83  http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
# 84  http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
# 85  http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
#
#    tdwgutility_organizedInClass
# 0
# 1
# 2
# 3
# 4
# ..                          ...
# 81
# 82
# 83
# 84
# 85
#
# [86 rows x 8 columns]

# %%
data_frame.to_csv('efg.csv', index = False)
print('done')
# Out:
# done
